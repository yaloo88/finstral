# %%
import sys
sys.path.append(r'C:\Users\Administrator\finstral-1')
print(sys.path)
from qt_api import qt_api as qt
# Out:
# ['c:\\Users\\Administrator\\finstral-1\\notebooks', 'c:\\ProgramData\\Anaconda3\\python311.zip', 'c:\\ProgramData\\Anaconda3\\DLLs', 'c:\\ProgramData\\Anaconda3\\Lib', 'c:\\ProgramData\\Anaconda3', '', 'C:\\Users\\Administrator\\AppData\\Roaming\\Python\\Python311\\site-packages', 'c:\\ProgramData\\Anaconda3\\Lib\\site-packages', '\\\\10.3.0.38\\backup\\users\\backup\\questradecustomapiwrapper', 'c:\\ProgramData\\Anaconda3\\Lib\\site-packages\\win32', 'c:\\ProgramData\\Anaconda3\\Lib\\site-packages\\win32\\lib', 'c:\\ProgramData\\Anaconda3\\Lib\\site-packages\\Pythonwin', '..', '..', 'C:\\Users\\Administrator\\finstral-1', 'C:\\Users\\Administrator\\finstral-1']

# %%
import datetime

# %%
days_back = 30
start_time = (datetime.datetime.now() - datetime.timedelta(days=days_back)).replace(hour=0, minute=0, second=0, microsecond=0).astimezone().isoformat()
end_time = datetime.datetime.now().replace(hour=23, minute=59, second=59, microsecond=0).astimezone().isoformat()

# %%
accounts = qt.get_questrade_accounts()
accounts
# Out:
# {'accounts': [{'type': 'Margin',
#    'number': '27955569',
#    'status': 'Active',
#    'isPrimary': True,
#    'isBilling': True,
#    'clientAccountType': 'Individual'},
#   {'type': 'TFSA',
#    'number': '52541889',
#    'status': 'Active',
#    'isPrimary': False,
#    'isBilling': False,
#    'clientAccountType': 'Individual'},
#   {'type': 'RRSP',
#    'number': '52814982',
#    'status': 'Active',
#    'isPrimary': False,
#    'isBilling': False,
#    'clientAccountType': 'Individual'},
#   {'type': 'FHSA',
#    'number': '52963793',
#    'status': 'Active',
#    'isPrimary': False,
#    'isBilling': False,
#    'clientAccountType': 'Individual'}],
#  'userId': 1241629}

# %%
positions = qt.get_questrade_positions(accounts["accounts"][1]["number"])
positions
# Out:
# {'positions': [{'symbol': 'CGXF.TO',
#    'symbolId': 26941696,
#    'openQuantity': 1,
#    'closedQuantity': 0,
#    'currentMarketValue': 13.19,
#    'currentPrice': 13.19,
#    'averageEntryPrice': 11,
#    'dayPnl': None,
#    'closedPnl': 0,
#    'openPnl': 2.19,
#    'totalCost': 11,
#    'isRealTime': True,
#    'isUnderReorg': False},
#   {'symbol': 'XEC.TO',
#    'symbolId': 3607312,
#    'openQuantity': 9,
#    'closedQuantity': 0,
#    'currentMarketValue': 261.45,
#    'currentPrice': 29.05,
#    'averageEntryPrice': 29.252222,
#    'dayPnl': None,
#    'closedPnl': 0,
#    'openPnl': -1.819998,
#    'totalCost': 263.269998,
#    'isRealTime': True,
#    'isUnderReorg': False},
#   {'symbol': 'XGRO.TO',
#    'symbolId': 1897749,
#    'openQuantity': 8,
#    'closedQuantity': 0,
#    'currentMarketValue': 234.8,
#    'currentPrice': 29.35,
#    'averageEntryPrice': 29.6925,
#    'dayPnl': None,
#    'closedPnl': 0,
#    'openPnl': -2.74,
#    'totalCost': 237.54,
#    'isRealTime': True,
#    'isUnderReorg': False},
#   {'symbol': 'ZCN.TO',
#    'symbolId': 2701877,
#    'openQuantity': 35,
#    'closedQuantity': 0,
#    'currentMarketValue': 1139.25,
#    'currentPrice': 32.55,
#    'averageEntryPrice': 32.049143,
#    'dayPnl': None,
#    'closedPnl': 0,
#    'openPnl': 17.529995,
#    'totalCost': 1121.720005,
#    'isRealTime': True,
#    'isUnderReorg': False},
#   {'symbol': 'ZSP.TO',
#    'symbolId': 2965569,
#    'openQuantity': 29,
#    'closedQuantity': 0,
#    'currentMarketValue': 2407.87,
#    'currentPrice': 83.03,
#    'averageEntryPrice': 87.244828,
#    'dayPnl': None,
#    'closedPnl': 0,
#    'openPnl': -122.230012,
#    'totalCost': 2530.100012,
#    'isRealTime': True,
#    'isUnderReorg': False},
#   {'symbol': 'CNDU.TO',
#    'symbolId': 28103235,
#    'openQuantity': 1,
#    'closedQuantity': 0,
#    'currentMarketValue': 26.39,
#    'currentPrice': 26.39,
#    'averageEntryPrice': 18.23,
#    'dayPnl': None,
#    'closedPnl': 0,
#    'openPnl': 8.16,
#    'totalCost': 18.23,
#    'isRealTime': True,
#    'isUnderReorg': False},
#   {'symbol': 'ZEM.TO',
#    'symbolId': 3579720,
#    'openQuantity': 1,
#    'closedQuantity': 0,
#    'currentMarketValue': 21.45,
#    'currentPrice': 21.45,
#    'averageEntryPrice': 19.2,
#    'dayPnl': None,
#    'closedPnl': 0,
#    'openPnl': 2.25,
#    'totalCost': 19.2,
#    'isRealTime': True,
#    'isUnderReorg': False},
#   {'symbol': 'WEED.TO',
#    'symbolId': 52040561,
#    'openQuantity': 29,
#    'closedQuantity': 0,
#    'currentMarketValue': 40.02,
#    'currentPrice': 1.38,
#    'averageEntryPrice': 72.90406,
#    'dayPnl': None,
#    'closedPnl': 0,
#    'openPnl': -2074.19774,
#    'totalCost': 2114.21774,
#    'isRealTime': True,
#    'isUnderReorg': False},
#   {'symbol': 'ZEA.TO',
#    'symbolId': 5587643,
#    'openQuantity': 47,
#    'closedQuantity': 0,
#    'currentMarketValue': 1121.42,
#    'currentPrice': 23.86,
#    'averageEntryPrice': 23.469363,
#    'dayPnl': None,
#    'closedPnl': 0,
#    'openPnl': 18.359939,
#    'totalCost': 1103.060061,
#    'isRealTime': True,
#    'isUnderReorg': False},
#   {'symbol': 'NEGG',
#    'symbolId': 36083445,
#    'openQuantity': 104,
#    'closedQuantity': 0,
#    'currentMarketValue': 22.8904,
#    'currentPrice': 0.2201,
#    'averageEntryPrice': 4.24546,
#    'dayPnl': None,
#    'closedPnl': 0,
#    'openPnl': -418.63744,
#    'totalCost': 441.52784,
#    'isRealTime': True,
#    'isUnderReorg': False},
#   {'symbol': 'BTCX.B.TO',
#    'symbolId': 34965750,
#    'openQuantity': 14,
#    'closedQuantity': 0,
#    'currentMarketValue': 237.58,
#    'currentPrice': 16.97,
#    'averageEntryPrice': 10.55,
#    'dayPnl': None,
#    'closedPnl': 0,
#    'openPnl': 89.88,
#    'totalCost': 147.7,
#    'isRealTime': True,
#    'isUnderReorg': False}]}

# %%
balances = qt.get_questrade_balances(accounts["accounts"][1]["number"])
balances
# Out:
# {'perCurrencyBalances': [{'currency': 'CAD',
#    'cash': 117.3225,
#    'marketValue': 5503.42,
#    'totalEquity': 5620.7425,
#    'buyingPower': 117.3225,
#    'maintenanceExcess': 117.3225,
#    'isRealTime': True},
#   {'currency': 'USD',
#    'cash': 22.891772,
#    'marketValue': 22.8904,
#    'totalEquity': 45.782172,
#    'buyingPower': 22.891772,
#    'maintenanceExcess': 22.891772,
#    'isRealTime': True}],
#  'combinedBalances': [{'currency': 'CAD',
#    'cash': 149.580441,
#    'marketValue': 5535.676007,
#    'totalEquity': 5685.256448,
#    'buyingPower': 149.580441,
#    'maintenanceExcess': 149.580441,
#    'isRealTime': True},
#   {'currency': 'USD',
#    'cash': 106.14941,
#    'marketValue': 3928.379525,
#    'totalEquity': 4034.528934,
#    'buyingPower': 106.14941,
#    'maintenanceExcess': 106.14941,
#    'isRealTime': True}],
#  'sodPerCurrencyBalances': [{'currency': 'CAD',
#    'cash': 117.3225,
#    'marketValue': 5496.52,
#    'totalEquity': 5613.8425,
#    'buyingPower': 117.3225,
#    'maintenanceExcess': 117.3225,
#    'isRealTime': True},
#   {'currency': 'USD',
#    'cash': 22.891772,
#    'marketValue': 22.8904,
#    'totalEquity': 45.782172,
#    'buyingPower': 22.891772,
#    'maintenanceExcess': 22.891772,
#    'isRealTime': True}],
#  'sodCombinedBalances': [{'currency': 'CAD',
#    'cash': 149.580441,
#    'marketValue': 5528.776007,
#    'totalEquity': 5678.356448,
#    'buyingPower': 149.580441,
#    'maintenanceExcess': 149.580441,
#    'isRealTime': True},
#   {'currency': 'USD',
#    'cash': 106.14941,
#    'marketValue': 3923.482956,
#    'totalEquity': 4029.632365,
#    'buyingPower': 106.14941,
#    'maintenanceExcess': 106.14941,
#    'isRealTime': True}]}

# %%
executions = qt.get_questrade_executions(accounts["accounts"][1]["number"],start_time,end_time)
executions
# Out:
# {'executions': [{'symbol': 'ZSP.TO',
#    'symbolId': 2965569,
#    'quantity': 1,
#    'side': 'Buy',
#    'price': 86.87,
#    'id': 2166696643,
#    'orderId': 1409969916,
#    'orderChainId': 1409969916,
#    'exchangeExecId': 'S3-778411',
#    'timestamp': '2025-03-31T10:32:46.232000-04:00',
#    'notes': '',
#    'venue': 'CXD',
#    'totalCost': 86.87,
#    'orderPlacementCommission': 0,
#    'commission': 0,
#    'executionFee': 0,
#    'secFee': 0,
#    'legId': 0,
#    'canadianExecutionFee': 0,
#    'parentId': 2166696643},
#   {'symbol': 'ZEA.TO',
#    'symbolId': 5587643,
#    'quantity': 1,
#    'side': 'Buy',
#    'price': 24.54,
#    'id': 2166696639,
#    'orderId': 1409969915,
#    'orderChainId': 1409969915,
#    'exchangeExecId': 'S3-778381',
#    'timestamp': '2025-03-31T10:32:45.751000-04:00',
#    'notes': '',
#    'venue': 'CXD',
#    'totalCost': 24.54,
#    'orderPlacementCommission': 0,
#    'commission': 0,
#    'executionFee': 0,
#    'secFee': 0,
#    'legId': 0,
#    'canadianExecutionFee': 0,
#    'parentId': 2166696639},
#   {'symbol': 'ZSP.TO',
#    'symbolId': 2965569,
#    'quantity': 1,
#    'side': 'Buy',
#    'price': 89.07,
#    'id': 2152820079,
#    'orderId': 1401348382,
#    'orderChainId': 1401348382,
#    'exchangeExecId': 'S3-1204231',
#    'timestamp': '2025-03-17T15:13:42.297000-04:00',
#    'notes': '',
#    'venue': 'CXD',
#    'totalCost': 89.07,
#    'orderPlacementCommission': 0,
#    'commission': 0,
#    'executionFee': 0,
#    'secFee': 0,
#    'legId': 0,
#    'canadianExecutionFee': 0,
#    'parentId': 2152820079},
#   {'symbol': 'ZCN.TO',
#    'symbolId': 2701877,
#    'quantity': 2,
#    'side': 'Buy',
#    'price': 32.81,
#    'id': 2144257938,
#    'orderId': 1396366045,
#    'orderChainId': 1396366045,
#    'exchangeExecId': 'S3-743910',
#    'timestamp': '2025-03-10T10:47:43.529000-04:00',
#    'notes': '',
#    'venue': 'TSX',
#    'totalCost': 65.62,
#    'orderPlacementCommission': 0,
#    'commission': 0,
#    'executionFee': 0,
#    'secFee': 0,
#    'legId': 0,
#    'canadianExecutionFee': 0,
#    'parentId': 2144257938},
#   {'symbol': 'BTCX.B.TO',
#    'symbolId': 34965750,
#    'quantity': 2,
#    'side': 'Buy',
#    'price': 16.84,
#    'id': 2144257934,
#    'orderId': 1396366044,
#    'orderChainId': 1396366044,
#    'exchangeExecId': 'S3-743842',
#    'timestamp': '2025-03-10T10:47:43.001000-04:00',
#    'notes': '',
#    'venue': 'CXD',
#    'totalCost': 33.68,
#    'orderPlacementCommission': 0,
#    'commission': 0,
#    'executionFee': 0,
#    'secFee': 0,
#    'legId': 0,
#    'canadianExecutionFee': 0,
#    'parentId': 2144257934}]}

# %%
import datetime
orders = qt.get_account_orders(accounts["accounts"][1]["number"],start_time,end_time)
orders
# Out:
# {'orders': [{'id': 1396366044,
#    'symbol': 'BTCX.B.TO',
#    'symbolId': 34965750,
#    'totalQuantity': 2,
#    'openQuantity': 0,
#    'filledQuantity': 2,
#    'canceledQuantity': 0,
#    'side': 'Buy',
#    'orderType': 'Limit',
#    'limitPrice': 16.84,
#    'stopPrice': None,
#    'isAllOrNone': False,
#    'isAnonymous': False,
#    'icebergQuantity': None,
#    'minQuantity': None,
#    'avgExecPrice': 16.84,
#    'lastExecPrice': None,
#    'source': 'TradingAPI',
#    'timeInForce': 'Day',
#    'gtdDate': None,
#    'state': 'Executed',
#    'rejectionReason': '',
#    'chainId': 1396366044,
#    'creationTime': '2025-03-10T10:47:42.934000-04:00',
#    'updateTime': '2025-03-10T10:47:43.082000-04:00',
#    'notes': '',
#    'primaryRoute': 'AUTO',
#    'secondaryRoute': 'AUTO',
#    'orderRoute': 'ITSR',
#    'venueHoldingOrder': 'ITSR',
#    'comissionCharged': None,
#    'exchangeOrderId': 'H39086464',
#    'isSignificantShareHolder': False,
#    'isInsider': False,
#    'isLimitOffsetInDollar': False,
#    'userId': 1241629,
#    'placementCommission': None,
#    'legs': [],
#    'strategyType': 'SingleLeg',
#    'triggerStopPrice': None,
#    'orderGroupId': 0,
#    'orderClass': None,
#    'isCrossZero': False},
#   {'id': 1396366045,
#    'symbol': 'ZCN.TO',
#    'symbolId': 2701877,
#    'totalQuantity': 2,
#    'openQuantity': 0,
#    'filledQuantity': 2,
#    'canceledQuantity': 0,
#    'side': 'Buy',
#    'orderType': 'Limit',
#    'limitPrice': 32.82,
#    'stopPrice': None,
#    'isAllOrNone': False,
#    'isAnonymous': False,
#    'icebergQuantity': None,
#    'minQuantity': None,
#    'avgExecPrice': 32.81,
#    'lastExecPrice': None,
#    'source': 'TradingAPI',
#    'timeInForce': 'Day',
#    'gtdDate': None,
#    'state': 'Executed',
#    'rejectionReason': '',
#    'chainId': 1396366045,
#    'creationTime': '2025-03-10T10:47:43.500000-04:00',
#    'updateTime': '2025-03-10T10:47:43.565000-04:00',
#    'notes': '',
#    'primaryRoute': 'AUTO',
#    'secondaryRoute': 'AUTO',
#    'orderRoute': 'ITSR',
#    'venueHoldingOrder': 'ITSR',
#    'comissionCharged': None,
#    'exchangeOrderId': 'BT0250310000000061',
#    'isSignificantShareHolder': False,
#    'isInsider': False,
#    'isLimitOffsetInDollar': False,
#    'userId': 1241629,
#    'placementCommission': None,
#    'legs': [],
#    'strategyType': 'SingleLeg',
#    'triggerStopPrice': None,
#    'orderGroupId': 0,
#    'orderClass': None,
#    'isCrossZero': False},
#   {'id': 1401348382,
#    'symbol': 'ZSP.TO',
#    'symbolId': 2965569,
#    'totalQuantity': 1,
#    'openQuantity': 0,
#    'filledQuantity': 1,
#    'canceledQuantity': 0,
#    'side': 'Buy',
#    'orderType': 'Limit',
#    'limitPrice': 89.08,
#    'stopPrice': None,
#    'isAllOrNone': False,
#    'isAnonymous': False,
#    'icebergQuantity': None,
#    'minQuantity': None,
#    'avgExecPrice': 89.07,
#    'lastExecPrice': None,
#    'source': 'TradingAPI',
#    'timeInForce': 'Day',
#    'gtdDate': None,
#    'state': 'Executed',
#    'rejectionReason': '',
#    'chainId': 1401348382,
#    'creationTime': '2025-03-17T15:13:42.228000-04:00',
#    'updateTime': '2025-03-17T15:13:42.363000-04:00',
#    'notes': '',
#    'primaryRoute': 'AUTO',
#    'secondaryRoute': 'AUTO',
#    'orderRoute': 'ITSR',
#    'venueHoldingOrder': 'ITSR',
#    'comissionCharged': None,
#    'exchangeOrderId': 'H81581555',
#    'isSignificantShareHolder': False,
#    'isInsider': False,
#    'isLimitOffsetInDollar': False,
#    'userId': 1241629,
#    'placementCommission': None,
#    'legs': [],
#    'strategyType': 'SingleLeg',
#    'triggerStopPrice': None,
#    'orderGroupId': 0,
#    'orderClass': None,
#    'isCrossZero': False},
#   {'id': 1409969915,
#    'symbol': 'ZEA.TO',
#    'symbolId': 5587643,
#    'totalQuantity': 1,
#    'openQuantity': 0,
#    'filledQuantity': 1,
#    'canceledQuantity': 0,
#    'side': 'Buy',
#    'orderType': 'Limit',
#    'limitPrice': 24.56,
#    'stopPrice': None,
#    'isAllOrNone': False,
#    'isAnonymous': False,
#    'icebergQuantity': None,
#    'minQuantity': None,
#    'avgExecPrice': 24.54,
#    'lastExecPrice': None,
#    'source': 'TradingAPI',
#    'timeInForce': 'Day',
#    'gtdDate': None,
#    'state': 'Executed',
#    'rejectionReason': '',
#    'chainId': 1409969915,
#    'creationTime': '2025-03-31T10:32:45.729000-04:00',
#    'updateTime': '2025-03-31T10:32:45.859000-04:00',
#    'notes': '',
#    'primaryRoute': 'AUTO',
#    'secondaryRoute': 'AUTO',
#    'orderRoute': 'ITSR',
#    'venueHoldingOrder': 'ITSR',
#    'comissionCharged': None,
#    'exchangeOrderId': 'H28870239',
#    'isSignificantShareHolder': False,
#    'isInsider': False,
#    'isLimitOffsetInDollar': False,
#    'userId': 1241629,
#    'placementCommission': None,
#    'legs': [],
#    'strategyType': 'SingleLeg',
#    'triggerStopPrice': None,
#    'orderGroupId': 0,
#    'orderClass': None,
#    'isCrossZero': False},
#   {'id': 1409969916,
#    'symbol': 'ZSP.TO',
#    'symbolId': 2965569,
#    'totalQuantity': 1,
#    'openQuantity': 0,
#    'filledQuantity': 1,
#    'canceledQuantity': 0,
#    'side': 'Buy',
#    'orderType': 'Limit',
#    'limitPrice': 86.88,
#    'stopPrice': None,
#    'isAllOrNone': False,
#    'isAnonymous': False,
#    'icebergQuantity': None,
#    'minQuantity': None,
#    'avgExecPrice': 86.87,
#    'lastExecPrice': None,
#    'source': 'TradingAPI',
#    'timeInForce': 'Day',
#    'gtdDate': None,
#    'state': 'Executed',
#    'rejectionReason': '',
#    'chainId': 1409969916,
#    'creationTime': '2025-03-31T10:32:46.168000-04:00',
#    'updateTime': '2025-03-31T10:32:46.286000-04:00',
#    'notes': '',
#    'primaryRoute': 'AUTO',
#    'secondaryRoute': 'AUTO',
#    'orderRoute': 'ITSR',
#    'venueHoldingOrder': 'ITSR',
#    'comissionCharged': None,
#    'exchangeOrderId': 'H28871828',
#    'isSignificantShareHolder': False,
#    'isInsider': False,
#    'isLimitOffsetInDollar': False,
#    'userId': 1241629,
#    'placementCommission': None,
#    'legs': [],
#    'strategyType': 'SingleLeg',
#    'triggerStopPrice': None,
#    'orderGroupId': 0,
#    'orderClass': None,
#    'isCrossZero': False}]}

# %%
account_activities = qt.get_account_activities(accounts["accounts"][1]["number"],start_time,end_time)
account_activities
# Out:
# {'activities': [{'tradeDate': '2025-03-10T00:00:00.000000-04:00',
#    'transactionDate': '2025-03-11T00:00:00.000000-04:00',
#    'settlementDate': '2025-03-11T00:00:00.000000-04:00',
#    'action': 'Buy',
#    'symbol': 'ZCN.TO',
#    'symbolId': 2701877,
#    'description': 'BMO S&P/TSX CAPPED  COMPOSITE INDEX ETF SERIES ETF  UNITS  WE ACTED AS AGENT',
#    'currency': 'CAD',
#    'quantity': 2,
#    'price': 32.81,
#    'grossAmount': -65.62,
#    'commission': 0,
#    'netAmount': -65.62,
#    'type': 'Trades'},
#   {'tradeDate': '2025-03-31T00:00:00.000000-04:00',
#    'transactionDate': '2025-04-01T00:00:00.000000-04:00',
#    'settlementDate': '2025-04-01T00:00:00.000000-04:00',
#    'action': 'Buy',
#    'symbol': 'ZEA.TO',
#    'symbolId': 5587643,
#    'description': 'BMO MSCI EAFE INDEX ETF  CAD UNITS  WE ACTED AS AGENT',
#    'currency': 'CAD',
#    'quantity': 1,
#    'price': 24.54,
#    'grossAmount': -24.54,
#    'commission': 0,
#    'netAmount': -24.54,
#    'type': 'Trades'},
#   {'tradeDate': '2025-03-17T00:00:00.000000-04:00',
#    'transactionDate': '2025-03-18T00:00:00.000000-04:00',
#    'settlementDate': '2025-03-18T00:00:00.000000-04:00',
#    'action': 'Buy',
#    'symbol': 'ZSP.TO',
#    'symbolId': 2965569,
#    'description': 'BMO S&P 500 INDEX ETF  SERIES ETF UNITS  WE ACTED AS AGENT',
#    'currency': 'CAD',
#    'quantity': 1,
#    'price': 89.07,
#    'grossAmount': -89.07,
#    'commission': 0,
#    'netAmount': -89.07,
#    'type': 'Trades'},
#   {'tradeDate': '2025-03-10T00:00:00.000000-04:00',
#    'transactionDate': '2025-03-11T00:00:00.000000-04:00',
#    'settlementDate': '2025-03-11T00:00:00.000000-04:00',
#    'action': 'Buy',
#    'symbol': 'BTCX.B.TO',
#    'symbolId': 34965750,
#    'description': 'CI GALAXY BITCOIN ETF  CAD UNHEDGED ETF UNITS  WE ACTED AS AGENT',
#    'currency': 'CAD',
#    'quantity': 2,
#    'price': 16.84,
#    'grossAmount': -33.68,
#    'commission': 0,
#    'netAmount': -33.68,
#    'type': 'Trades'},
#   {'tradeDate': '2025-03-31T00:00:00.000000-04:00',
#    'transactionDate': '2025-04-01T00:00:00.000000-04:00',
#    'settlementDate': '2025-04-01T00:00:00.000000-04:00',
#    'action': 'Buy',
#    'symbol': 'ZSP.TO',
#    'symbolId': 2965569,
#    'description': 'BMO S&P 500 INDEX ETF  CAD UNITS  WE ACTED AS AGENT',
#    'currency': 'CAD',
#    'quantity': 1,
#    'price': 86.87,
#    'grossAmount': -86.87,
#    'commission': 0,
#    'netAmount': -86.87,
#    'type': 'Trades'},
#   {'tradeDate': '2025-03-14T00:00:00.000000-04:00',
#    'transactionDate': '2025-03-14T00:00:00.000000-04:00',
#    'settlementDate': '2025-03-14T00:00:00.000000-04:00',
#    'action': 'CON',
#    'symbol': '',
#    'symbolId': 0,
#    'description': 'PAD CONT 5254188914',
#    'currency': 'CAD',
#    'quantity': 0,
#    'price': 0,
#    'grossAmount': 0,
#    'commission': 0,
#    'netAmount': 100,
#    'type': 'Deposits'},
#   {'tradeDate': '2025-03-31T00:00:00.000000-04:00',
#    'transactionDate': '2025-03-31T00:00:00.000000-04:00',
#    'settlementDate': '2025-03-31T00:00:00.000000-04:00',
#    'action': '   ',
#    'symbol': 'XGRO.TO',
#    'symbolId': 1897749,
#    'description': 'ISHARES CORE GROWTH ETF PORTFOLIO INDEX COM UNIT DIST      ON       8 SHS REC 03/26/25 PAY 03/31/25',
#    'currency': 'CAD',
#    'quantity': 0,
#    'price': 0.11,
#    'grossAmount': 0,
#    'commission': 0,
#    'netAmount': 0.89,
#    'type': 'Dividends'},
#   {'tradeDate': '2025-04-02T00:00:00.000000-04:00',
#    'transactionDate': '2025-04-02T00:00:00.000000-04:00',
#    'settlementDate': '2025-04-02T00:00:00.000000-04:00',
#    'action': '   ',
#    'symbol': 'ZSP.TO',
#    'symbolId': 2965569,
#    'description': 'BMO S&P 500 INDEX ETF CAD UNITS DIST      ON      28 SHS REC 03/28/25 PAY 04/02/25',
#    'currency': 'CAD',
#    'quantity': 0,
#    'price': 0.21,
#    'grossAmount': 0,
#    'commission': 0,
#    'netAmount': 5.88,
#    'type': 'Dividends'},
#   {'tradeDate': '2025-03-28T00:00:00.000000-04:00',
#    'transactionDate': '2025-03-28T00:00:00.000000-04:00',
#    'settlementDate': '2025-03-28T00:00:00.000000-04:00',
#    'action': 'CON',
#    'symbol': '',
#    'symbolId': 0,
#    'description': 'PAD CONT 5254188914',
#    'currency': 'CAD',
#    'quantity': 0,
#    'price': 0,
#    'grossAmount': 0,
#    'commission': 0,
#    'netAmount': 100,
#    'type': 'Deposits'},
#   {'tradeDate': '2025-04-02T00:00:00.000000-04:00',
#    'transactionDate': '2025-04-02T00:00:00.000000-04:00',
#    'settlementDate': '2025-04-02T00:00:00.000000-04:00',
#    'action': '   ',
#    'symbol': 'ZEA.TO',
#    'symbolId': 5587643,
#    'description': 'BMO MSCI EAFE INDEX ETF CAD UNITS DIST      ON      46 SHS REC 03/28/25 PAY 04/02/25',
#    'currency': 'CAD',
#    'quantity': 0,
#    'price': 0.16,
#    'grossAmount': 0,
#    'commission': 0,
#    'netAmount': 7.36,
#    'type': 'Dividends'},
#   {'tradeDate': '2025-03-31T00:00:00.000000-04:00',
#    'transactionDate': '2025-03-31T00:00:00.000000-04:00',
#    'settlementDate': '2025-03-31T00:00:00.000000-04:00',
#    'action': '   ',
#    'symbol': 'CGXF.TO',
#    'symbolId': 26941696,
#    'description': 'CI GOLD+ GIANTSCOVERED CALL ETF HEDGED COMMON UNITS DIST      ON       1 SHS REC 03/25/25 PAY 03/31/25',
#    'currency': 'CAD',
#    'quantity': 0,
#    'price': 0.23,
#    'grossAmount': 0,
#    'commission': 0,
#    'netAmount': 0.23,
#    'type': 'Dividends'},
#   {'tradeDate': '2025-04-02T00:00:00.000000-04:00',
#    'transactionDate': '2025-04-02T00:00:00.000000-04:00',
#    'settlementDate': '2025-04-02T00:00:00.000000-04:00',
#    'action': '   ',
#    'symbol': 'ZCN.TO',
#    'symbolId': 2701877,
#    'description': 'BMO S&P/TSX CAPPED COMPOSITE INDEX ETF CAD UNITS DIST      ON      35 SHS REC 03/28/25 PAY 04/02/25',
#    'currency': 'CAD',
#    'quantity': 0,
#    'price': 0.23,
#    'grossAmount': 0,
#    'commission': 0,
#    'netAmount': 8.05,
#    'type': 'Dividends'}]}

# %%
markets = qt.get_markets()
markets
# Out:
# {'markets': [{'name': 'TSX',
#    'tradingVenues': ['TSX',
#     'ALPH',
#     'CXC',
#     'OMGA',
#     'PURE',
#     'CNSX',
#     'ATS',
#     'ICX',
#     'LIQ',
#     'LYX',
#     'CXD',
#     'NEOL',
#     'NEO',
#     'MATCH',
#     'CX2'],
#    'defaultTradingVenue': 'AUTO',
#    'primaryOrderRoutes': ['AUTO'],
#    'secondaryOrderRoutes': ['TSX',
#     'AUTO',
#     'CX2',
#     'AQN',
#     'AQL',
#     'CXC',
#     'OME',
#     'OM2',
#     'CXD'],
#    'level1Feeds': ['TSX'],
#    'level2Feeds': ['ALPH', 'CXC', 'NEO', 'NEOL', 'OMGA', 'PURE', 'TSX'],
#    'extendedStartTime': '2025-04-04T07:00:00.000000-04:00',
#    'startTime': '2025-04-04T09:30:00.000000-04:00',
#    'endTime': '2025-04-04T16:00:00.000000-04:00',
#    'extendedEndTime': '2025-04-04T20:00:00.000000-04:00',
#    'snapQuotesLimit': 2147483647},
#   {'name': 'TSXV',
#    'tradingVenues': ['TSXV',
#     'ALPH',
#     'CXC',
#     'OMGA',
#     'PURE',
#     'CNSX',
#     'ATS',
#     'ICX',
#     'LIQ',
#     'LYX',
#     'CXD',
#     'NEOL',
#     'NEO',
#     'MATCH',
#     'CX2'],
#    'defaultTradingVenue': 'AUTO',
#    'primaryOrderRoutes': ['AUTO'],
#    'secondaryOrderRoutes': ['TSXV',
#     'AUTO',
#     'CX2',
#     'AQN',
#     'AQL',
#     'CXC',
#     'OME',
#     'OM2',
#     'CXD'],
#    'level1Feeds': ['TSX'],
#    'level2Feeds': ['ALPH', 'CXC', 'NEO', 'NEOL', 'OMGA', 'PURE', 'TSXV'],
#    'extendedStartTime': '2025-04-04T07:00:00.000000-04:00',
#    'startTime': '2025-04-04T09:30:00.000000-04:00',
#    'endTime': '2025-04-04T16:00:00.000000-04:00',
#    'extendedEndTime': '2025-04-04T20:00:00.000000-04:00',
#    'snapQuotesLimit': 2147483647},
#   {'name': 'MX',
#    'tradingVenues': ['MX'],
#    'defaultTradingVenue': 'AUTO',
#    'primaryOrderRoutes': ['AUTO'],
#    'secondaryOrderRoutes': [],
#    'level1Feeds': ['MX'],
#    'level2Feeds': ['MX'],
#    'extendedStartTime': '2025-04-04T07:00:00.000000-04:00',
#    'startTime': '2025-04-04T09:30:00.000000-04:00',
#    'endTime': '2025-04-04T16:00:00.000000-04:00',
#    'extendedEndTime': '2025-04-04T20:00:00.000000-04:00',
#    'snapQuotesLimit': 2147483647},
#   {'name': 'CNSX',
#    'tradingVenues': ['ALPH', 'CXC', 'OMGA', 'CNSX', 'ATS'],
#    'defaultTradingVenue': 'AUTO',
#    'primaryOrderRoutes': ['AUTO'],
#    'secondaryOrderRoutes': ['AUTO', 'CX2', 'AQN', 'AQL', 'CXC', 'OME', 'OM2'],
#    'level1Feeds': ['TSX'],
#    'level2Feeds': ['ALPH', 'CNSX', 'CXC', 'OMGA'],
#    'extendedStartTime': '2025-04-04T07:00:00.000000-04:00',
#    'startTime': '2025-04-04T09:30:00.000000-04:00',
#    'endTime': '2025-04-04T16:00:00.000000-04:00',
#    'extendedEndTime': '2025-04-04T20:00:00.000000-04:00',
#    'snapQuotesLimit': 2147483647},
#   {'name': 'NASDAQ',
#    'tradingVenues': ['NASDAQ',
#     'NYSE',
#     'NYSEAM',
#     'CHX',
#     'PHLX',
#     'ARCA',
#     'BATS',
#     'BSE',
#     'ISE',
#     'NSE',
#     'IDC',
#     'EDGA',
#     'EDGX',
#     'BATSY',
#     'ISEG',
#     'IEX',
#     'ADF'],
#    'defaultTradingVenue': 'AUTO',
#    'primaryOrderRoutes': ['AUTO',
#     'NASDAQ',
#     'ARCA',
#     'MNGD',
#     'IEX',
#     'BATS',
#     'EDGA',
#     'EDGX'],
#    'secondaryOrderRoutes': [],
#    'level1Feeds': ['BATSY', 'BSE', 'CHX', 'IEX', 'NASDAQ', 'NSE', 'PHLX'],
#    'level2Feeds': ['ARCA', 'BATS', 'EDGA', 'EDGX', 'NASDAQ', 'NYSE', 'NYSEAM'],
#    'extendedStartTime': '2025-04-04T04:00:00.000000-04:00',
#    'startTime': '2025-04-04T09:30:00.000000-04:00',
#    'endTime': '2025-04-04T16:00:00.000000-04:00',
#    'extendedEndTime': '2025-04-04T20:00:00.000000-04:00',
#    'snapQuotesLimit': 2147483647},
#   {'name': 'NYSE',
#    'tradingVenues': ['NASDAQ',
#     'NYSE',
#     'NYSEAM',
#     'CHX',
#     'PHLX',
#     'ARCA',
#     'BATS',
#     'BSE',
#     'ISE',
#     'NSE',
#     'IDC',
#     'EDGA',
#     'EDGX',
#     'BATSY',
#     'ISEG',
#     'IEX',
#     'ADF'],
#    'defaultTradingVenue': 'AUTO',
#    'primaryOrderRoutes': ['AUTO',
#     'NYSE',
#     'ARCA',
#     'NASDAQ',
#     'MNGD',
#     'IEX',
#     'BATS',
#     'EDGA',
#     'EDGX'],
#    'secondaryOrderRoutes': [],
#    'level1Feeds': ['BATSY', 'BSE', 'CHX', 'IEX', 'NSE', 'NYSE', 'PHLX'],
#    'level2Feeds': ['ARCA', 'BATS', 'EDGA', 'EDGX', 'NASDAQ', 'NYSE', 'NYSEAM'],
#    'extendedStartTime': '2025-04-04T04:00:00.000000-04:00',
#    'startTime': '2025-04-04T09:30:00.000000-04:00',
#    'endTime': '2025-04-04T16:00:00.000000-04:00',
#    'extendedEndTime': '2025-04-04T20:00:00.000000-04:00',
#    'snapQuotesLimit': 2147483647},
#   {'name': 'NYSEAM',
#    'tradingVenues': ['NASDAQ',
#     'NYSE',
#     'NYSEAM',
#     'CHX',
#     'PHLX',
#     'ARCA',
#     'BATS',
#     'BSE',
#     'ISE',
#     'NSE',
#     'IDC',
#     'EDGA',
#     'EDGX',
#     'BATSY',
#     'ISEG',
#     'IEX',
#     'ADF'],
#    'defaultTradingVenue': 'AUTO',
#    'primaryOrderRoutes': ['AUTO',
#     'ARCA',
#     'NASDAQ',
#     'MNGD',
#     'IEX',
#     'BATS',
#     'EDGA',
#     'EDGX'],
#    'secondaryOrderRoutes': [],
#    'level1Feeds': ['BATSY', 'BSE', 'CHX', 'IEX', 'NSE', 'NYSEAM', 'PHLX'],
#    'level2Feeds': ['ARCA', 'BATS', 'EDGA', 'EDGX', 'NASDAQ', 'NYSEAM'],
#    'extendedStartTime': '2025-04-04T04:00:00.000000-04:00',
#    'startTime': '2025-04-04T09:30:00.000000-04:00',
#    'endTime': '2025-04-04T16:00:00.000000-04:00',
#    'extendedEndTime': '2025-04-04T20:00:00.000000-04:00',
#    'snapQuotesLimit': 2147483647},
#   {'name': 'ARCA',
#    'tradingVenues': ['NASDAQ',
#     'NYSE',
#     'NYSEAM',
#     'CHX',
#     'PHLX',
#     'ARCA',
#     'BATS',
#     'BSE',
#     'ISE',
#     'NSE',
#     'IDC',
#     'EDGA',
#     'EDGX',
#     'BATSY',
#     'ISEG',
#     'IEX',
#     'ADF'],
#    'defaultTradingVenue': 'AUTO',
#    'primaryOrderRoutes': ['AUTO',
#     'ARCA',
#     'NASDAQ',
#     'MNGD',
#     'BATS',
#     'EDGA',
#     'EDGX',
#     'IEX'],
#    'secondaryOrderRoutes': [],
#    'level1Feeds': ['NYSEAM'],
#    'level2Feeds': ['ARCA', 'BATS', 'EDGA', 'EDGX', 'NASDAQ', 'NYSEAM'],
#    'extendedStartTime': '2025-04-04T04:00:00.000000-04:00',
#    'startTime': '2025-04-04T09:30:00.000000-04:00',
#    'endTime': '2025-04-04T16:00:00.000000-04:00',
#    'extendedEndTime': '2025-04-04T20:00:00.000000-04:00',
#    'snapQuotesLimit': 2147483647},
#   {'name': 'BATS',
#    'tradingVenues': ['NASDAQ',
#     'NYSE',
#     'NYSEAM',
#     'CHX',
#     'PHLX',
#     'ARCA',
#     'BATS',
#     'BSE',
#     'ISE',
#     'NSE',
#     'IDC',
#     'EDGA',
#     'EDGX',
#     'BATSY',
#     'ISEG',
#     'IEX',
#     'ADF'],
#    'defaultTradingVenue': 'AUTO',
#    'primaryOrderRoutes': ['IEX',
#     'NASDAQ',
#     'ARCA',
#     'BATS',
#     'MNGD',
#     'AUTO',
#     'EDGA',
#     'EDGX'],
#    'secondaryOrderRoutes': [],
#    'level1Feeds': ['NYSEAM'],
#    'level2Feeds': ['ARCA', 'BATS', 'EDGA', 'EDGX', 'NASDAQ', 'NYSEAM'],
#    'extendedStartTime': '2025-04-04T04:00:00.000000-04:00',
#    'startTime': '2025-04-04T09:30:00.000000-04:00',
#    'endTime': '2025-04-04T16:00:00.000000-04:00',
#    'extendedEndTime': '2025-04-04T20:00:00.000000-04:00',
#    'snapQuotesLimit': 99999},
#   {'name': 'OPRA',
#    'tradingVenues': ['NASDAQ',
#     'NYSE',
#     'NYSEAM',
#     'AMXO',
#     'CHX',
#     'PHLX',
#     'XPHO',
#     'ARCA',
#     'ARCO',
#     'BATS',
#     'XBOX',
#     'BSE',
#     'XNDQ',
#     'XCBO',
#     'ISE',
#     'OPRA',
#     'NSE',
#     'IDC',
#     'EDGA',
#     'EDGX',
#     'C2OX',
#     'BATO',
#     'XBXO',
#     'MIAXO',
#     'MPRL',
#     'EDGO',
#     'MCRY',
#     'GMNI',
#     'MEMR'],
#    'defaultTradingVenue': 'AUTO',
#    'primaryOrderRoutes': ['AUTO', 'MNGD'],
#    'secondaryOrderRoutes': [],
#    'level1Feeds': ['AMXO',
#     'ARCO',
#     'BATO',
#     'C2OX',
#     'EDGO',
#     'GMNI',
#     'ISE',
#     'MCRY',
#     'MEMR',
#     'MIAXO',
#     'MPRL',
#     'OPRA',
#     'XBOX',
#     'XBXO',
#     'XCBO',
#     'XNDQ',
#     'XPHO'],
#    'level2Feeds': [],
#    'extendedStartTime': '2025-04-04T07:00:00.000000-04:00',
#    'startTime': '2025-04-04T09:30:00.000000-04:00',
#    'endTime': '2025-04-04T16:00:00.000000-04:00',
#    'extendedEndTime': '2025-04-04T20:00:00.000000-04:00',
#    'snapQuotesLimit': 2147483647},
#   {'name': 'PINX',
#    'tradingVenues': ['PINX'],
#    'defaultTradingVenue': 'AUTO',
#    'primaryOrderRoutes': ['AUTO', 'MNGD', 'IEX'],
#    'secondaryOrderRoutes': [],
#    'level1Feeds': ['PINX'],
#    'level2Feeds': ['PINX'],
#    'extendedStartTime': '2025-04-04T04:00:00.000000-04:00',
#    'startTime': '2025-04-04T09:30:00.000000-04:00',
#    'endTime': '2025-04-04T16:00:00.000000-04:00',
#    'extendedEndTime': '2025-04-04T20:00:00.000000-04:00',
#    'snapQuotesLimit': 2147483647},
#   {'name': 'OTCBB',
#    'tradingVenues': ['NASDAQ', 'NYSE', 'ARCA', 'PINX', 'OTCBB'],
#    'defaultTradingVenue': 'AUTO',
#    'primaryOrderRoutes': ['AUTO', 'MNGD'],
#    'secondaryOrderRoutes': [],
#    'level1Feeds': ['PINX'],
#    'level2Feeds': ['PINX'],
#    'extendedStartTime': '2025-04-04T04:00:00.000000-04:00',
#    'startTime': '2025-04-04T09:30:00.000000-04:00',
#    'endTime': '2025-04-04T16:00:00.000000-04:00',
#    'extendedEndTime': '2025-04-04T20:00:00.000000-04:00',
#    'snapQuotesLimit': 2147483647},
#   {'name': 'NEO',
#    'tradingVenues': ['ALPH', 'CXC', 'OMGA', 'ATS', 'NEOL', 'NEO'],
#    'defaultTradingVenue': 'AUTO',
#    'primaryOrderRoutes': ['AUTO'],
#    'secondaryOrderRoutes': ['TSX',
#     'AUTO',
#     'CX2',
#     'AQN',
#     'AQL',
#     'CXC',
#     'OME',
#     'OM2',
#     'CXD'],
#    'level1Feeds': ['TSX'],
#    'level2Feeds': ['ALPH', 'CXC', 'NEO', 'NEOL', 'OMGA'],
#    'extendedStartTime': '2025-04-04T07:00:00.000000-04:00',
#    'startTime': '2025-04-04T09:30:00.000000-04:00',
#    'endTime': '2025-04-04T16:00:00.000000-04:00',
#    'extendedEndTime': '2025-04-04T20:00:00.000000-04:00',
#    'snapQuotesLimit': 99999}]}

# %%
symbols = qt.search_symbols("AAPL")
symbols
# Out:
# {'symbols': [{'symbol': 'AAPL',
#    'symbolId': 8049,
#    'description': 'APPLE INC',
#    'securityType': 'Stock',
#    'listingExchange': 'NASDAQ',
#    'isTradable': True,
#    'isQuotable': True,
#    'currency': 'USD'},
#   {'symbol': 'AAPL.TO',
#    'symbolId': 39472334,
#    'description': 'APPLE INC',
#    'securityType': 'Stock',
#    'listingExchange': 'TSX',
#    'isTradable': True,
#    'isQuotable': True,
#    'currency': 'CAD'},
#   {'symbol': 'AVSPY.IN',
#    'symbolId': 28301,
#    'description': 'AAPL Alpha Index',
#    'securityType': 'Index',
#    'listingExchange': 'NASDAQI',
#    'isTradable': False,
#    'isQuotable': True,
#    'currency': 'USD'},
#   {'symbol': 'AAPW',
#    'symbolId': 59883807,
#    'description': 'ROUNDHILL AAPL WEEKLYPAY ETF',
#    'securityType': 'Stock',
#    'listingExchange': 'BATS',
#    'isTradable': True,
#    'isQuotable': True,
#    'currency': 'USD'},
#   {'symbol': 'AAPL.TO',
#    'symbolId': 37727146,
#    'description': 'APPLE INC CDR (CAD HEDGED) DEPOSITARY RECEIPTS REG S',
#    'securityType': 'Stock',
#    'listingExchange': 'NEO',
#    'isTradable': False,
#    'isQuotable': False,
#    'currency': 'CAD'},
#   {'symbol': 'NY2LAAPL.IN',
#    'symbolId': 19786673,
#    'description': 'ICE Leveraged 2x AAPL Index',
#    'securityType': 'Index',
#    'listingExchange': 'NYSEGIF',
#    'isTradable': False,
#    'isQuotable': True,
#    'currency': 'USD'},
#   {'symbol': 'APLY',
#    'symbolId': 47195488,
#    'description': 'TIDAL TRUST II YIELDMAX AAPL OPTION INCOME STRATEGY ETF',
#    'securityType': 'Stock',
#    'listingExchange': 'ARCA',
#    'isTradable': True,
#    'isQuotable': True,
#    'currency': 'USD'},
#   {'symbol': 'AAPB',
#    'symbolId': 43621933,
#    'description': 'GRANITESHARES ETF TRUST 2X LONG AAPL DAILY ETF',
#    'securityType': 'Stock',
#    'listingExchange': 'NASDAQ',
#    'isTradable': True,
#    'isQuotable': True,
#    'currency': 'USD'},
#   {'symbol': 'AAPD',
#    'symbolId': 43621934,
#    'description': 'DIREXION SHARES ETF TRUST DAILY AAPL BEAR 1X SHS',
#    'securityType': 'Stock',
#    'listingExchange': 'NASDAQ',
#    'isTradable': True,
#    'isQuotable': True,
#    'currency': 'USD'},
#   {'symbol': 'AAPU',
#    'symbolId': 43621935,
#    'description': 'DIREXION SHARES ETF TRUST DAILY AAPL BULL 2X SHARES',
#    'securityType': 'Stock',
#    'listingExchange': 'NASDAQ',
#    'isTradable': True,
#    'isQuotable': True,
#    'currency': 'USD'},
#   {'symbol': 'AAPY',
#    'symbolId': 51092636,
#    'description': 'NEOS ETF TRUST KURV YIELD PREMIUM STRATEGY APPLE AAPL ETF',
#    'securityType': 'Stock',
#    'listingExchange': 'BATS',
#    'isTradable': False,
#    'isQuotable': False,
#    'currency': 'USD'},
#   {'symbol': 'J008303.90',
#    'symbolId': 943205,
#    'description': 'WTS JPMORGAN CHASE BANK N A WTS REG S ON SHS AAPLE INC',
#    'securityType': 'Right',
#    'listingExchange': '',
#    'isTradable': False,
#    'isQuotable': False,
#    'currency': 'USD'}]}

# %%
symbol_details = qt.get_symbol_details(symbol_id=symbols['symbols'][0]['symbolId'])
symbol_details

# Get details for multiple symbols at once
symbol_ids = [symbols['symbols'][0]['symbolId'], symbols['symbols'][1]['symbolId']]
multiple_symbols = qt.get_symbol_details(symbol_ids=symbol_ids)
multiple_symbols
# Out:
# {'symbols': [{'symbol': 'AAPL',
#    'symbolId': 8049,
#    'prevDayClosePrice': 203.19,
#    'highPrice52': 260.1,
#    'lowPrice52': 164.075,
#    'averageVol3Months': 53187951,
#    'averageVol20Days': 54883180,
#    'outstandingShares': 15022070000,
#    'eps': 6.3,
#    'pe': 35.5381,
#    'dividend': 0.25,
#    'yield': 0.44665,
#    'exDate': '2025-02-10T00:00:00.000000-05:00',
#    'marketCap': 3363291924000,
#    'tradeUnit': 1,
#    'optionType': None,
#    'optionDurationType': None,
#    'optionRoot': '',
#    'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#    'optionExerciseType': None,
#    'listingExchange': 'NASDAQ',
#    'description': 'APPLE INC',
#    'securityType': 'Stock',
#    'optionExpiryDate': None,
#    'dividendDate': '2025-02-13T00:00:00.000000-05:00',
#    'optionStrikePrice': None,
#    'isTradable': True,
#    'isQuotable': True,
#    'hasOptions': True,
#    'currency': 'USD',
#    'minTicks': [{'pivot': 0, 'minTick': 0.0001},
#     {'pivot': 1, 'minTick': 0.01}],
#    'industrySector': 'Technology',
#    'industryGroup': 'Undefined',
#    'industrySubgroup': 'Undefined'},
#   {'symbol': 'AAPL.TO',
#    'symbolId': 39472334,
#    'prevDayClosePrice': 29.66,
#    'highPrice52': 36.4,
#    'lowPrice52': 29.32,
#    'averageVol3Months': 119727,
#    'averageVol20Days': 103364,
#    'outstandingShares': 15022073000,
#    'eps': None,
#    'pe': 250.38462,
#    'dividend': 0.036345,
#    'yield': 0.44902,
#    'exDate': '2025-02-10T00:00:00.000000-05:00',
#    'marketCap': 488968476200,
#    'tradeUnit': 1,
#    'optionType': None,
#    'optionDurationType': None,
#    'optionRoot': '',
#    'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#    'optionExerciseType': None,
#    'listingExchange': 'TSX',
#    'description': 'APPLE INC',
#    'securityType': 'Stock',
#    'optionExpiryDate': None,
#    'dividendDate': '2025-02-21T00:00:00.000000-05:00',
#    'optionStrikePrice': None,
#    'isTradable': True,
#    'isQuotable': True,
#    'hasOptions': True,
#    'currency': 'CAD',
#    'minTicks': [{'pivot': 0, 'minTick': 0.005},
#     {'pivot': 0.5, 'minTick': 0.01}],
#    'industrySector': 'Technology',
#    'industryGroup': 'Undefined',
#    'industrySubgroup': 'Undefined'}]}

# %%
candles = qt.get_candles(symbol_id=symbols['symbols'][0]['symbolId'], start_time=start_time, end_time=end_time, interval="OneMinute")
candles
# Out:
# {'candles': [{'start': '2025-03-05T05:00:00.000000-05:00',
#    'end': '2025-03-05T05:01:00.000000-05:00',
#    'low': 237.58,
#    'high': 237.58,
#    'open': 237.58,
#    'close': 237.58,
#    'volume': 100,
#    'VWAP': 237.580486},
#   {'start': '2025-03-05T05:03:00.000000-05:00',
#    'end': '2025-03-05T05:04:00.000000-05:00',
#    'low': 237.22,
#    'high': 237.55,
#    'open': 237.55,
#    'close': 237.22,
#    'volume': 716,
#    'VWAP': 237.429915},
#   {'start': '2025-03-05T05:04:00.000000-05:00',
#    'end': '2025-03-05T05:05:00.000000-05:00',
#    'low': 237.33,
#    'high': 237.33,
#    'open': 237.33,
#    'close': 237.33,
#    'volume': 106,
#    'VWAP': 237.397259},
#   {'start': '2025-03-05T05:09:00.000000-05:00',
#    'end': '2025-03-05T05:10:00.000000-05:00',
#    'low': 237.47,
#    'high': 237.5,
#    'open': 237.47,
#    'close': 237.5,
#    'volume': 657,
#    'VWAP': 237.420648},
#   {'start': '2025-03-05T05:12:00.000000-05:00',
#    'end': '2025-03-05T05:13:00.000000-05:00',
#    'low': 237.29,
#    'high': 237.29,
#    'open': 237.29,
#    'close': 237.29,
#    'volume': 250,
#    'VWAP': 237.404745},
#   {'start': '2025-03-05T05:13:00.000000-05:00',
#    'end': '2025-03-05T05:14:00.000000-05:00',
#    'low': 237.21,
#    'high': 237.26,
#    'open': 237.26,
#    'close': 237.21,
#    'volume': 1194,
#    'VWAP': 237.348821},
#   {'start': '2025-03-05T05:14:00.000000-05:00',
#    'end': '2025-03-05T05:15:00.000000-05:00',
#    'low': 237.16,
#    'high': 237.24,
#    'open': 237.24,
#    'close': 237.16,
#    'volume': 750,
#    'VWAP': 237.316991},
#   {'start': '2025-03-05T05:15:00.000000-05:00',
#    'end': '2025-03-05T05:16:00.000000-05:00',
#    'low': 237.12,
#    'high': 237.12,
#    'open': 237.12,
#    'close': 237.12,
#    'volume': 369,
#    'VWAP': 237.303867},
#   {'start': '2025-03-05T05:17:00.000000-05:00',
#    'end': '2025-03-05T05:18:00.000000-05:00',
#    'low': 237,
#    'high': 237,
#    'open': 237,
#    'close': 237,
#    'volume': 100,
#    'VWAP': 237.269787},
#   {'start': '2025-03-05T05:19:00.000000-05:00',
#    'end': '2025-03-05T05:20:00.000000-05:00',
#    'low': 236.93,
#    'high': 237,
#    'open': 237,
#    'close': 236.93,
#    'volume': 512,
#    'VWAP': 237.248012},
#   {'start': '2025-03-05T05:25:00.000000-05:00',
#    'end': '2025-03-05T05:26:00.000000-05:00',
#    'low': 237.05,
#    'high': 237.05,
#    'open': 237.05,
#    'close': 237.05,
#    'volume': 100,
#    'VWAP': 237.212059},
#   {'start': '2025-03-05T05:26:00.000000-05:00',
#    'end': '2025-03-05T05:27:00.000000-05:00',
#    'low': 237.08,
#    'high': 237.08,
#    'open': 237.08,
#    'close': 237.08,
#    'volume': 170,
#    'VWAP': 237.208317},
#   {'start': '2025-03-05T05:27:00.000000-05:00',
#    'end': '2025-03-05T05:28:00.000000-05:00',
#    'low': 237.02,
#    'high': 237.1,
#    'open': 237.1,
#    'close': 237.02,
#    'volume': 200,
#    'VWAP': 237.205011},
#   {'start': '2025-03-05T05:29:00.000000-05:00',
#    'end': '2025-03-05T05:30:00.000000-05:00',
#    'low': 237,
#    'high': 237,
#    'open': 237,
#    'close': 237,
#    'volume': 100,
#    'VWAP': 237.196743},
#   {'start': '2025-03-05T05:30:00.000000-05:00',
#    'end': '2025-03-05T05:31:00.000000-05:00',
#    'low': 237.05,
#    'high': 237.05,
#    'open': 237.05,
#    'close': 237.05,
#    'volume': 100,
#    'VWAP': 237.194094},
#   {'start': '2025-03-05T05:35:00.000000-05:00',
#    'end': '2025-03-05T05:36:00.000000-05:00',
#    'low': 237.16,
#    'high': 237.16,
#    'open': 237.16,
#    'close': 237.16,
#    'volume': 150,
#    'VWAP': 237.191562},
#   {'start': '2025-03-05T05:39:00.000000-05:00',
#    'end': '2025-03-05T05:40:00.000000-05:00',
#    'low': 237.16,
#    'high': 237.16,
#    'open': 237.16,
#    'close': 237.16,
#    'volume': 100,
#    'VWAP': 237.190125},
#   {'start': '2025-03-05T05:40:00.000000-05:00',
#    'end': '2025-03-05T05:41:00.000000-05:00',
#    'low': 237.13,
#    'high': 237.13,
#    'open': 237.13,
#    'close': 237.13,
#    'volume': 100,
#    'VWAP': 237.18976},
#   {'start': '2025-03-05T05:43:00.000000-05:00',
#    'end': '2025-03-05T05:44:00.000000-05:00',
#    'low': 237.22,
#    'high': 237.22,
#    'open': 237.22,
#    'close': 237.22,
#    'volume': 200,
#    'VWAP': 237.1908},
#   {'start': '2025-03-05T05:56:00.000000-05:00',
#    'end': '2025-03-05T05:57:00.000000-05:00',
#    'low': 237.01,
#    'high': 237.02,
#    'open': 237.02,
#    'close': 237.01,
#    'volume': 295,
#    'VWAP': 237.182213},
#   {'start': '2025-03-05T05:57:00.000000-05:00',
#    'end': '2025-03-05T05:58:00.000000-05:00',
#    'low': 236.95,
#    'high': 236.95,
#    'open': 236.95,
#    'close': 236.95,
#    'volume': 233,
#    'VWAP': 237.172991},
#   {'start': '2025-03-05T06:01:00.000000-05:00',
#    'end': '2025-03-05T06:02:00.000000-05:00',
#    'low': 236.96,
#    'high': 236.96,
#    'open': 236.96,
#    'close': 236.96,
#    'volume': 100,
#    'VWAP': 237.166905},
#   {'start': '2025-03-05T06:02:00.000000-05:00',
#    'end': '2025-03-05T06:03:00.000000-05:00',
#    'low': 236.98,
#    'high': 236.98,
#    'open': 236.98,
#    'close': 236.98,
#    'volume': 179,
#    'VWAP': 237.164654},
#   {'start': '2025-03-05T06:05:00.000000-05:00',
#    'end': '2025-03-05T06:06:00.000000-05:00',
#    'low': 236.89,
#    'high': 236.89,
#    'open': 236.89,
#    'close': 236.89,
#    'volume': 189,
#    'VWAP': 237.158852},
#   {'start': '2025-03-05T06:10:00.000000-05:00',
#    'end': '2025-03-05T06:11:00.000000-05:00',
#    'low': 236.79,
#    'high': 236.85,
#    'open': 236.79,
#    'close': 236.85,
#    'volume': 224,
#    'VWAP': 237.144912},
#   {'start': '2025-03-05T06:18:00.000000-05:00',
#    'end': '2025-03-05T06:19:00.000000-05:00',
#    'low': 236.77,
#    'high': 236.77,
#    'open': 236.77,
#    'close': 236.77,
#    'volume': 140,
#    'VWAP': 237.133594},
#   {'start': '2025-03-05T06:24:00.000000-05:00',
#    'end': '2025-03-05T06:25:00.000000-05:00',
#    'low': 236.8,
#    'high': 236.8,
#    'open': 236.8,
#    'close': 236.8,
#    'volume': 100,
#    'VWAP': 237.119838},
#   {'start': '2025-03-05T06:39:00.000000-05:00',
#    'end': '2025-03-05T06:40:00.000000-05:00',
#    'low': 236.85,
#    'high': 236.85,
#    'open': 236.85,
#    'close': 236.85,
#    'volume': 200,
#    'VWAP': 237.109635},
#   {'start': '2025-03-05T06:48:00.000000-05:00',
#    'end': '2025-03-05T06:49:00.000000-05:00',
#    'low': 236.99,
#    'high': 236.99,
#    'open': 236.99,
#    'close': 236.99,
#    'volume': 200,
#    'VWAP': 237.100652},
#   {'start': '2025-03-05T06:51:00.000000-05:00',
#    'end': '2025-03-05T06:52:00.000000-05:00',
#    'low': 237.03,
#    'high': 237.03,
#    'open': 237.03,
#    'close': 237.03,
#    'volume': 107,
#    'VWAP': 237.099501},
#   {'start': '2025-03-05T06:52:00.000000-05:00',
#    'end': '2025-03-05T06:53:00.000000-05:00',
#    'low': 237.01,
#    'high': 237.05,
#    'open': 237.01,
#    'close': 237.01,
#    'volume': 954,
#    'VWAP': 237.0962},
#   {'start': '2025-03-05T06:53:00.000000-05:00',
#    'end': '2025-03-05T06:54:00.000000-05:00',
#    'low': 236.99,
#    'high': 237.01,
#    'open': 237.01,
#    'close': 236.99,
#    'volume': 843,
#    'VWAP': 237.071496},
#   {'start': '2025-03-05T06:54:00.000000-05:00',
#    'end': '2025-03-05T06:55:00.000000-05:00',
#    'low': 236.19,
#    'high': 236.5,
#    'open': 236.5,
#    'close': 236.23,
#    'volume': 2048,
#    'VWAP': 236.982936},
#   {'start': '2025-03-05T06:55:00.000000-05:00',
#    'end': '2025-03-05T06:56:00.000000-05:00',
#    'low': 236.53,
#    'high': 236.59,
#    'open': 236.53,
#    'close': 236.59,
#    'volume': 915,
#    'VWAP': 236.966779},
#   {'start': '2025-03-05T06:56:00.000000-05:00',
#    'end': '2025-03-05T06:57:00.000000-05:00',
#    'low': 236.52,
#    'high': 236.53,
#    'open': 236.52,
#    'close': 236.52,
#    'volume': 400,
#    'VWAP': 236.954302},
#   {'start': '2025-03-05T06:58:00.000000-05:00',
#    'end': '2025-03-05T06:59:00.000000-05:00',
#    'low': 236.55,
#    'high': 236.59,
#    'open': 236.55,
#    'close': 236.59,
#    'volume': 200,
#    'VWAP': 236.948238},
#   {'start': '2025-03-05T07:00:00.000000-05:00',
#    'end': '2025-03-05T07:01:00.000000-05:00',
#    'low': 236.72,
#    'high': 236.93,
#    'open': 236.72,
#    'close': 236.92,
#    'volume': 688,
#    'VWAP': 236.94055},
#   {'start': '2025-03-05T07:02:00.000000-05:00',
#    'end': '2025-03-05T07:03:00.000000-05:00',
#    'low': 236.86,
#    'high': 236.86,
#    'open': 236.86,
#    'close': 236.86,
#    'volume': 349,
#    'VWAP': 236.938784},
#   {'start': '2025-03-05T07:04:00.000000-05:00',
#    'end': '2025-03-05T07:05:00.000000-05:00',
#    'low': 236.85,
#    'high': 236.85,
#    'open': 236.85,
#    'close': 236.85,
#    'volume': 140,
#    'VWAP': 236.937434},
#   {'start': '2025-03-05T07:06:00.000000-05:00',
#    'end': '2025-03-05T07:07:00.000000-05:00',
#    'low': 236.7,
#    'high': 236.75,
#    'open': 236.7,
#    'close': 236.75,
#    'volume': 350,
#    'VWAP': 236.932175},
#   {'start': '2025-03-05T07:13:00.000000-05:00',
#    'end': '2025-03-05T07:14:00.000000-05:00',
#    'low': 236.85,
#    'high': 236.85,
#    'open': 236.85,
#    'close': 236.85,
#    'volume': 122,
#    'VWAP': 236.931063},
#   {'start': '2025-03-05T07:18:00.000000-05:00',
#    'end': '2025-03-05T07:19:00.000000-05:00',
#    'low': 236.63,
#    'high': 236.63,
#    'open': 236.63,
#    'close': 236.63,
#    'volume': 200,
#    'VWAP': 236.923716},
#   {'start': '2025-03-05T07:19:00.000000-05:00',
#    'end': '2025-03-05T07:20:00.000000-05:00',
#    'low': 236.64,
#    'high': 236.64,
#    'open': 236.64,
#    'close': 236.64,
#    'volume': 104,
#    'VWAP': 236.92217},
#   {'start': '2025-03-05T07:21:00.000000-05:00',
#    'end': '2025-03-05T07:22:00.000000-05:00',
#    'low': 236.32,
#    'high': 236.5,
#    'open': 236.5,
#    'close': 236.32,
#    'volume': 216,
#    'VWAP': 236.91016},
#   {'start': '2025-03-05T07:22:00.000000-05:00',
#    'end': '2025-03-05T07:23:00.000000-05:00',
#    'low': 236.43,
#    'high': 236.43,
#    'open': 236.43,
#    'close': 236.43,
#    'volume': 170,
#    'VWAP': 236.907432},
#   {'start': '2025-03-05T07:23:00.000000-05:00',
#    'end': '2025-03-05T07:24:00.000000-05:00',
#    'low': 236.43,
#    'high': 236.43,
#    'open': 236.43,
#    'close': 236.43,
#    'volume': 100,
#    'VWAP': 236.899865},
#   {'start': '2025-03-05T07:25:00.000000-05:00',
#    'end': '2025-03-05T07:26:00.000000-05:00',
#    'low': 236.64,
#    'high': 236.7,
#    'open': 236.64,
#    'close': 236.7,
#    'volume': 400,
#    'VWAP': 236.89366},
#   {'start': '2025-03-05T07:31:00.000000-05:00',
#    'end': '2025-03-05T07:32:00.000000-05:00',
#    'low': 236.84,
#    'high': 236.84,
#    'open': 236.84,
#    'close': 236.84,
#    'volume': 100,
#    'VWAP': 236.892393},
#   {'start': '2025-03-05T07:39:00.000000-05:00',
#    'end': '2025-03-05T07:40:00.000000-05:00',
#    'low': 236.82,
#    'high': 236.82,
#    'open': 236.82,
#    'close': 236.82,
#    'volume': 300,
#    'VWAP': 236.890057},
#   {'start': '2025-03-05T07:41:00.000000-05:00',
#    'end': '2025-03-05T07:42:00.000000-05:00',
#    'low': 236.71,
#    'high': 236.74,
#    'open': 236.71,
#    'close': 236.73,
#    'volume': 411,
#    'VWAP': 236.880552},
#   {'start': '2025-03-05T07:44:00.000000-05:00',
#    'end': '2025-03-05T07:45:00.000000-05:00',
#    'low': 236.76,
#    'high': 236.76,
#    'open': 236.76,
#    'close': 236.76,
#    'volume': 194,
#    'VWAP': 236.879468},
#   {'start': '2025-03-05T07:48:00.000000-05:00',
#    'end': '2025-03-05T07:49:00.000000-05:00',
#    'low': 236.5,
#    'high': 236.5,
#    'open': 236.5,
#    'close': 236.5,
#    'volume': 413,
#    'VWAP': 236.872003},
#   {'start': '2025-03-05T07:58:00.000000-05:00',
#    'end': '2025-03-05T07:59:00.000000-05:00',
#    'low': 236.45,
#    'high': 236.45,
#    'open': 236.45,
#    'close': 236.45,
#    'volume': 105,
#    'VWAP': 236.863233},
#   {'start': '2025-03-05T08:00:00.000000-05:00',
#    'end': '2025-03-05T08:01:00.000000-05:00',
#    'low': 236.4,
#    'high': 237.72,
#    'open': 236.75,
#    'close': 236.9,
#    'volume': 38072,
#    'VWAP': 236.903634},
#   {'start': '2025-03-05T08:01:00.000000-05:00',
#    'end': '2025-03-05T08:02:00.000000-05:00',
#    'low': 236.42,
#    'high': 236.42,
#    'open': 236.42,
#    'close': 236.42,
#    'volume': 250,
#    'VWAP': 236.907781},
#   {'start': '2025-03-05T08:03:00.000000-05:00',
#    'end': '2025-03-05T08:04:00.000000-05:00',
#    'low': 236.37,
#    'high': 236.4,
#    'open': 236.4,
#    'close': 236.37,
#    'volume': 258,
#    'VWAP': 236.89875},
#   {'start': '2025-03-05T08:04:00.000000-05:00',
#    'end': '2025-03-05T08:05:00.000000-05:00',
#    'low': 236.67,
#    'high': 236.76,
#    'open': 236.67,
#    'close': 236.76,
#    'volume': 750,
#    'VWAP': 236.895358},
#   {'start': '2025-03-05T08:05:00.000000-05:00',
#    'end': '2025-03-05T08:06:00.000000-05:00',
#    'low': 236.7599,
#    'high': 236.7599,
#    'open': 236.7599,
#    'close': 236.7599,
#    'volume': 100,
#    'VWAP': 236.894752},
#   {'start': '2025-03-05T08:09:00.000000-05:00',
#    'end': '2025-03-05T08:10:00.000000-05:00',
#    'low': 236.71,
#    'high': 236.71,
#    'open': 236.71,
#    'close': 236.71,
#    'volume': 207,
#    'VWAP': 236.827709},
#   {'start': '2025-03-05T08:10:00.000000-05:00',
#    'end': '2025-03-05T08:11:00.000000-05:00',
#    'low': 236.71,
#    'high': 236.8595,
#    'open': 236.71,
#    'close': 236.75,
#    'volume': 1350,
#    'VWAP': 236.827266},
#   {'start': '2025-03-05T08:12:00.000000-05:00',
#    'end': '2025-03-05T08:13:00.000000-05:00',
#    'low': 236.8,
#    'high': 236.8,
#    'open': 236.8,
#    'close': 236.8,
#    'volume': 205,
#    'VWAP': 236.827189},
#   {'start': '2025-03-05T08:13:00.000000-05:00',
#    'end': '2025-03-05T08:14:00.000000-05:00',
#    'low': 236.88,
#    'high': 236.88,
#    'open': 236.88,
#    'close': 236.88,
#    'volume': 4330,
#    'VWAP': 236.828884},
#   {'start': '2025-03-05T08:14:00.000000-05:00',
#    'end': '2025-03-05T08:15:00.000000-05:00',
#    'low': 236.88,
#    'high': 236.88,
#    'open': 236.88,
#    'close': 236.88,
#    'volume': 100,
#    'VWAP': 236.82892},
#   {'start': '2025-03-05T08:15:00.000000-05:00',
#    'end': '2025-03-05T08:16:00.000000-05:00',
#    'low': 236.25,
#    'high': 236.5999,
#    'open': 236.25,
#    'close': 236.5999,
#    'volume': 1073,
#    'VWAP': 236.821794},
#   {'start': '2025-03-05T08:16:00.000000-05:00',
#    'end': '2025-03-05T08:17:00.000000-05:00',
#    'low': 236.3706,
#    'high': 236.44,
#    'open': 236.3706,
#    'close': 236.43,
#    'volume': 1598,
#    'VWAP': 236.815759},
#   {'start': '2025-03-05T08:19:00.000000-05:00',
#    'end': '2025-03-05T08:20:00.000000-05:00',
#    'low': 236.1486,
#    'high': 236.41,
#    'open': 236.4,
#    'close': 236.1486,
#    'volume': 440,
#    'VWAP': 236.802602},
#   {'start': '2025-03-05T08:20:00.000000-05:00',
#    'end': '2025-03-05T08:21:00.000000-05:00',
#    'low': 236.32,
#    'high': 236.32,
#    'open': 236.32,
#    'close': 236.32,
#    'volume': 100,
#    'VWAP': 236.801573},
#   {'start': '2025-03-05T08:22:00.000000-05:00',
#    'end': '2025-03-05T08:23:00.000000-05:00',
#    'low': 236.5,
#    'high': 236.5,
#    'open': 236.5,
#    'close': 236.5,
#    'volume': 100,
#    'VWAP': 236.801031},
#   {'start': '2025-03-05T08:23:00.000000-05:00',
#    'end': '2025-03-05T08:24:00.000000-05:00',
#    'low': 236.54,
#    'high': 236.54,
#    'open': 236.54,
#    'close': 236.54,
#    'volume': 100,
#    'VWAP': 236.800366},
#   {'start': '2025-03-05T08:24:00.000000-05:00',
#    'end': '2025-03-05T08:25:00.000000-05:00',
#    'low': 236.61,
#    'high': 236.69,
#    'open': 236.69,
#    'close': 236.62,
#    'volume': 1300,
#    'VWAP': 236.798189},
#   {'start': '2025-03-05T08:25:00.000000-05:00',
#    'end': '2025-03-05T08:26:00.000000-05:00',
#    'low': 235.93,
#    'high': 236.62,
#    'open': 235.93,
#    'close': 236.61,
#    'volume': 6626,
#    'VWAP': 236.774408},
#   {'start': '2025-03-05T08:26:00.000000-05:00',
#    'end': '2025-03-05T08:27:00.000000-05:00',
#    'low': 236.65,
#    'high': 236.65,
#    'open': 236.65,
#    'close': 236.65,
#    'volume': 300,
#    'VWAP': 236.77394},
#   {'start': '2025-03-05T08:27:00.000000-05:00',
#    'end': '2025-03-05T08:28:00.000000-05:00',
#    'low': 236.6099,
#    'high': 236.6099,
#    'open': 236.6099,
#    'close': 236.6099,
#    'volume': 300,
#    'VWAP': 236.773343},
#   {'start': '2025-03-05T08:28:00.000000-05:00',
#    'end': '2025-03-05T08:29:00.000000-05:00',
#    'low': 236.23,
#    'high': 236.51,
#    'open': 236.5,
#    'close': 236.23,
#    'volume': 1561,
#    'VWAP': 236.764426},
#   {'start': '2025-03-05T08:29:00.000000-05:00',
#    'end': '2025-03-05T08:30:00.000000-05:00',
#    'low': 236.2206,
#    'high': 236.38,
#    'open': 236.2286,
#    'close': 236.35,
#    'volume': 1009,
#    'VWAP': 236.755194},
#   {'start': '2025-03-05T08:30:00.000000-05:00',
#    'end': '2025-03-05T08:31:00.000000-05:00',
#    'low': 236.52,
#    'high': 236.52,
#    'open': 236.52,
#    'close': 236.52,
#    'volume': 100,
#    'VWAP': 236.754522},
#   {'start': '2025-03-05T08:31:00.000000-05:00',
#    'end': '2025-03-05T08:32:00.000000-05:00',
#    'low': 236.62,
#    'high': 236.65,
#    'open': 236.62,
#    'close': 236.65,
#    'volume': 202,
#    'VWAP': 236.753114},
#   {'start': '2025-03-05T08:32:00.000000-05:00',
#    'end': '2025-03-05T08:33:00.000000-05:00',
#    'low': 236.71,
#    'high': 236.75,
#    'open': 236.75,
#    'close': 236.71,
#    'volume': 521,
#    'VWAP': 236.237661},
#   {'start': '2025-03-05T08:33:00.000000-05:00',
#    'end': '2025-03-05T08:34:00.000000-05:00',
#    'low': 236.73,
#    'high': 236.74,
#    'open': 236.73,
#    'close': 236.74,
#    'volume': 1197,
#    'VWAP': 236.239585},
#   {'start': '2025-03-05T08:34:00.000000-05:00',
#    'end': '2025-03-05T08:35:00.000000-05:00',
#    'low': 236.67,
#    'high': 236.82,
#    'open': 236.67,
#    'close': 236.7202,
#    'volume': 705,
#    'VWAP': 236.242124},
#   {'start': '2025-03-05T08:36:00.000000-05:00',
#    'end': '2025-03-05T08:37:00.000000-05:00',
#    'low': 236.63,
#    'high': 236.74,
#    'open': 236.74,
#    'close': 236.63,
#    'volume': 607,
#    'VWAP': 236.24507},
#   {'start': '2025-03-05T08:37:00.000000-05:00',
#    'end': '2025-03-05T08:38:00.000000-05:00',
#    'low': 236.71,
#    'high': 236.79,
#    'open': 236.79,
#    'close': 236.7887,
#    'volume': 785,
#    'VWAP': 236.246725},
#   {'start': '2025-03-05T08:38:00.000000-05:00',
#    'end': '2025-03-05T08:39:00.000000-05:00',
#    'low': 236.7518,
#    'high': 236.7518,
#    'open': 236.7518,
#    'close': 236.7518,
#    'volume': 100,
#    'VWAP': 236.247397},
#   {'start': '2025-03-05T08:40:00.000000-05:00',
#    'end': '2025-03-05T08:41:00.000000-05:00',
#    'low': 236.63,
#    'high': 236.7,
#    'open': 236.63,
#    'close': 236.7,
#    'volume': 1000,
#    'VWAP': 236.248497},
#   {'start': '2025-03-05T08:43:00.000000-05:00',
#    'end': '2025-03-05T08:44:00.000000-05:00',
#    'low': 236.64,
#    'high': 236.74,
#    'open': 236.64,
#    'close': 236.64,
#    'volume': 1394,
#    'VWAP': 236.252438},
#   {'start': '2025-03-05T08:44:00.000000-05:00',
#    'end': '2025-03-05T08:45:00.000000-05:00',
#    'low': 236.61,
#    'high': 236.7367,
#    'open': 236.7367,
#    'close': 236.61,
#    'volume': 500,
#    'VWAP': 236.253078},
#   {'start': '2025-03-05T08:45:00.000000-05:00',
#    'end': '2025-03-05T08:46:00.000000-05:00',
#    'low': 236.51,
#    'high': 236.51,
#    'open': 236.51,
#    'close': 236.51,
#    'volume': 100,
#    'VWAP': 236.25333},
#   {'start': '2025-03-05T08:47:00.000000-05:00',
#    'end': '2025-03-05T08:48:00.000000-05:00',
#    'low': 236.63,
#    'high': 236.74,
#    'open': 236.74,
#    'close': 236.63,
#    'volume': 300,
#    'VWAP': 236.254038},
#   {'start': '2025-03-05T08:48:00.000000-05:00',
#    'end': '2025-03-05T08:49:00.000000-05:00',
#    'low': 236.54,
#    'high': 236.6,
#    'open': 236.54,
#    'close': 236.6,
#    'volume': 1000,
#    'VWAP': 236.254939},
#   {'start': '2025-03-05T08:49:00.000000-05:00',
#    'end': '2025-03-05T08:50:00.000000-05:00',
#    'low': 236.5322,
#    'high': 236.82,
#    'open': 236.72,
#    'close': 236.82,
#    'volume': 2450,
#    'VWAP': 236.265206},
#   {'start': '2025-03-05T08:52:00.000000-05:00',
#    'end': '2025-03-05T08:53:00.000000-05:00',
#    'low': 236.57,
#    'high': 236.66,
#    'open': 236.66,
#    'close': 236.57,
#    'volume': 1593,
#    'VWAP': 236.267137},
#   {'start': '2025-03-05T08:53:00.000000-05:00',
#    'end': '2025-03-05T08:54:00.000000-05:00',
#    'low': 236.58,
#    'high': 236.59,
#    'open': 236.58,
#    'close': 236.59,
#    'volume': 200,
#    'VWAP': 236.267728},
#   {'start': '2025-03-05T08:54:00.000000-05:00',
#    'end': '2025-03-05T08:55:00.000000-05:00',
#    'low': 236.51,
#    'high': 236.56,
#    'open': 236.51,
#    'close': 236.56,
#    'volume': 250,
#    'VWAP': 236.268394},
#   {'start': '2025-03-05T08:55:00.000000-05:00',
#    'end': '2025-03-05T08:56:00.000000-05:00',
#    'low': 236.45,
#    'high': 236.535,
#    'open': 236.535,
#    'close': 236.52,
#    'volume': 538,
#    'VWAP': 236.269439},
#   {'start': '2025-03-05T08:56:00.000000-05:00',
#    'end': '2025-03-05T08:57:00.000000-05:00',
#    'low': 236.53,
#    'high': 236.53,
#    'open': 236.53,
#    'close': 236.53,
#    'volume': 211,
#    'VWAP': 236.269874},
#   {'start': '2025-03-05T08:57:00.000000-05:00',
#    'end': '2025-03-05T08:58:00.000000-05:00',
#    'low': 236.5493,
#    'high': 236.55,
#    'open': 236.55,
#    'close': 236.5493,
#    'volume': 1168,
#    'VWAP': 236.270737},
#   {'start': '2025-03-05T08:58:00.000000-05:00',
#    'end': '2025-03-05T08:59:00.000000-05:00',
#    'low': 236.38,
#    'high': 236.5,
#    'open': 236.5,
#    'close': 236.38,
#    'volume': 811,
#    'VWAP': 236.271842},
#   {'start': '2025-03-05T08:59:00.000000-05:00',
#    'end': '2025-03-05T09:00:00.000000-05:00',
#    'low': 236.2801,
#    'high': 236.39,
#    'open': 236.39,
#    'close': 236.2801,
#    'volume': 1770,
#    'VWAP': 236.272261},
#   {'start': '2025-03-05T09:00:00.000000-05:00',
#    'end': '2025-03-05T09:01:00.000000-05:00',
#    'low': 236.29,
#    'high': 236.33,
#    'open': 236.29,
#    'close': 236.3,
#    'volume': 345,
#    'VWAP': 236.272312},
#   {'start': '2025-03-05T09:01:00.000000-05:00',
#    'end': '2025-03-05T09:02:00.000000-05:00',
#    'low': 236.33,
#    'high': 236.35,
#    'open': 236.34,
#    'close': 236.35,
#    'volume': 1450,
#    'VWAP': 236.272627},
#   {'start': '2025-03-05T09:02:00.000000-05:00',
#    'end': '2025-03-05T09:03:00.000000-05:00',
#    'low': 236.28,
#    'high': 236.39,
#    'open': 236.28,
#    'close': 236.39,
#    'volume': 428,
#    'VWAP': 236.272859},
#   {'start': '2025-03-05T09:03:00.000000-05:00',
#    'end': '2025-03-05T09:04:00.000000-05:00',
#    'low': 236.49,
#    'high': 236.49,
#    'open': 236.49,
#    'close': 236.49,
#    'volume': 200,
#    'VWAP': 236.273031},
#   {'start': '2025-03-05T09:04:00.000000-05:00',
#    'end': '2025-03-05T09:05:00.000000-05:00',
#    'low': 236.36,
#    'high': 236.37,
#    'open': 236.36,
#    'close': 236.37,
#    'volume': 700,
#    'VWAP': 236.273217},
#   {'start': '2025-03-05T09:05:00.000000-05:00',
#    'end': '2025-03-05T09:06:00.000000-05:00',
#    'low': 236.31,
#    'high': 236.33,
#    'open': 236.32,
#    'close': 236.324,
#    'volume': 400,
#    'VWAP': 236.273626},
#   {'start': '2025-03-05T09:06:00.000000-05:00',
#    'end': '2025-03-05T09:07:00.000000-05:00',
#    'low': 236.45,
#    'high': 236.45,
#    'open': 236.45,
#    'close': 236.45,
#    'volume': 600,
#    'VWAP': 236.273999},
#   {'start': '2025-03-05T09:08:00.000000-05:00',
#    'end': '2025-03-05T09:09:00.000000-05:00',
#    'low': 236.424,
#    'high': 236.5499,
#    'open': 236.4299,
#    'close': 236.5499,
#    'volume': 3340,
#    'VWAP': 236.275789},
#   {'start': '2025-03-05T09:10:00.000000-05:00',
#    'end': '2025-03-05T09:11:00.000000-05:00',
#    'low': 236.39,
#    'high': 236.39,
#    'open': 236.39,
#    'close': 236.39,
#    'volume': 250,
#    'VWAP': 236.275888},
#   {'start': '2025-03-05T09:12:00.000000-05:00',
#    'end': '2025-03-05T09:13:00.000000-05:00',
#    'low': 236.37,
#    'high': 236.4,
#    'open': 236.4,
#    'close': 236.4,
#    'volume': 807,
#    'VWAP': 236.276192},
#   {'start': '2025-03-05T09:13:00.000000-05:00',
#    'end': '2025-03-05T09:14:00.000000-05:00',
#    'low': 236.496,
#    'high': 236.496,
#    'open': 236.496,
#    'close': 236.496,
#    'volume': 200,
#    'VWAP': 236.276331},
#   {'start': '2025-03-05T09:14:00.000000-05:00',
#    'end': '2025-03-05T09:15:00.000000-05:00',
#    'low': 236.4995,
#    'high': 236.5,
#    'open': 236.5,
#    'close': 236.4995,
#    'volume': 600,
#    'VWAP': 236.277077},
#   {'start': '2025-03-05T09:15:00.000000-05:00',
#    'end': '2025-03-05T09:16:00.000000-05:00',
#    'low': 236.5,
#    'high': 236.61,
#    'open': 236.5,
#    'close': 236.61,
#    'volume': 767,
#    'VWAP': 236.278697},
#   {'start': '2025-03-05T09:16:00.000000-05:00',
#    'end': '2025-03-05T09:17:00.000000-05:00',
#    'low': 236.64,
#    'high': 236.6996,
#    'open': 236.6984,
#    'close': 236.6463,
#    'volume': 1200,
#    'VWAP': 236.280023},
#   {'start': '2025-03-05T09:17:00.000000-05:00',
#    'end': '2025-03-05T09:18:00.000000-05:00',
#    'low': 236.65,
#    'high': 236.65,
#    'open': 236.65,
#    'close': 236.65,
#    'volume': 100,
#    'VWAP': 236.280194},
#   {'start': '2025-03-05T09:20:00.000000-05:00',
#    'end': '2025-03-05T09:21:00.000000-05:00',
#    'low': 236.56,
#    'high': 236.56,
#    'open': 236.56,
#    'close': 236.56,
#    'volume': 100,
#    'VWAP': 236.280805},
#   {'start': '2025-03-05T09:21:00.000000-05:00',
#    'end': '2025-03-05T09:22:00.000000-05:00',
#    'low': 236.52,
#    'high': 236.6178,
#    'open': 236.52,
#    'close': 236.6178,
#    'volume': 600,
#    'VWAP': 236.281225},
#   {'start': '2025-03-05T09:22:00.000000-05:00',
#    'end': '2025-03-05T09:23:00.000000-05:00',
#    'low': 236.5206,
#    'high': 236.65,
#    'open': 236.5206,
#    'close': 236.65,
#    'volume': 1000,
#    'VWAP': 236.282904},
#   {'start': '2025-03-05T09:23:00.000000-05:00',
#    'end': '2025-03-05T09:24:00.000000-05:00',
#    'low': 236.39,
#    'high': 236.61,
#    'open': 236.61,
#    'close': 236.39,
#    'volume': 3308,
#    'VWAP': 236.285721},
#   {'start': '2025-03-05T09:25:00.000000-05:00',
#    'end': '2025-03-05T09:26:00.000000-05:00',
#    'low': 235.81,
#    'high': 236.09,
#    'open': 235.93,
#    'close': 236.0803,
#    'volume': 7806,
#    'VWAP': 236.273801},
#   {'start': '2025-03-05T09:26:00.000000-05:00',
#    'end': '2025-03-05T09:27:00.000000-05:00',
#    'low': 235.91,
#    'high': 236.17,
#    'open': 236.12,
#    'close': 235.92,
#    'volume': 10974,
#    'VWAP': 236.268571},
#   {'start': '2025-03-05T09:27:00.000000-05:00',
#    'end': '2025-03-05T09:28:00.000000-05:00',
#    'low': 235.67,
#    'high': 236.1328,
#    'open': 235.91,
#    'close': 235.83,
#    'volume': 6736,
#    'VWAP': 236.257727},
#   {'start': '2025-03-05T09:28:00.000000-05:00',
#    'end': '2025-03-05T09:29:00.000000-05:00',
#    'low': 235.38,
#    'high': 235.67,
#    'open': 235.58,
#    'close': 235.53,
#    'volume': 13884,
#    'VWAP': 236.224908},
#   {'start': '2025-03-05T09:29:00.000000-05:00',
#    'end': '2025-03-05T09:30:00.000000-05:00',
#    'low': 235.22,
#    'high': 235.44,
#    'open': 235.44,
#    'close': 235.34,
#    'volume': 8172,
#    'VWAP': 236.20762},
#   {'start': '2025-03-05T09:30:00.000000-05:00',
#    'end': '2025-03-05T09:31:00.000000-05:00',
#    'low': 234.5501,
#    'high': 235.95,
#    'open': 235.42,
#    'close': 235.868,
#    'volume': 836168,
#    'VWAP': 235.420718},
#   {'start': '2025-03-05T09:31:00.000000-05:00',
#    'end': '2025-03-05T09:32:00.000000-05:00',
#    'low': 234.8401,
#    'high': 235.8519,
#    'open': 235.8519,
#    'close': 234.8401,
#    'volume': 133082,
#    'VWAP': 235.39448},
#   {'start': '2025-03-05T09:32:00.000000-05:00',
#    'end': '2025-03-05T09:33:00.000000-05:00',
#    'low': 234.8,
#    'high': 235.44,
#    'open': 234.84,
#    'close': 235.16,
#    'volume': 117205,
#    'VWAP': 235.374608},
#   {'start': '2025-03-05T09:33:00.000000-05:00',
#    'end': '2025-03-05T09:34:00.000000-05:00',
#    'low': 235,
#    'high': 235.9073,
#    'open': 235.16,
#    'close': 235.64,
#    'volume': 145458,
#    'VWAP': 235.384977},
#   {'start': '2025-03-05T09:34:00.000000-05:00',
#    'end': '2025-03-05T09:35:00.000000-05:00',
#    'low': 235.065,
#    'high': 235.71,
#    'open': 235.65,
#    'close': 235.12,
#    'volume': 89180,
#    'VWAP': 235.385052},
#   {'start': '2025-03-05T09:35:00.000000-05:00',
#    'end': '2025-03-05T09:36:00.000000-05:00',
#    'low': 235.08,
#    'high': 235.43,
#    'open': 235.11,
#    'close': 235.265,
#    'volume': 124517,
#    'VWAP': 235.37785},
#   {'start': '2025-03-05T09:36:00.000000-05:00',
#    'end': '2025-03-05T09:37:00.000000-05:00',
#    'low': 234.43,
#    'high': 235.32,
#    'open': 235.25,
#    'close': 234.6,
#    'volume': 110477,
#    'VWAP': 235.338826},
#   {'start': '2025-03-05T09:37:00.000000-05:00',
#    'end': '2025-03-05T09:38:00.000000-05:00',
#    'low': 234.05,
#    'high': 234.64,
#    'open': 234.58,
#    'close': 234.24,
#    'volume': 156925,
#    'VWAP': 235.249279},
#   {'start': '2025-03-05T09:38:00.000000-05:00',
#    'end': '2025-03-05T09:39:00.000000-05:00',
#    'low': 233.64,
#    'high': 234.25,
#    'open': 234.2489,
#    'close': 233.87,
#    'volume': 203463,
#    'VWAP': 235.109376},
#   {'start': '2025-03-05T09:39:00.000000-05:00',
#    'end': '2025-03-05T09:40:00.000000-05:00',
#    'low': 233.44,
#    'high': 233.9,
#    'open': 233.87,
#    'close': 233.81,
#    'volume': 161730,
#    'VWAP': 235.005235},
#   {'start': '2025-03-05T09:40:00.000000-05:00',
#    'end': '2025-03-05T09:41:00.000000-05:00',
#    'low': 233.57,
#    'high': 234.21,
#    'open': 233.81,
#    'close': 234.09,
#    'volume': 177042,
#    'VWAP': 234.922044},
#   {'start': '2025-03-05T09:41:00.000000-05:00',
#    'end': '2025-03-05T09:42:00.000000-05:00',
#    'low': 233.85,
#    'high': 234.14,
#    'open': 234.11,
#    'close': 233.9806,
#    'volume': 114485,
#    'VWAP': 234.877767},
#   {'start': '2025-03-05T09:42:00.000000-05:00',
#    'end': '2025-03-05T09:43:00.000000-05:00',
#    'low': 233.75,
#    'high': 234.0783,
#    'open': 233.96,
#    'close': 233.91,
#    'volume': 114308,
#    'VWAP': 234.833174},
#   {'start': '2025-03-05T09:43:00.000000-05:00',
#    'end': '2025-03-05T09:44:00.000000-05:00',
#    'low': 233.848,
#    'high': 234.135,
#    'open': 233.96,
#    'close': 233.91,
#    'volume': 102018,
#    'VWAP': 234.799682},
#   {'start': '2025-03-05T09:44:00.000000-05:00',
#    'end': '2025-03-05T09:45:00.000000-05:00',
#    'low': 233.77,
#    'high': 233.97,
#    'open': 233.9425,
#    'close': 233.9201,
#    'volume': 77051,
#    'VWAP': 234.773044},
#   {'start': '2025-03-05T09:45:00.000000-05:00',
#    'end': '2025-03-05T09:46:00.000000-05:00',
#    'low': 233.52,
#    'high': 234.02,
#    'open': 233.88,
#    'close': 233.84,
#    'volume': 135573,
#    'VWAP': 234.722553},
#   {'start': '2025-03-05T09:46:00.000000-05:00',
#    'end': '2025-03-05T09:47:00.000000-05:00',
#    'low': 233.6601,
#    'high': 233.92,
#    'open': 233.81,
#    'close': 233.695,
#    'volume': 90609,
#    'VWAP': 234.692755},
#   {'start': '2025-03-05T09:47:00.000000-05:00',
#    'end': '2025-03-05T09:48:00.000000-05:00',
#    'low': 232.91,
#    'high': 233.693232,
#    'open': 233.68,
#    'close': 233.05,
#    'volume': 197584,
#    'VWAP': 234.597262},
#   {'start': '2025-03-05T09:48:00.000000-05:00',
#    'end': '2025-03-05T09:49:00.000000-05:00',
#    'low': 232.67,
#    'high': 233.2117,
#    'open': 233.05,
#    'close': 232.855,
#    'volume': 129956,
#    'VWAP': 234.533072},
#   {'start': '2025-03-05T09:49:00.000000-05:00',
#    'end': '2025-03-05T09:50:00.000000-05:00',
#    'low': 232.38,
#    'high': 232.92,
#    'open': 232.88,
#    'close': 232.41,
#    'volume': 178723,
#    'VWAP': 234.430284},
#   {'start': '2025-03-05T09:50:00.000000-05:00',
#    'end': '2025-03-05T09:51:00.000000-05:00',
#    'low': 232.27,
#    'high': 232.77,
#    'open': 232.4132,
#    'close': 232.315,
#    'volume': 215076,
#    'VWAP': 234.314161},
#   {'start': '2025-03-05T09:51:00.000000-05:00',
#    'end': '2025-03-05T09:52:00.000000-05:00',
#    'low': 232.31,
#    'high': 232.76,
#    'open': 232.325,
#    'close': 232.625,
#    'volume': 174698,
#    'VWAP': 234.232737},
#   {'start': '2025-03-05T09:52:00.000000-05:00',
#    'end': '2025-03-05T09:53:00.000000-05:00',
#    'low': 232.22,
#    'high': 232.71,
#    'open': 232.59,
#    'close': 232.23,
#    'volume': 116735,
#    'VWAP': 234.178629},
#   {'start': '2025-03-05T09:53:00.000000-05:00',
#    'end': '2025-03-05T09:54:00.000000-05:00',
#    'low': 232.19,
#    'high': 232.55,
#    'open': 232.25,
#    'close': 232.39,
#    'volume': 86178,
#    'VWAP': 234.139772},
#   {'start': '2025-03-05T09:54:00.000000-05:00',
#    'end': '2025-03-05T09:55:00.000000-05:00',
#    'low': 231.77,
#    'high': 232.4595,
#    'open': 232.4595,
#    'close': 231.895,
#    'volume': 214955,
#    'VWAP': 234.03058},
#   {'start': '2025-03-05T09:55:00.000000-05:00',
#    'end': '2025-03-05T09:56:00.000000-05:00',
#    'low': 231.6,
#    'high': 231.98,
#    'open': 231.9136,
#    'close': 231.68,
#    'volume': 166234,
#    'VWAP': 233.946061},
#   {'start': '2025-03-05T09:56:00.000000-05:00',
#    'end': '2025-03-05T09:57:00.000000-05:00',
#    'low': 231.06,
#    'high': 231.78,
#    'open': 231.66,
#    'close': 231.23,
#    'volume': 236213,
#    'VWAP': 233.815177},
#   {'start': '2025-03-05T09:57:00.000000-05:00',
#    'end': '2025-03-05T09:58:00.000000-05:00',
#    'low': 231.04,
#    'high': 231.4939,
#    'open': 231.2354,
#    'close': 231.475,
#    'volume': 146193,
#    'VWAP': 233.736717},
#   {'start': '2025-03-05T09:58:00.000000-05:00',
#    'end': '2025-03-05T09:59:00.000000-05:00',
#    'low': 231.47,
#    'high': 232,
#    'open': 231.48,
#    'close': 231.94,
#    'volume': 140375,
#    'VWAP': 233.679309},
#   {'start': '2025-03-05T09:59:00.000000-05:00',
#    'end': '2025-03-05T10:00:00.000000-05:00',
#    'low': 231.6,
#    'high': 232.1,
#    'open': 231.9599,
#    'close': 231.77,
#    'volume': 162659,
#    'VWAP': 233.622401},
#   {'start': '2025-03-05T10:00:00.000000-05:00',
#    'end': '2025-03-05T10:01:00.000000-05:00',
#    'low': 231.83,
#    'high': 233.25,
#    'open': 231.83,
#    'close': 232.76,
#    'volume': 323116,
#    'VWAP': 233.56384},
#   {'start': '2025-03-05T10:01:00.000000-05:00',
#    'end': '2025-03-05T10:02:00.000000-05:00',
#    'low': 232.4208,
#    'high': 232.81,
#    'open': 232.76,
#    'close': 232.55,
#    'volume': 125571,
#    'VWAP': 233.541937},
#   {'start': '2025-03-05T10:02:00.000000-05:00',
#    'end': '2025-03-05T10:03:00.000000-05:00',
#    'low': 232.04,
#    'high': 232.61,
#    'open': 232.53,
#    'close': 232.61,
#    'volume': 163739,
#    'VWAP': 233.506169},
#   {'start': '2025-03-05T10:03:00.000000-05:00',
#    'end': '2025-03-05T10:04:00.000000-05:00',
#    'low': 232,
#    'high': 232.65,
#    'open': 232.59,
#    'close': 232.18,
#    'volume': 147751,
#    'VWAP': 233.476326},
#   {'start': '2025-03-05T10:04:00.000000-05:00',
#    'end': '2025-03-05T10:05:00.000000-05:00',
#    'low': 232.01,
#    'high': 232.48,
#    'open': 232.2,
#    'close': 232.41,
#    'volume': 145154,
#    'VWAP': 233.447121},
#   {'start': '2025-03-05T10:05:00.000000-05:00',
#    'end': '2025-03-05T10:06:00.000000-05:00',
#    'low': 232.13,
#    'high': 232.74,
#    'open': 232.45,
#    'close': 232.14,
#    'volume': 138048,
#    'VWAP': 233.424884},
#   {'start': '2025-03-05T10:06:00.000000-05:00',
#    'end': '2025-03-05T10:07:00.000000-05:00',
#    'low': 232.12,
#    'high': 232.56,
#    'open': 232.15,
#    'close': 232.435,
#    'volume': 94144,
#    'VWAP': 233.407808},
#   {'start': '2025-03-05T10:07:00.000000-05:00',
#    'end': '2025-03-05T10:08:00.000000-05:00',
#    'low': 232.32,
#    'high': 232.77,
#    'open': 232.43,
#    'close': 232.5101,
#    'volume': 69695,
#    'VWAP': 233.398598},
#   {'start': '2025-03-05T10:08:00.000000-05:00',
#    'end': '2025-03-05T10:09:00.000000-05:00',
#    'low': 232.16,
#    'high': 232.55,
#    'open': 232.51,
#    'close': 232.365,
#    'volume': 69145,
#    'VWAP': 233.387533},
#   {'start': '2025-03-05T10:09:00.000000-05:00',
#    'end': '2025-03-05T10:10:00.000000-05:00',
#    'low': 232.21,
#    'high': 232.47,
#    'open': 232.365,
#    'close': 232.32,
#    'volume': 98625,
#    'VWAP': 233.37163},
#   {'start': '2025-03-05T10:10:00.000000-05:00',
#    'end': '2025-03-05T10:11:00.000000-05:00',
#    'low': 231.85,
#    'high': 232.37,
#    'open': 232.29,
#    'close': 232.16,
#    'volume': 176809,
#    'VWAP': 233.338558},
#   {'start': '2025-03-05T10:11:00.000000-05:00',
#    'end': '2025-03-05T10:12:00.000000-05:00',
#    'low': 231.88,
#    'high': 232.21,
#    'open': 232.08,
#    'close': 232.0264,
#    'volume': 94530,
#    'VWAP': 233.320473},
#   {'start': '2025-03-05T10:12:00.000000-05:00',
#    'end': '2025-03-05T10:13:00.000000-05:00',
#    'low': 231.885,
#    'high': 232.73,
#    'open': 232.02,
#    'close': 232.73,
#    'volume': 100655,
#    'VWAP': 233.304934},
#   {'start': '2025-03-05T10:13:00.000000-05:00',
#    'end': '2025-03-05T10:14:00.000000-05:00',
#    'low': 232.4203,
#    'high': 232.79,
#    'open': 232.7,
#    'close': 232.64,
#    'volume': 74549,
#    'VWAP': 233.297454},
#   {'start': '2025-03-05T10:14:00.000000-05:00',
#    'end': '2025-03-05T10:15:00.000000-05:00',
#    'low': 232.56,
#    'high': 233.12,
#    'open': 232.58,
#    'close': 232.9207,
#    'volume': 138131,
#    'VWAP': 233.288696},
#   {'start': '2025-03-05T10:15:00.000000-05:00',
#    'end': '2025-03-05T10:16:00.000000-05:00',
#    'low': 232.86,
#    'high': 233.1186,
#    'open': 232.95,
#    'close': 232.875,
#    'volume': 77345,
#    'VWAP': 233.285445},
#   {'start': '2025-03-05T10:16:00.000000-05:00',
#    'end': '2025-03-05T10:17:00.000000-05:00',
#    'low': 232.7,
#    'high': 233.06,
#    'open': 232.96,
#    'close': 232.945,
#    'volume': 55931,
#    'VWAP': 233.282591},
#   {'start': '2025-03-05T10:17:00.000000-05:00',
#    'end': '2025-03-05T10:18:00.000000-05:00',
#    'low': 232.57,
#    'high': 232.93,
#    'open': 232.93,
#    'close': 232.88,
#    'volume': 64146,
#    'VWAP': 233.277319},
#   {'start': '2025-03-05T10:18:00.000000-05:00',
#    'end': '2025-03-05T10:19:00.000000-05:00',
#    'low': 232.6,
#    'high': 233.03,
#    'open': 232.85,
#    'close': 232.72,
#    'volume': 76883,
#    'VWAP': 233.272311},
#   {'start': '2025-03-05T10:19:00.000000-05:00',
#    'end': '2025-03-05T10:20:00.000000-05:00',
#    'low': 232,
#    'high': 232.71,
#    'open': 232.71,
#    'close': 232.25,
#    'volume': 195235,
#    'VWAP': 233.245818},
#   {'start': '2025-03-05T10:20:00.000000-05:00',
#    'end': '2025-03-05T10:21:00.000000-05:00',
#    'low': 231.67,
#    'high': 232.42,
#    'open': 232.26,
#    'close': 231.9796,
#    'volume': 98361,
#    'VWAP': 233.230176},
#   {'start': '2025-03-05T10:21:00.000000-05:00',
#    'end': '2025-03-05T10:22:00.000000-05:00',
#    'low': 230.52,
#    'high': 232,
#    'open': 231.945,
#    'close': 230.74,
#    'volume': 272225,
#    'VWAP': 233.156207},
#   {'start': '2025-03-05T10:22:00.000000-05:00',
#    'end': '2025-03-05T10:23:00.000000-05:00',
#    'low': 230.81,
#    'high': 231.65,
#    'open': 230.82,
#    'close': 231.57,
#    'volume': 97015,
#    'VWAP': 233.133983},
#   {'start': '2025-03-05T10:23:00.000000-05:00',
#    'end': '2025-03-05T10:24:00.000000-05:00',
#    'low': 231.31,
#    'high': 231.87,
#    'open': 231.56,
#    'close': 231.79,
#    'volume': 95737,
#    'VWAP': 233.114641},
#   {'start': '2025-03-05T10:24:00.000000-05:00',
#    'end': '2025-03-05T10:25:00.000000-05:00',
#    'low': 230.99,
#    'high': 231.85,
#    'open': 231.8499,
#    'close': 230.99,
#    'volume': 100269,
#    'VWAP': 233.093933},
#   {'start': '2025-03-05T10:25:00.000000-05:00',
#    'end': '2025-03-05T10:26:00.000000-05:00',
#    'low': 230.9,
#    'high': 231.13,
#    'open': 231.015,
#    'close': 231.0601,
#    'volume': 67382,
#    'VWAP': 233.076933},
#   {'start': '2025-03-05T10:26:00.000000-05:00',
#    'end': '2025-03-05T10:27:00.000000-05:00',
#    'low': 230.73,
#    'high': 231.29,
#    'open': 231.06,
#    'close': 231.04,
#    'volume': 102558,
#    'VWAP': 233.051393},
#   {'start': '2025-03-05T10:27:00.000000-05:00',
#    'end': '2025-03-05T10:28:00.000000-05:00',
#    'low': 230.89,
#    'high': 231.23,
#    'open': 231.04,
#    'close': 230.97,
#    'volume': 70012,
#    'VWAP': 233.034327},
#   {'start': '2025-03-05T10:28:00.000000-05:00',
#    'end': '2025-03-05T10:29:00.000000-05:00',
#    'low': 230.83,
#    'high': 231.1806,
#    'open': 230.98,
#    'close': 231.125,
#    'volume': 74494,
#    'VWAP': 233.016514},
#   {'start': '2025-03-05T10:29:00.000000-05:00',
#    'end': '2025-03-05T10:30:00.000000-05:00',
#    'low': 230.92,
#    'high': 231.3,
#    'open': 231.12,
#    'close': 230.92,
#    'volume': 75935,
#    'VWAP': 232.999691},
#   {'start': '2025-03-05T10:30:00.000000-05:00',
#    'end': '2025-03-05T10:31:00.000000-05:00',
#    'low': 230.8,
#    'high': 231.24,
#    'open': 230.94,
#    'close': 231.21,
#    'volume': 76812,
#    'VWAP': 232.981886},
#   {'start': '2025-03-05T10:31:00.000000-05:00',
#    'end': '2025-03-05T10:32:00.000000-05:00',
#    'low': 231.2279,
#    'high': 231.77,
#    'open': 231.235,
#    'close': 231.72,
#    'volume': 127184,
#    'VWAP': 232.960413},
#   {'start': '2025-03-05T10:32:00.000000-05:00',
#    'end': '2025-03-05T10:33:00.000000-05:00',
#    'low': 231.58,
#    'high': 231.95,
#    'open': 231.695,
#    'close': 231.82,
#    'volume': 120955,
#    'VWAP': 232.943971},
#   {'start': '2025-03-05T10:33:00.000000-05:00',
#    'end': '2025-03-05T10:34:00.000000-05:00',
#    'low': 231.67,
#    'high': 232.1698,
#    'open': 231.77,
#    'close': 231.92,
#    'volume': 74531,
#    'VWAP': 232.935734},
#   {'start': '2025-03-05T10:34:00.000000-05:00',
#    'end': '2025-03-05T10:35:00.000000-05:00',
#    'low': 231.86,
#    'high': 232.08,
#    'open': 231.945,
#    'close': 231.97,
#    'volume': 53969,
#    'VWAP': 232.929953},
#   {'start': '2025-03-05T10:35:00.000000-05:00',
#    'end': '2025-03-05T10:36:00.000000-05:00',
#    'low': 231.91,
#    'high': 232.47,
#    'open': 231.96,
#    'close': 232.38,
#    'volume': 87957,
#    'VWAP': 232.922144},
#   {'start': '2025-03-05T10:36:00.000000-05:00',
#    'end': '2025-03-05T10:37:00.000000-05:00',
#    'low': 232.125,
#    'high': 232.45,
#    'open': 232.39,
#    'close': 232.23,
#    'volume': 66582,
#    'VWAP': 232.917604},
#   {'start': '2025-03-05T10:37:00.000000-05:00',
#    'end': '2025-03-05T10:38:00.000000-05:00',
#    'low': 232.17,
#    'high': 232.47,
#    'open': 232.23,
#    'close': 232.398,
#    'volume': 59161,
#    'VWAP': 232.913983},
#   {'start': '2025-03-05T10:38:00.000000-05:00',
#    'end': '2025-03-05T10:39:00.000000-05:00',
#    'low': 232.415,
#    'high': 232.87,
#    'open': 232.415,
#    'close': 232.81,
#    'volume': 72665,
#    'VWAP': 232.912114},
#   {'start': '2025-03-05T10:39:00.000000-05:00',
#    'end': '2025-03-05T10:40:00.000000-05:00',
#    'low': 232.76,
#    'high': 233.2,
#    'open': 232.795,
#    'close': 233.015,
#    'volume': 121690,
#    'VWAP': 232.913251},
#   {'start': '2025-03-05T10:40:00.000000-05:00',
#    'end': '2025-03-05T10:41:00.000000-05:00',
#    'low': 232.79,
#    'high': 233.04,
#    'open': 233.03,
#    'close': 232.9101,
#    'volume': 49473,
#    'VWAP': 232.913225},
#   {'start': '2025-03-05T10:41:00.000000-05:00',
#    'end': '2025-03-05T10:42:00.000000-05:00',
#    'low': 232.8,
#    'high': 233.015,
#    'open': 232.935,
#    'close': 233.015,
#    'volume': 41531,
#    'VWAP': 232.913241},
#   {'start': '2025-03-05T10:42:00.000000-05:00',
#    'end': '2025-03-05T10:43:00.000000-05:00',
#    'low': 232.35,
#    'high': 233.025,
#    'open': 233.02,
#    'close': 232.45,
#    'volume': 70600,
#    'VWAP': 232.911144},
#   {'start': '2025-03-05T10:43:00.000000-05:00',
#    'end': '2025-03-05T10:44:00.000000-05:00',
#    'low': 232.43,
#    'high': 233.01,
#    'open': 232.475,
#    'close': 232.905,
#    'volume': 45710,
#    'VWAP': 232.910424},
#   {'start': '2025-03-05T10:44:00.000000-05:00',
#    'end': '2025-03-05T10:45:00.000000-05:00',
#    'low': 232.77,
#    'high': 233,
#    'open': 232.895,
#    'close': 232.875,
#    'volume': 26702,
#    'VWAP': 232.910303},
#   {'start': '2025-03-05T10:45:00.000000-05:00',
#    'end': '2025-03-05T10:46:00.000000-05:00',
#    'low': 232.84,
#    'high': 233.07,
#    'open': 232.87,
#    'close': 232.8537,
#    'volume': 62085,
#    'VWAP': 232.910563},
#   {'start': '2025-03-05T10:46:00.000000-05:00',
#    'end': '2025-03-05T10:47:00.000000-05:00',
#    'low': 232.8,
#    'high': 233.06,
#    'open': 232.86,
#    'close': 232.98,
#    'volume': 40431,
#    'VWAP': 232.910688},
#   {'start': '2025-03-05T10:47:00.000000-05:00',
#    'end': '2025-03-05T10:48:00.000000-05:00',
#    'low': 232.5978,
#    'high': 232.975,
#    'open': 232.975,
#    'close': 232.64,
#    'volume': 28000,
#    'VWAP': 232.910362},
#   {'start': '2025-03-05T10:48:00.000000-05:00',
#    'end': '2025-03-05T10:49:00.000000-05:00',
#    'low': 232.46,
#    'high': 232.75,
#    'open': 232.64,
#    'close': 232.5104,
#    'volume': 35151,
#    'VWAP': 232.909243},
#   {'start': '2025-03-05T10:49:00.000000-05:00',
#    'end': '2025-03-05T10:50:00.000000-05:00',
#    'low': 232.36,
#    'high': 232.59,
#    'open': 232.516,
#    'close': 232.51,
#    'volume': 41890,
#    'VWAP': 232.907481},
#   {'start': '2025-03-05T10:50:00.000000-05:00',
#    'end': '2025-03-05T10:51:00.000000-05:00',
#    'low': 232.39,
#    'high': 232.655,
#    'open': 232.5326,
#    'close': 232.4469,
#    'volume': 63342,
#    'VWAP': 232.90481},
#   {'start': '2025-03-05T10:51:00.000000-05:00',
#    'end': '2025-03-05T10:52:00.000000-05:00',
#    'low': 232.06,
#    'high': 232.4999,
#    'open': 232.49,
#    'close': 232.2,
#    'volume': 56034,
#    'VWAP': 232.901108},
#   {'start': '2025-03-05T10:52:00.000000-05:00',
#    'end': '2025-03-05T10:53:00.000000-05:00',
#    'low': 232.1,
#    'high': 232.4163,
#    'open': 232.1801,
#    'close': 232.315,
#    'volume': 49949,
#    'VWAP': 232.897828},
#   {'start': '2025-03-05T10:53:00.000000-05:00',
#    'end': '2025-03-05T10:54:00.000000-05:00',
#    'low': 232.2801,
#    'high': 232.4952,
#    'open': 232.34,
#    'close': 232.38,
#    'volume': 45234,
#    'VWAP': 232.895604},
#   {'start': '2025-03-05T10:54:00.000000-05:00',
#    'end': '2025-03-05T10:55:00.000000-05:00',
#    'low': 232.36,
#    'high': 232.53,
#    'open': 232.36,
#    'close': 232.5,
#    'volume': 30692,
#    'VWAP': 232.89426},
#   {'start': '2025-03-05T10:55:00.000000-05:00',
#    'end': '2025-03-05T10:56:00.000000-05:00',
#    'low': 232.42,
#    'high': 232.56,
#    'open': 232.495,
#    'close': 232.55,
#    'volume': 21213,
#    'VWAP': 232.893391},
#   {'start': '2025-03-05T10:56:00.000000-05:00',
#    'end': '2025-03-05T10:57:00.000000-05:00',
#    'low': 232.44,
#    'high': 232.78,
#    'open': 232.545,
#    'close': 232.78,
#    'volume': 42106,
#    'VWAP': 232.892269},
#   {'start': '2025-03-05T10:57:00.000000-05:00',
#    'end': '2025-03-05T10:58:00.000000-05:00',
#    'low': 232.6214,
#    'high': 232.82,
#    'open': 232.77,
#    'close': 232.815,
#    'volume': 29930,
#    'VWAP': 232.891778},
#   {'start': '2025-03-05T10:58:00.000000-05:00',
#    'end': '2025-03-05T10:59:00.000000-05:00',
#    'low': 232.76,
#    'high': 232.95,
#    'open': 232.82,
#    'close': 232.78,
#    'volume': 47359,
#    'VWAP': 232.891641},
#   {'start': '2025-03-05T10:59:00.000000-05:00',
#    'end': '2025-03-05T11:00:00.000000-05:00',
#    'low': 232.54,
#    'high': 232.8,
#    'open': 232.76,
#    'close': 232.57,
#    'volume': 43799,
#    'VWAP': 232.890521},
#   {'start': '2025-03-05T11:00:00.000000-05:00',
#    'end': '2025-03-05T11:01:00.000000-05:00',
#    'low': 232.21,
#    'high': 232.63,
#    'open': 232.565,
#    'close': 232.23,
#    'volume': 45821,
#    'VWAP': 232.888121},
#   {'start': '2025-03-05T11:01:00.000000-05:00',
#    'end': '2025-03-05T11:02:00.000000-05:00',
#    'low': 231.82,
#    'high': 232.219,
#    'open': 232.2,
#    'close': 232,
#    'volume': 62040,
#    'VWAP': 232.882829},
#   {'start': '2025-03-05T11:02:00.000000-05:00',
#    'end': '2025-03-05T11:03:00.000000-05:00',
#    'low': 231.89,
#    'high': 232.1507,
#    'open': 232.02,
#    'close': 232.08,
#    'volume': 43523,
#    'VWAP': 232.879204},
#   {'start': '2025-03-05T11:03:00.000000-05:00',
#    'end': '2025-03-05T11:04:00.000000-05:00',
#    'low': 231.96,
#    'high': 232.132641,
#    'open': 232.085,
#    'close': 232.0501,
#    'volume': 50107,
#    'VWAP': 232.875197},
#   {'start': '2025-03-05T11:04:00.000000-05:00',
#    'end': '2025-03-05T11:05:00.000000-05:00',
#    'low': 231.81,
#    'high': 232.07,
#    'open': 232.05,
#    'close': 231.99,
#    'volume': 54391,
#    'VWAP': 232.870335},
#   {'start': '2025-03-05T11:05:00.000000-05:00',
#    'end': '2025-03-05T11:06:00.000000-05:00',
#    'low': 231.835,
#    'high': 232.1132,
#    'open': 232,
#    'close': 231.8404,
#    'volume': 33969,
#    'VWAP': 232.867533},
#   {'start': '2025-03-05T11:06:00.000000-05:00',
#    'end': '2025-03-05T11:07:00.000000-05:00',
#    'low': 231.66,
#    'high': 231.92,
#    'open': 231.885,
#    'close': 231.695,
#    'volume': 72189,
#    'VWAP': 232.860232},
#   {'start': '2025-03-05T11:07:00.000000-05:00',
#    'end': '2025-03-05T11:08:00.000000-05:00',
#    'low': 231.51,
#    'high': 231.77,
#    'open': 231.67,
#    'close': 231.72,
#    'volume': 39654,
#    'VWAP': 232.855766},
#   {'start': '2025-03-05T11:08:00.000000-05:00',
#    'end': '2025-03-05T11:09:00.000000-05:00',
#    'low': 231.3774,
#    'high': 231.74,
#    'open': 231.72,
#    'close': 231.5199,
#    'volume': 52110,
#    'VWAP': 232.849466},
#   {'start': '2025-03-05T11:09:00.000000-05:00',
#    'end': '2025-03-05T11:10:00.000000-05:00',
#    'low': 231.32,
#    'high': 231.53,
#    'open': 231.48,
#    'close': 231.39,
#    'volume': 49149,
#    'VWAP': 232.843038},
#   {'start': '2025-03-05T11:10:00.000000-05:00',
#    'end': '2025-03-05T11:11:00.000000-05:00',
#    'low': 231.14,
#    'high': 231.48,
#    'open': 231.37,
#    'close': 231.22,
#    'volume': 73523,
#    'VWAP': 232.832728},
#   {'start': '2025-03-05T11:11:00.000000-05:00',
#    'end': '2025-03-05T11:12:00.000000-05:00',
#    'low': 230.8506,
#    'high': 231.26,
#    'open': 231.26,
#    'close': 230.98,
#    'volume': 109761,
#    'VWAP': 232.814519},
#   {'start': '2025-03-05T11:12:00.000000-05:00',
#    'end': '2025-03-05T11:13:00.000000-05:00',
# ...
#    'high': 236.9,
#    'open': 236.625,
#    'close': 236.54,
#    'volume': 49484,
#    'VWAP': 236.044417},
#   {'start': '2025-03-06T11:37:00.000000-05:00',
#    'end': '2025-03-06T11:38:00.000000-05:00',
#    'low': 236.32,
#    'high': 236.5697,
#    'open': 236.5697,
#    'close': 236.38,
#    'volume': 29225,
#    'VWAP': 236.045521},
#   {'start': '2025-03-06T11:38:00.000000-05:00',
#    'end': '2025-03-06T11:39:00.000000-05:00',
#    'low': 236.2,
#    'high': 236.405,
#    'open': 236.4,
#    'close': 236.26,
#    'volume': 46013,
#    'VWAP': 236.046707},
#   {'start': '2025-03-06T11:39:00.000000-05:00',
#    'end': '2025-03-06T11:40:00.000000-05:00',
#    'low': 236,
#    'high': 236.34,
#    'open': 236.283,
#    'close': 236.225,
#    'volume': 48942,
#    'VWAP': 236.047315},
#   {'start': '2025-03-06T11:40:00.000000-05:00',
#    'end': '2025-03-06T11:41:00.000000-05:00',
#    'low': 235.92,
#    'high': 236.22,
#    'open': 236.22,
#    'close': 236.02,
#    'volume': 45445,
#    'VWAP': 236.047208},
#   {'start': '2025-03-06T11:41:00.000000-05:00',
#    'end': '2025-03-06T11:42:00.000000-05:00',
#    'low': 235.91,
#    'high': 236.18,
#    'open': 236.02,
#    'close': 236.08,
#    'volume': 41081,
#    'VWAP': 236.047181},
#   {'start': '2025-03-06T11:42:00.000000-05:00',
#    'end': '2025-03-06T11:43:00.000000-05:00',
#    'low': 235.8504,
#    'high': 236.08,
#    'open': 236.06,
#    'close': 236.025,
#    'volume': 36373,
#    'VWAP': 236.046901},
#   {'start': '2025-03-06T11:43:00.000000-05:00',
#    'end': '2025-03-06T11:44:00.000000-05:00',
#    'low': 235.8273,
#    'high': 236.03,
#    'open': 235.98,
#    'close': 235.93,
#    'volume': 36750,
#    'VWAP': 236.046485},
#   {'start': '2025-03-06T11:44:00.000000-05:00',
#    'end': '2025-03-06T11:45:00.000000-05:00',
#    'low': 235.89,
#    'high': 236.03,
#    'open': 235.9,
#    'close': 236.02,
#    'volume': 28738,
#    'VWAP': 236.046238},
#   {'start': '2025-03-06T11:45:00.000000-05:00',
#    'end': '2025-03-06T11:46:00.000000-05:00',
#    'low': 235.75,
#    'high': 236.04,
#    'open': 236.03,
#    'close': 235.775,
#    'volume': 64012,
#    'VWAP': 236.045069},
#   {'start': '2025-03-06T11:46:00.000000-05:00',
#    'end': '2025-03-06T11:47:00.000000-05:00',
#    'low': 235.54,
#    'high': 235.91,
#    'open': 235.76,
#    'close': 235.8,
#    'volume': 56201,
#    'VWAP': 236.043213},
#   {'start': '2025-03-06T11:47:00.000000-05:00',
#    'end': '2025-03-06T11:48:00.000000-05:00',
#    'low': 235.8157,
#    'high': 235.99,
#    'open': 235.83,
#    'close': 235.98,
#    'volume': 35250,
#    'VWAP': 236.042697},
#   {'start': '2025-03-06T11:48:00.000000-05:00',
#    'end': '2025-03-06T11:49:00.000000-05:00',
#    'low': 235.62,
#    'high': 236,
#    'open': 236,
#    'close': 235.71,
#    'volume': 37074,
#    'VWAP': 236.041778},
#   {'start': '2025-03-06T11:49:00.000000-05:00',
#    'end': '2025-03-06T11:50:00.000000-05:00',
#    'low': 235.41,
#    'high': 235.717,
#    'open': 235.717,
#    'close': 235.42,
#    'volume': 46992,
#    'VWAP': 236.039487},
#   {'start': '2025-03-06T11:50:00.000000-05:00',
#    'end': '2025-03-06T11:51:00.000000-05:00',
#    'low': 235.14,
#    'high': 235.45,
#    'open': 235.4155,
#    'close': 235.355,
#    'volume': 77212,
#    'VWAP': 236.034197},
#   {'start': '2025-03-06T11:51:00.000000-05:00',
#    'end': '2025-03-06T11:52:00.000000-05:00',
#    'low': 234.97,
#    'high': 235.3999,
#    'open': 235.33,
#    'close': 235.185,
#    'volume': 67786,
#    'VWAP': 236.028777},
#   {'start': '2025-03-06T11:52:00.000000-05:00',
#    'end': '2025-03-06T11:53:00.000000-05:00',
#    'low': 234.935,
#    'high': 235.2289,
#    'open': 235.2289,
#    'close': 235.0488,
#    'volume': 70629,
#    'VWAP': 236.022655},
#   {'start': '2025-03-06T11:53:00.000000-05:00',
#    'end': '2025-03-06T11:54:00.000000-05:00',
#    'low': 234.91,
#    'high': 235.2,
#    'open': 235.05,
#    'close': 235.08,
#    'volume': 44455,
#    'VWAP': 236.018748},
#   {'start': '2025-03-06T11:54:00.000000-05:00',
#    'end': '2025-03-06T11:55:00.000000-05:00',
#    'low': 235.07,
#    'high': 235.35,
#    'open': 235.07,
#    'close': 235.14,
#    'volume': 53877,
#    'VWAP': 236.014855},
#   {'start': '2025-03-06T11:55:00.000000-05:00',
#    'end': '2025-03-06T11:56:00.000000-05:00',
#    'low': 234.85,
#    'high': 235.15,
#    'open': 235.11,
#    'close': 235,
#    'volume': 56704,
#    'VWAP': 236.009628},
#   {'start': '2025-03-06T11:56:00.000000-05:00',
#    'end': '2025-03-06T11:57:00.000000-05:00',
#    'low': 234.9201,
#    'high': 235.21,
#    'open': 234.99,
#    'close': 235.21,
#    'volume': 41523,
#    'VWAP': 236.006081},
#   {'start': '2025-03-06T11:57:00.000000-05:00',
#    'end': '2025-03-06T11:58:00.000000-05:00',
#    'low': 234.9258,
#    'high': 235.25,
#    'open': 235.18,
#    'close': 234.98,
#    'volume': 44690,
#    'VWAP': 236.002391},
#   {'start': '2025-03-06T11:58:00.000000-05:00',
#    'end': '2025-03-06T11:59:00.000000-05:00',
#    'low': 234.8201,
#    'high': 235.07,
#    'open': 234.985,
#    'close': 234.98,
#    'volume': 33852,
#    'VWAP': 235.999351},
#   {'start': '2025-03-06T11:59:00.000000-05:00',
#    'end': '2025-03-06T12:00:00.000000-05:00',
#    'low': 234.83,
#    'high': 235.02,
#    'open': 234.98,
#    'close': 234.935,
#    'volume': 25947,
#    'VWAP': 235.996939},
#   {'start': '2025-03-06T12:00:00.000000-05:00',
#    'end': '2025-03-06T12:01:00.000000-05:00',
#    'low': 234.81,
#    'high': 235.07,
#    'open': 234.95,
#    'close': 235.002,
#    'volume': 30544,
#    'VWAP': 235.994179},
#   {'start': '2025-03-06T12:01:00.000000-05:00',
#    'end': '2025-03-06T12:02:00.000000-05:00',
#    'low': 234.99,
#    'high': 235.23,
#    'open': 235.04,
#    'close': 235.2299,
#    'volume': 48878,
#    'VWAP': 235.990589},
#   {'start': '2025-03-06T12:02:00.000000-05:00',
#    'end': '2025-03-06T12:03:00.000000-05:00',
#    'low': 234.79,
#    'high': 235.26,
#    'open': 235.2293,
#    'close': 234.85,
#    'volume': 51827,
#    'VWAP': 235.986203},
#   {'start': '2025-03-06T12:03:00.000000-05:00',
#    'end': '2025-03-06T12:04:00.000000-05:00',
#    'low': 234.51,
#    'high': 234.88,
#    'open': 234.85,
#    'close': 234.5853,
#    'volume': 55905,
#    'VWAP': 235.979787},
#   {'start': '2025-03-06T12:04:00.000000-05:00',
#    'end': '2025-03-06T12:05:00.000000-05:00',
#    'low': 234.32,
#    'high': 234.6298,
#    'open': 234.58,
#    'close': 234.35,
#    'volume': 127637,
#    'VWAP': 235.963693},
#   {'start': '2025-03-06T12:05:00.000000-05:00',
#    'end': '2025-03-06T12:06:00.000000-05:00',
#    'low': 234.15,
#    'high': 234.6,
#    'open': 234.33,
#    'close': 234.5598,
#    'volume': 46205,
#    'VWAP': 235.957513},
#   {'start': '2025-03-06T12:06:00.000000-05:00',
#    'end': '2025-03-06T12:07:00.000000-05:00',
#    'low': 234.19,
#    'high': 234.57,
#    'open': 234.55,
#    'close': 234.38,
#    'volume': 64426,
#    'VWAP': 235.949363},
#   {'start': '2025-03-06T12:07:00.000000-05:00',
#    'end': '2025-03-06T12:08:00.000000-05:00',
#    'low': 234.27,
#    'high': 234.78,
#    'open': 234.37,
#    'close': 234.69,
#    'volume': 40837,
#    'VWAP': 235.944535},
#   {'start': '2025-03-06T12:08:00.000000-05:00',
#    'end': '2025-03-06T12:09:00.000000-05:00',
#    'low': 234.6564,
#    'high': 234.98,
#    'open': 234.6601,
#    'close': 234.96,
#    'volume': 35524,
#    'VWAP': 235.941125},
#   {'start': '2025-03-06T12:09:00.000000-05:00',
#    'end': '2025-03-06T12:10:00.000000-05:00',
#    'low': 234.74,
#    'high': 235.21,
#    'open': 234.985,
#    'close': 235.08,
#    'volume': 135821,
#    'VWAP': 235.931069},
#   {'start': '2025-03-06T12:10:00.000000-05:00',
#    'end': '2025-03-06T12:11:00.000000-05:00',
#    'low': 234.9201,
#    'high': 235.18,
#    'open': 235.08,
#    'close': 235.0324,
#    'volume': 38462,
#    'VWAP': 235.928214},
#   {'start': '2025-03-06T12:11:00.000000-05:00',
#    'end': '2025-03-06T12:12:00.000000-05:00',
#    'low': 234.86,
#    'high': 235.12,
#    'open': 235,
#    'close': 234.99,
#    'volume': 33632,
#    'VWAP': 235.925717},
#   {'start': '2025-03-06T12:12:00.000000-05:00',
#    'end': '2025-03-06T12:13:00.000000-05:00',
#    'low': 234.82,
#    'high': 235,
#    'open': 234.96,
#    'close': 234.96,
#    'volume': 41228,
#    'VWAP': 235.922279},
#   {'start': '2025-03-06T12:13:00.000000-05:00',
#    'end': '2025-03-06T12:14:00.000000-05:00',
#    'low': 234.815,
#    'high': 235.1,
#    'open': 234.95,
#    'close': 235.07,
#    'volume': 49720,
#    'VWAP': 235.918539},
#   {'start': '2025-03-06T12:14:00.000000-05:00',
#    'end': '2025-03-06T12:15:00.000000-05:00',
#    'low': 234.83,
#    'high': 235.1,
#    'open': 235.085,
#    'close': 234.86,
#    'volume': 43497,
#    'VWAP': 235.915258},
#   {'start': '2025-03-06T12:15:00.000000-05:00',
#    'end': '2025-03-06T12:16:00.000000-05:00',
#    'low': 234.85,
#    'high': 235.08,
#    'open': 234.87,
#    'close': 235.05,
#    'volume': 44824,
#    'VWAP': 235.911763},
#   {'start': '2025-03-06T12:16:00.000000-05:00',
#    'end': '2025-03-06T12:17:00.000000-05:00',
#    'low': 234.84,
#    'high': 235.055,
#    'open': 235.03,
#    'close': 234.84,
#    'volume': 21807,
#    'VWAP': 235.910039},
#   {'start': '2025-03-06T12:17:00.000000-05:00',
#    'end': '2025-03-06T12:18:00.000000-05:00',
#    'low': 234.56,
#    'high': 234.878,
#    'open': 234.85,
#    'close': 234.63,
#    'volume': 133756,
#    'VWAP': 235.897336},
#   {'start': '2025-03-06T12:18:00.000000-05:00',
#    'end': '2025-03-06T12:19:00.000000-05:00',
#    'low': 234.6,
#    'high': 234.95,
#    'open': 234.64,
#    'close': 234.91,
#    'volume': 49626,
#    'VWAP': 235.892852},
#   {'start': '2025-03-06T12:19:00.000000-05:00',
#    'end': '2025-03-06T12:20:00.000000-05:00',
#    'low': 234.72,
#    'high': 234.95,
#    'open': 234.7863,
#    'close': 234.83,
#    'volume': 24672,
#    'VWAP': 235.890839},
#   {'start': '2025-03-06T12:20:00.000000-05:00',
#    'end': '2025-03-06T12:21:00.000000-05:00',
#    'low': 234.79,
#    'high': 235.28,
#    'open': 234.83,
#    'close': 235.2,
#    'volume': 113721,
#    'VWAP': 235.884286},
#   {'start': '2025-03-06T12:21:00.000000-05:00',
#    'end': '2025-03-06T12:22:00.000000-05:00',
#    'low': 235.0096,
#    'high': 235.26,
#    'open': 235.22,
#    'close': 235.0096,
#    'volume': 32685,
#    'VWAP': 235.882298},
#   {'start': '2025-03-06T12:22:00.000000-05:00',
#    'end': '2025-03-06T12:23:00.000000-05:00',
#    'low': 235,
#    'high': 235.24,
#    'open': 235.03,
#    'close': 235.06,
#    'volume': 30881,
#    'VWAP': 235.88046},
#   {'start': '2025-03-06T12:23:00.000000-05:00',
#    'end': '2025-03-06T12:24:00.000000-05:00',
#    'low': 234.93,
#    'high': 235.1,
#    'open': 235.03,
#    'close': 234.98,
#    'volume': 27620,
#    'VWAP': 235.878587},
#   {'start': '2025-03-06T12:24:00.000000-05:00',
#    'end': '2025-03-06T12:25:00.000000-05:00',
#    'low': 234.65,
#    'high': 234.95,
#    'open': 234.9477,
#    'close': 234.74,
#    'volume': 43342,
#    'VWAP': 235.874884},
#   {'start': '2025-03-06T12:25:00.000000-05:00',
#    'end': '2025-03-06T12:26:00.000000-05:00',
#    'low': 234.37,
#    'high': 234.74,
#    'open': 234.74,
#    'close': 234.59,
#    'volume': 44739,
#    'VWAP': 235.870102},
#   {'start': '2025-03-06T12:26:00.000000-05:00',
#    'end': '2025-03-06T12:27:00.000000-05:00',
#    'low': 234.485,
#    'high': 234.66,
#    'open': 234.605,
#    'close': 234.5701,
#    'volume': 19029,
#    'VWAP': 235.868179},
#   {'start': '2025-03-06T12:27:00.000000-05:00',
#    'end': '2025-03-06T12:28:00.000000-05:00',
#    'low': 234.04,
#    'high': 234.57,
#    'open': 234.57,
#    'close': 234.105,
#    'volume': 197101,
#    'VWAP': 235.844873},
#   {'start': '2025-03-06T12:28:00.000000-05:00',
#    'end': '2025-03-06T12:29:00.000000-05:00',
#    'low': 234.05,
#    'high': 234.34,
#    'open': 234.13,
#    'close': 234.33,
#    'volume': 73646,
#    'VWAP': 235.835615},
#   {'start': '2025-03-06T12:29:00.000000-05:00',
#    'end': '2025-03-06T12:30:00.000000-05:00',
#    'low': 234.26,
#    'high': 234.5,
#    'open': 234.35,
#    'close': 234.4,
#    'volume': 119237,
#    'VWAP': 235.822651},
#   {'start': '2025-03-06T12:30:00.000000-05:00',
#    'end': '2025-03-06T12:31:00.000000-05:00',
#    'low': 234.33,
#    'high': 234.87,
#    'open': 234.4,
#    'close': 234.845,
#    'volume': 53591,
#    'VWAP': 235.817714},
#   {'start': '2025-03-06T12:31:00.000000-05:00',
#    'end': '2025-03-06T12:32:00.000000-05:00',
#    'low': 234.5,
#    'high': 234.95,
#    'open': 234.85,
#    'close': 234.555,
#    'volume': 66636,
#    'VWAP': 235.812379},
#   {'start': '2025-03-06T12:32:00.000000-05:00',
#    'end': '2025-03-06T12:33:00.000000-05:00',
#    'low': 234.44,
#    'high': 234.6,
#    'open': 234.54,
#    'close': 234.545,
#    'volume': 34101,
#    'VWAP': 235.809126},
#   {'start': '2025-03-06T12:33:00.000000-05:00',
#    'end': '2025-03-06T12:34:00.000000-05:00',
#    'low': 234.5,
#    'high': 234.7799,
#    'open': 234.56,
#    'close': 234.6378,
#    'volume': 35839,
#    'VWAP': 235.806071},
#   {'start': '2025-03-06T12:34:00.000000-05:00',
#    'end': '2025-03-06T12:35:00.000000-05:00',
#    'low': 234.44,
#    'high': 234.71,
#    'open': 234.61,
#    'close': 234.697,
#    'volume': 36367,
#    'VWAP': 235.802837},
#   {'start': '2025-03-06T12:35:00.000000-05:00',
#    'end': '2025-03-06T12:36:00.000000-05:00',
#    'low': 234.63,
#    'high': 234.78,
#    'open': 234.68,
#    'close': 234.69,
#    'volume': 29209,
#    'VWAP': 235.800514},
#   {'start': '2025-03-06T12:36:00.000000-05:00',
#    'end': '2025-03-06T12:37:00.000000-05:00',
#    'low': 234.58,
#    'high': 234.78,
#    'open': 234.72,
#    'close': 234.75,
#    'volume': 39546,
#    'VWAP': 235.797165},
#   {'start': '2025-03-06T12:37:00.000000-05:00',
#    'end': '2025-03-06T12:38:00.000000-05:00',
#    'low': 234.69,
#    'high': 234.82,
#    'open': 234.8,
#    'close': 234.71,
#    'volume': 30691,
#    'VWAP': 235.794749},
#   {'start': '2025-03-06T12:38:00.000000-05:00',
#    'end': '2025-03-06T12:39:00.000000-05:00',
#    'low': 234.67,
#    'high': 234.92,
#    'open': 234.7,
#    'close': 234.87,
#    'volume': 36124,
#    'VWAP': 235.792251},
#   {'start': '2025-03-06T12:39:00.000000-05:00',
#    'end': '2025-03-06T12:40:00.000000-05:00',
#    'low': 234.7,
#    'high': 234.95,
#    'open': 234.84,
#    'close': 234.7,
#    'volume': 41232,
#    'VWAP': 235.789261},
#   {'start': '2025-03-06T12:40:00.000000-05:00',
#    'end': '2025-03-06T12:41:00.000000-05:00',
#    'low': 234.61,
#    'high': 235.08,
#    'open': 234.7,
#    'close': 235.015,
#    'volume': 109346,
#    'VWAP': 235.781581},
#   {'start': '2025-03-06T12:41:00.000000-05:00',
#    'end': '2025-03-06T12:42:00.000000-05:00',
#    'low': 234.82,
#    'high': 235.21,
#    'open': 235,
#    'close': 234.9,
#    'volume': 73445,
#    'VWAP': 235.777625},
#   {'start': '2025-03-06T12:42:00.000000-05:00',
#    'end': '2025-03-06T12:43:00.000000-05:00',
#    'low': 234.83,
#    'high': 235.06,
#    'open': 234.9,
#    'close': 234.86,
#    'volume': 34839,
#    'VWAP': 235.775527},
#   {'start': '2025-03-06T12:43:00.000000-05:00',
#    'end': '2025-03-06T12:44:00.000000-05:00',
#    'low': 234.725,
#    'high': 234.855,
#    'open': 234.8506,
#    'close': 234.79,
#    'volume': 25648,
#    'VWAP': 235.773733},
#   {'start': '2025-03-06T12:44:00.000000-05:00',
#    'end': '2025-03-06T12:45:00.000000-05:00',
#    'low': 234.64,
#    'high': 234.79,
#    'open': 234.79,
#    'close': 234.71,
#    'volume': 30782,
#    'VWAP': 235.771422},
#   {'start': '2025-03-06T12:45:00.000000-05:00',
#    'end': '2025-03-06T12:46:00.000000-05:00',
#    'low': 234.57,
#    'high': 234.77,
#    'open': 234.715,
#    'close': 234.57,
#    'volume': 32311,
#    'VWAP': 235.768836},
#   {'start': '2025-03-06T12:46:00.000000-05:00',
#    'end': '2025-03-06T12:47:00.000000-05:00',
#    'low': 234.16,
#    'high': 234.56,
#    'open': 234.56,
#    'close': 234.19,
#    'volume': 83813,
#    'VWAP': 235.76027},
#   {'start': '2025-03-06T12:47:00.000000-05:00',
#    'end': '2025-03-06T12:48:00.000000-05:00',
#    'low': 234.0718,
#    'high': 234.22,
#    'open': 234.17,
#    'close': 234.17,
#    'volume': 43167,
#    'VWAP': 235.7552},
#   {'start': '2025-03-06T12:48:00.000000-05:00',
#    'end': '2025-03-06T12:49:00.000000-05:00',
#    'low': 234.06,
#    'high': 234.41,
#    'open': 234.175,
#    'close': 234.29,
#    'volume': 49401,
#    'VWAP': 235.749833},
#   {'start': '2025-03-06T12:49:00.000000-05:00',
#    'end': '2025-03-06T12:50:00.000000-05:00',
#    'low': 234.0648,
#    'high': 234.475,
#    'open': 234.31,
#    'close': 234.375,
#    'volume': 53415,
#    'VWAP': 235.744202},
#   {'start': '2025-03-06T12:50:00.000000-05:00',
#    'end': '2025-03-06T12:51:00.000000-05:00',
#    'low': 234.28,
#    'high': 234.48,
#    'open': 234.36,
#    'close': 234.3848,
#    'volume': 19052,
#    'VWAP': 235.742309},
#   ...]}

# %%
quote = qt.get_market_quote(symbol_id=symbols['symbols'][0]['symbolId'])
quote

# Get quote for multiple symbols at once
symbol_ids = [symbols['symbols'][0]['symbolId'], symbols['symbols'][1]['symbolId']]
multiple_quotes = qt.get_market_quote(ids=symbol_ids)
multiple_quotes
# Out:
# {'quotes': [{'symbol': 'AAPL',
#    'symbolId': 8049,
#    'tier': '',
#    'bidPrice': 193.5,
#    'bidSize': 2,
#    'askPrice': 193.51,
#    'askSize': 10,
#    'lastTradePriceTrHrs': 203.19,
#    'lastTradePrice': 193.51,
#    'lastTradeSize': 100,
#    'lastTradeTick': 'Up',
#    'lastTradeTime': '2025-04-04T08:20:18.067000-04:00',
#    'volume': 3574975,
#    'openPrice': 0,
#    'highPrice': 0,
#    'lowPrice': 0,
#    'delay': 0,
#    'isHalted': False,
#    'high52w': 260.1,
#    'low52w': 164.075,
#    'VWAP': 194.488148},
#   {'symbol': 'AAPL.TO',
#    'symbolId': 39472334,
#    'tier': '',
#    'bidPrice': 32,
#    'bidSize': 35,
#    'askPrice': 32,
#    'askSize': 41,
#    'lastTradePriceTrHrs': 29.66,
#    'lastTradePrice': 29.66,
#    'lastTradeSize': 0,
#    'lastTradeTick': 'Equal',
#    'lastTradeTime': '2025-04-03T00:00:00.000000-04:00',
#    'volume': 0,
#    'openPrice': 0,
#    'highPrice': 0,
#    'lowPrice': 0,
#    'delay': 0,
#    'isHalted': False,
#    'high52w': 36.4,
#    'low52w': 29.32,
#    'VWAP': 0}]}

# %%
import sys
sys.path.append(r'C:\Users\Administrator\finstral-1')
from qt_api import qt_api as qt

# %%
import src.local_symbols as local_symbols

symbol = input('Enter a symbol: ').upper()
symbol_info = local_symbols.get_local_symbol(symbol)
symbol_info
# Out:
# {'symbol': 'INTC',
#  'symbolId': 23205,
#  'prevDayClosePrice': 22.43,
#  'highPrice52': 40.7798,
#  'lowPrice52': 18.51,
#  'averageVol3Months': 101906199,
#  'averageVol20Days': 102682731,
#  'outstandingShares': 4330000000,
#  'eps': -4.38,
#  'pe': None,
#  'dividend': 0.125,
#  'yield': 0,
#  'exDate': '2024-08-07T00:00:00.000000-04:00',
#  'marketCap': 95173400000,
#  'tradeUnit': 1,
#  'optionType': None,
#  'optionDurationType': None,
#  'optionRoot': '',
#  'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#  'optionExerciseType': None,
#  'listingExchange': 'NASDAQ',
#  'description': 'INTEL CORP',
#  'securityType': 'Stock',
#  'optionExpiryDate': None,
#  'dividendDate': '2024-09-01T00:00:00.000000-04:00',
#  'optionStrikePrice': None,
#  'isTradable': True,
#  'isQuotable': True,
#  'hasOptions': True,
#  'currency': 'USD',
#  'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#  'industrySector': 'Technology',
#  'industryGroup': 'Undefined',
#  'industrySubgroup': 'Undefined'}

# %%
all_symbols = local_symbols.get_all_local_symbols()
all_symbols
# Out:
# [{'symbol': 'TSLL',
#   'symbolId': 43622030,
#   'prevDayClosePrice': 10.03,
#   'highPrice52': 41.5,
#   'lowPrice52': 4.94,
#   'averageVol3Months': 123728208,
#   'averageVol20Days': 215524717,
#   'outstandingShares': 436425000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.08448,
#   'yield': 3.42848,
#   'exDate': '2025-03-25T00:00:00.000000-04:00',
#   'marketCap': 4918509800,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NASDAQ',
#   'description': 'DIREXION SHARES ETF TRUST DAILY TSLA BULL 2X SHARES',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-01T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'SOXL',
#   'symbolId': 16114,
#   'prevDayClosePrice': 11.41,
#   'highPrice52': 70.08,
#   'lowPrice52': 11.4,
#   'averageVol3Months': 94306712,
#   'averageVol20Days': 119116504,
#   'outstandingShares': 470000000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.06477,
#   'yield': 2.15627,
#   'exDate': '2025-03-25T00:00:00.000000-04:00',
#   'marketCap': 7642201000,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'DIREXION SHARES ETF TRUST DAILY SEMICONDUCTOR BULL 3X SHS',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-01T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'SPXS',
#   'symbolId': 33944516,
#   'prevDayClosePrice': 7.92,
#   'highPrice52': 10.45,
#   'lowPrice52': 5.55,
#   'averageVol3Months': 77193094,
#   'averageVol20Days': 90495826,
#   'outstandingShares': 60027000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.08421,
#   'yield': 4.84263,
#   'exDate': '2025-03-25T00:00:00.000000-04:00',
#   'marketCap': 415386300,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'DIREXION SHARES ETF TRUST DAILY S&P 500 BEAR 3X SHS (R/S)',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-01T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'TQQQ',
#   'symbolId': 32959,
#   'prevDayClosePrice': 50.3,
#   'highPrice52': 93.7892,
#   'lowPrice52': 48.8,
#   'averageVol3Months': 72013502,
#   'averageVol20Days': 103711570,
#   'outstandingShares': 343600000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.19773,
#   'yield': 1.64547,
#   'exDate': '2025-03-26T00:00:00.000000-04:00',
#   'marketCap': 20591948000,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NASDAQ',
#   'description': 'PROSHARES TRUST ULTRAPRO QQQ USD',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-01T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'TSLZ',
#   'symbolId': 50833351,
#   'prevDayClosePrice': 3.86,
#   'highPrice52': 60.6469,
#   'lowPrice52': 1.8501,
#   'averageVol3Months': 69746661,
#   'averageVol20Days': 81370711,
#   'outstandingShares': 27270000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.05187,
#   'yield': 1.4947,
#   'exDate': '2024-12-24T00:00:00.000000-05:00',
#   'marketCap': 94626900,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'BATS',
#   'description': 'ETF OPPORTUNITIES TR T-REX 2X INVERSE TESLA DAILY TARGET ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2024-12-26T00:00:00.000000-05:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'SQQQ',
#   'symbolId': 57647974,
#   'prevDayClosePrice': 42.53,
#   'highPrice52': 64.95,
#   'lowPrice52': 26.2146,
#   'averageVol3Months': 70714317,
#   'averageVol20Days': 88971916,
#   'outstandingShares': 67818000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.4823,
#   'yield': 7.78383,
#   'exDate': '2025-03-26T00:00:00.000000-04:00',
#   'marketCap': 2482127300,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NASDAQ',
#   'description': 'PROSHARES ULTRAPRO SHORT QQQ',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-01T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'MSTU',
#   'symbolId': 56711606,
#   'prevDayClosePrice': 5.16,
#   'highPrice52': 31.5,
#   'lowPrice52': 2.406,
#   'averageVol3Months': 63421421,
#   'averageVol20Days': 84324329,
#   'outstandingShares': 215750000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0,
#   'yield': 0,
#   'exDate': None,
#   'marketCap': 1380800000,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'BATS',
#   'description': 'T-REX 2X LONG MSTR DAILY TARGET ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': None,
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'NVDQ',
#   'symbolId': 55548492,
#   'prevDayClosePrice': 4.22,
#   'highPrice52': 18.75,
#   'lowPrice52': 2.44,
#   'averageVol3Months': 55998236,
#   'averageVol20Days': 48133250,
#   'outstandingShares': 10731000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.15241,
#   'yield': 4.16977,
#   'exDate': '2024-12-24T00:00:00.000000-05:00',
#   'marketCap': 39223600,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'BATS',
#   'description': 'ETF OPPORTUNITIES TR T REX 2X INVERSE NVIDIA DAILY TARGET ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2024-12-26T00:00:00.000000-05:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'SPY',
#   'symbolId': 34987,
#   'prevDayClosePrice': 536.7,
#   'highPrice52': 613.23,
#   'lowPrice52': 493.86,
#   'averageVol3Months': 57437516,
#   'averageVol20Days': 70917973,
#   'outstandingShares': 1059432000,
#   'eps': None,
#   'pe': None,
#   'dividend': 1.69553,
#   'yield': 1.26933,
#   'exDate': '2025-03-21T00:00:00.000000-04:00',
#   'marketCap': 598070618100,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'SPDR S&P500 ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-30T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'FXI',
#   'symbolId': 23787,
#   'prevDayClosePrice': 35.22,
#   'highPrice52': 38.73,
#   'lowPrice52': 23.615,
#   'averageVol3Months': 50740467,
#   'averageVol20Days': 43949311,
#   'outstandingShares': 209850000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.4511,
#   'yield': 1.50785,
#   'exDate': '2024-12-17T00:00:00.000000-05:00',
#   'marketCap': 7458069000,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'ISHARES TRUST CHINA LARGE-CAP ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2024-12-20T00:00:00.000000-05:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'XLF',
#   'symbolId': 35762,
#   'prevDayClosePrice': 47.69,
#   'highPrice52': 52.635,
#   'lowPrice52': 39.53,
#   'averageVol3Months': 48059578,
#   'averageVol20Days': 51172791,
#   'outstandingShares': 1045395000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.17878,
#   'yield': 1.4217,
#   'exDate': '2025-03-24T00:00:00.000000-04:00',
#   'marketCap': 52437034600,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'SELECT SECTOR SPDR TRUST AMEX FINANCIAL SELECT INDEX USD DIS',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-03-26T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'IBIT',
#   'symbolId': 52317225,
#   'prevDayClosePrice': 46.57,
#   'highPrice52': 61.75,
#   'lowPrice52': 28.23,
#   'averageVol3Months': 44975405,
#   'averageVol20Days': 37449929,
#   'outstandingShares': 1013480000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0,
#   'yield': 0,
#   'exDate': None,
#   'marketCap': 50076046800,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NASDAQ',
#   'description': 'ISHARES BITCOIN TRUST ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': None,
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'SOXS',
#   'symbolId': 54019649,
#   'prevDayClosePrice': 36.81,
#   'highPrice52': 46.84,
#   'lowPrice52': 16.35,
#   'averageVol3Months': 44841121,
#   'averageVol20Days': 37109603,
#   'outstandingShares': 16387000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.18461,
#   'yield': 3.51079,
#   'exDate': '2025-03-25T00:00:00.000000-04:00',
#   'marketCap': 464721800,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'DIREXION SHARES ETF TRUST DAILY SEMICONDUCTOR BEAR 3X SHS (R/S)',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-01T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'ETHU',
#   'symbolId': 54875261,
#   'prevDayClosePrice': 1.73,
#   'highPrice52': 16.16,
#   'lowPrice52': 1.67,
#   'averageVol3Months': 38770736,
#   'averageVol20Days': 40270377,
#   'outstandingShares': 225860000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.01,
#   'yield': 3.61496,
#   'exDate': '2025-03-27T00:00:00.000000-04:00',
#   'marketCap': 452849300,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'BATS',
#   'description': '2X ETHER ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-03-28T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'QQQ',
#   'symbolId': 21806473,
#   'prevDayClosePrice': 450.66,
#   'highPrice52': 540.81,
#   'lowPrice52': 413.07,
#   'averageVol3Months': 38318606,
#   'averageVol20Days': 46374505,
#   'outstandingShares': 633700000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.71571,
#   'yield': 0.62769,
#   'exDate': '2025-03-24T00:00:00.000000-04:00',
#   'marketCap': 301736255000,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NASDAQ',
#   'description': 'INVESCO QQQ TRUST UNIT SER 1',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-30T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'HYG',
#   'symbolId': 23879,
#   'prevDayClosePrice': 77.87,
#   'highPrice52': 80.37,
#   'lowPrice52': 75.59,
#   'averageVol3Months': 39057520,
#   'averageVol20Days': 52644077,
#   'outstandingShares': 199500000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.3824,
#   'yield': 5.864,
#   'exDate': '2025-04-01T00:00:00.000000-04:00',
#   'marketCap': 15730575000,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'ISHARES TRUST IBOXX USD HIGH YIELD CORPORATE BOND ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-04T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'TLT',
#   'symbolId': 23803,
#   'prevDayClosePrice': 91.85,
#   'highPrice52': 101.64,
#   'lowPrice52': 84.89,
#   'averageVol3Months': 35937394,
#   'averageVol20Days': 34007423,
#   'outstandingShares': 569900000,
#   'eps': None,
#   'pe': 22.19175,
#   'dividend': 0.32558,
#   'yield': 4.1177,
#   'exDate': '2025-04-01T00:00:00.000000-04:00',
#   'marketCap': 52105957000,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NASDAQ',
#   'description': 'ISHARES TRUST 20+ YR TREAS BD ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-04T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'PSLV',
#   'symbolId': 37034,
#   'prevDayClosePrice': 10.89,
#   'highPrice52': 11.77,
#   'lowPrice52': 8.81,
#   'averageVol3Months': 33730184,
#   'averageVol20Days': 45463389,
#   'outstandingShares': 520394000,
#   'eps': 1.65,
#   'pe': 7.0303,
#   'dividend': 0,
#   'yield': 0,
#   'exDate': None,
#   'marketCap': 6036565500,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'SPROTT PHYSICAL SILVER TRUST',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': None,
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': False,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': 'FinancialServices',
#   'industryGroup': 'Undefined',
#   'industrySubgroup': 'Undefined'},
#  {'symbol': 'IWM',
#   'symbolId': 23826,
#   'prevDayClosePrice': 189.65,
#   'highPrice52': 243.69,
#   'lowPrice52': 189.2,
#   'averageVol3Months': 28337145,
#   'averageVol20Days': 32622570,
#   'outstandingShares': 313900000,
#   'eps': None,
#   'pe': 250.19753,
#   'dividend': 0.45985,
#   'yield': 1.21793,
#   'exDate': '2025-03-18T00:00:00.000000-04:00',
#   'marketCap': 63614974000,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'ISHARES TRUST RUSSELL 2000 ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-03-21T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'TZA',
#   'symbolId': 34856857,
#   'prevDayClosePrice': 19.38,
#   'highPrice52': 22.29,
#   'lowPrice52': 9.84,
#   'averageVol3Months': 27352112,
#   'averageVol20Days': 23751618,
#   'outstandingShares': 17023000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.23778,
#   'yield': 4.32502,
#   'exDate': '2025-03-25T00:00:00.000000-04:00',
#   'marketCap': 276280000,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'DIREXION SHARES ETF TRUST DIREXION DILY SMALL CAP BR 3X SHS (R/S)',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-01T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'EEM',
#   'symbolId': 23791,
#   'prevDayClosePrice': 42.97,
#   'highPrice52': 47.44,
#   'lowPrice52': 39.39,
#   'averageVol3Months': 25976419,
#   'averageVol20Days': 23673268,
#   'outstandingShares': 380250000,
#   'eps': None,
#   'pe': 79.81818,
#   'dividend': 0.72737,
#   'yield': 2.31714,
#   'exDate': '2024-12-17T00:00:00.000000-05:00',
#   'marketCap': 16692974999,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'ISHARES TRUST MSCI EMG MKTS ETF USD DIS',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2024-12-20T00:00:00.000000-05:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'KWEB',
#   'symbolId': 4252331,
#   'prevDayClosePrice': 34.56,
#   'highPrice52': 39.17,
#   'lowPrice52': 24.68,
#   'averageVol3Months': 25812110,
#   'averageVol20Days': 21881983,
#   'outstandingShares': 231000000,
#   'eps': None,
#   'pe': None,
#   'dividend': 1.02494,
#   'yield': 2.93176,
#   'exDate': '2024-12-17T00:00:00.000000-05:00',
#   'marketCap': 8075760000,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'KRANESHARES TRUST CSI CHINA INTERNET ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2024-12-18T00:00:00.000000-05:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'LQD',
#   'symbolId': 23792,
#   'prevDayClosePrice': 108.9,
#   'highPrice52': 114.07,
#   'lowPrice52': 104.14,
#   'averageVol3Months': 26398877,
#   'averageVol20Days': 28876880,
#   'outstandingShares': 276100000,
#   'eps': None,
#   'pe': 21.14757,
#   'dividend': 0.41678,
#   'yield': 4.38778,
#   'exDate': '2025-04-01T00:00:00.000000-04:00',
#   'marketCap': 30070051000,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'ISHARES TRUST IBOXX USD INVESTMENT GRADE CORP BOND ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-04T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'FAZ',
#   'symbolId': 34856837,
#   'prevDayClosePrice': 6.35,
#   'highPrice52': 11.92,
#   'lowPrice52': 4.97,
#   'averageVol3Months': 25781538,
#   'averageVol20Days': 32353462,
#   'outstandingShares': 17553000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.10318,
#   'yield': 7.10127,
#   'exDate': '2025-03-25T00:00:00.000000-04:00',
#   'marketCap': 96719000,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'DIREXION SHARES ETF TRUST DIREXION DAILY FINL BR 3X SH NEW 21(R/S)',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-01T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'NVDL',
#   'symbolId': 45662774,
#   'prevDayClosePrice': 32.45,
#   'highPrice52': 91.7,
#   'lowPrice52': 28.2901,
#   'averageVol3Months': 25225664,
#   'averageVol20Days': 23415310,
#   'outstandingShares': 98180000,
#   'eps': None,
#   'pe': None,
#   'dividend': 1.68524,
#   'yield': 0,
#   'exDate': '2023-12-27T00:00:00.000000-05:00',
#   'marketCap': 3768148600,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NASDAQ',
#   'description': 'GRANITESHARES ETF TRUST 2X LONG NVDA DAILY ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2023-12-29T00:00:00.000000-05:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'EWZ',
#   'symbolId': 23751,
#   'prevDayClosePrice': 26.33,
#   'highPrice52': 33,
#   'lowPrice52': 22.26,
#   'averageVol3Months': 22839655,
#   'averageVol20Days': 22162891,
#   'outstandingShares': 127300000,
#   'eps': None,
#   'pe': None,
#   'dividend': 1.09197,
#   'yield': 7.67531,
#   'exDate': '2024-12-17T00:00:00.000000-05:00',
#   'marketCap': 3327622000,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'ISHARES INC MSCI BRAZIL ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2024-12-20T00:00:00.000000-05:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'MSTZ',
#   'symbolId': 58491093,
#   'prevDayClosePrice': 14.03,
#   'highPrice52': 513.8,
#   'lowPrice52': 10.2998,
#   'averageVol3Months': 22679314,
#   'averageVol20Days': 28918417,
#   'outstandingShares': 12460000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0,
#   'yield': 0,
#   'exDate': None,
#   'marketCap': 146778800,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'BATS',
#   'description': 'T-REX 2X INVERSE MSTR DAILY TARGET ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': None,
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'UVXY',
#   'symbolId': 53925369,
#   'prevDayClosePrice': 30.88,
#   'highPrice52': 65.87,
#   'lowPrice52': 17.265,
#   'averageVol3Months': 20878149,
#   'averageVol20Days': 21739537,
#   'outstandingShares': 13794000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0,
#   'yield': 0,
#   'exDate': None,
#   'marketCap': 311046600,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'BATS',
#   'description': 'PROSHARES ULTRA VIX SHORT-TERM FUTURES ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': None,
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'SLV',
#   'symbolId': 23969,
#   'prevDayClosePrice': 28.89,
#   'highPrice52': 31.8,
#   'lowPrice52': 23.87,
#   'averageVol3Months': 20572121,
#   'averageVol20Days': 22496442,
#   'outstandingShares': 492150000,
#   'eps': None,
#   'pe': 21.97143,
#   'dividend': 0,
#   'yield': 0,
#   'exDate': None,
#   'marketCap': 15138534000,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'ISHARES SILVER TRUST ISHARES',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': None,
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'GDX',
#   'symbolId': 13683881,
#   'prevDayClosePrice': 45.72,
#   'highPrice52': 46.94,
#   'lowPrice52': 32.2,
#   'averageVol3Months': 18351168,
#   'averageVol20Days': 19095560,
#   'outstandingShares': 323003000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.4025,
#   'yield': 0.87959,
#   'exDate': '2024-12-23T00:00:00.000000-05:00',
#   'marketCap': 14780594400,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'VANECK ETF TR VANECK GOLD MINERS ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2024-12-24T00:00:00.000000-05:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'LABD',
#   'symbolId': 31984585,
#   'prevDayClosePrice': 10.35,
#   'highPrice52': 11.41,
#   'lowPrice52': 4.78,
#   'averageVol3Months': 16705597,
#   'averageVol20Days': 10516759,
#   'outstandingShares': 4416000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.05463,
#   'yield': 3.45416,
#   'exDate': '2025-03-25T00:00:00.000000-04:00',
#   'marketCap': 41908100,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'DIREXION SHARES ETF TRUST DAILY S&P BIOTECH BEAR 3X SHS NEW(R/S)',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-01T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'NVDX',
#   'symbolId': 50833348,
#   'prevDayClosePrice': 6.79,
#   'highPrice52': 22.263,
#   'lowPrice52': 6.75,
#   'averageVol3Months': 16019650,
#   'averageVol20Days': 14866181,
#   'outstandingShares': 57190000,
#   'eps': None,
#   'pe': None,
#   'dividend': 2.16776,
#   'yield': 0,
#   'exDate': '2024-12-24T00:00:00.000000-05:00',
#   'marketCap': 457520000,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'BATS',
#   'description': 'ETF OPPORTUNITIES TR T REX 2X LONG NVIDIA DAILY TARGET ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2024-12-26T00:00:00.000000-05:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'XLE',
#   'symbolId': 35761,
#   'prevDayClosePrice': 86.74,
#   'highPrice52': 98.97,
#   'lowPrice52': 82.75,
#   'averageVol3Months': 16272623,
#   'averageVol20Days': 16280455,
#   'outstandingShares': 357574000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.71633,
#   'yield': 3.03692,
#   'exDate': '2025-03-24T00:00:00.000000-04:00',
#   'marketCap': 33658459400,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'SELECT SECTOR SPDR TRUST ENERGY',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-03-26T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'AMDL',
#   'symbolId': 53652201,
#   'prevDayClosePrice': 4.24,
#   'highPrice52': 22.71,
#   'lowPrice52': 4.23,
#   'averageVol3Months': 15711059,
#   'averageVol20Days': 14909424,
#   'outstandingShares': 47630000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0,
#   'yield': 0,
#   'exDate': None,
#   'marketCap': 246723400,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NASDAQ',
#   'description': 'GRANITESHARES ETF TRUST GRANITE 2X LONG AMD DAILY ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': None,
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'SCHD',
#   'symbolId': 1262083,
#   'prevDayClosePrice': 26.73,
#   'highPrice52': 29.62,
#   'lowPrice52': 25.1767,
#   'averageVol3Months': 15518590,
#   'averageVol20Days': 17210282,
#   'outstandingShares': 2539550000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.2488,
#   'yield': 3.72982,
#   'exDate': '2025-03-26T00:00:00.000000-04:00',
#   'marketCap': 70777258500,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'SCHWAB STRATEGIC TR US DIVIDEND EQUITY ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-03-31T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'BKLN',
#   'symbolId': 21802129,
#   'prevDayClosePrice': 20.52,
#   'highPrice52': 21.24,
#   'lowPrice52': 20.52,
#   'averageVol3Months': 16308800,
#   'averageVol20Days': 24128572,
#   'outstandingShares': 389400000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.10781,
#   'yield': 8.17033,
#   'exDate': '2025-03-24T00:00:00.000000-04:00',
#   'marketCap': 8072262000,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'INVESCO EXCHANGE TRADED FD TR II SR LN ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-03-28T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'SDS',
#   'symbolId': 39925754,
#   'prevDayClosePrice': 23.07,
#   'highPrice52': 28.045,
#   'lowPrice52': 18.14,
#   'averageVol3Months': 13345970,
#   'averageVol20Days': 12581474,
#   'outstandingShares': 21756000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.23345,
#   'yield': 6.83946,
#   'exDate': '2025-03-26T00:00:00.000000-04:00',
#   'marketCap': 458621700,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'PROSHARES TRUST ULTRASHORT S&P 500 (POST REV SPLIT)',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-01T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'EFA',
#   'symbolId': 23806,
#   'prevDayClosePrice': 80.32,
#   'highPrice52': 85.185,
#   'lowPrice52': 73.91,
#   'averageVol3Months': 13163793,
#   'averageVol20Days': 15382242,
#   'outstandingShares': 702600000,
#   'eps': None,
#   'pe': 84.57732,
#   'dividend': 1.05717,
#   'yield': 2.98634,
#   'exDate': '2024-12-17T00:00:00.000000-05:00',
#   'marketCap': 57641304000,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'ISHARES TRUST MSCI EAFE ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2024-12-20T00:00:00.000000-05:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'TNA',
#   'symbolId': 16128,
#   'prevDayClosePrice': 24.68,
#   'highPrice52': 57.07,
#   'lowPrice52': 24.5,
#   'averageVol3Months': 13040457,
#   'averageVol20Days': 13854455,
#   'outstandingShares': 59050000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.10328,
#   'yield': 1.51864,
#   'exDate': '2025-03-25T00:00:00.000000-04:00',
#   'marketCap': 1808701500,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'DIREXION SHARES ETF TRUST DIREXION DAILY SMALL CAP BULL 3X SHS',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-01T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'NVDD',
#   'symbolId': 50264522,
#   'prevDayClosePrice': 7.73,
#   'highPrice52': 13.5,
#   'lowPrice52': 5.65,
#   'averageVol3Months': 12996263,
#   'averageVol20Days': 15902753,
#   'outstandingShares': 3975000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.04991,
#   'yield': 3.47434,
#   'exDate': '2025-03-25T00:00:00.000000-04:00',
#   'marketCap': 28500800,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NASDAQ',
#   'description': 'DIREXION SHARES ETF TRUST DAILY NVDA BEAR 1X SHS',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-01T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'SPXU',
#   'symbolId': 53919631,
#   'prevDayClosePrice': 28.35,
#   'highPrice52': 38.63,
#   'lowPrice52': 19.89,
#   'averageVol3Months': 12940353,
#   'averageVol20Days': 14174919,
#   'outstandingShares': 23439000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.2601,
#   'yield': 7.14152,
#   'exDate': '2025-03-26T00:00:00.000000-04:00',
#   'marketCap': 581753200,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'PROSHARES TRUST ULTRAPRO SHORT S&P 500 (REVERSE SPLIT)',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-01T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'XLP',
#   'symbolId': 35759,
#   'prevDayClosePrice': 82.02,
#   'highPrice52': 84.53,
#   'lowPrice52': 72.93,
#   'averageVol3Months': 12541683,
#   'averageVol20Days': 14656865,
#   'outstandingShares': 205522000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.41824,
#   'yield': 2.50336,
#   'exDate': '2025-03-24T00:00:00.000000-04:00',
#   'marketCap': 16760303500,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'SELECT SECTOR SPDR TRUST AMEX CONSUMER STAPLES INDEX',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-03-26T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'KRE',
#   'symbolId': 35061,
#   'prevDayClosePrice': 51.31,
#   'highPrice52': 69.14,
#   'lowPrice52': 45.46,
#   'averageVol3Months': 12836008,
#   'averageVol20Days': 14133433,
#   'outstandingShares': 61503000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.37816,
#   'yield': 2.73377,
#   'exDate': '2025-03-24T00:00:00.000000-04:00',
#   'marketCap': 3519177900,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'SPDR SERIES TRUST S&P REGIONAL BKG ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-03-26T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'VEA',
#   'symbolId': 40428,
#   'prevDayClosePrice': 50.08,
#   'highPrice52': 53.395,
#   'lowPrice52': 46.795,
#   'averageVol3Months': 12160779,
#   'averageVol20Days': 12942031,
#   'outstandingShares': 2835729000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.2422,
#   'yield': 3.04966,
#   'exDate': '2025-03-21T00:00:00.000000-04:00',
#   'marketCap': 145047529300,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'ARCA',
#   'description': 'VANGUARD TAX MANAGED FUND FTSE DEVELOPED MKTS ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-03-25T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'USHY',
#   'symbolId': 19304153,
#   'prevDayClosePrice': 36.29,
#   'highPrice52': 37.72,
#   'lowPrice52': 35.55,
#   'averageVol3Months': 12841079,
#   'averageVol20Days': 17547055,
#   'outstandingShares': 541250000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.21027,
#   'yield': 6.82406,
#   'exDate': '2025-04-01T00:00:00.000000-04:00',
#   'marketCap': 19885525000,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'BATS',
#   'description': 'ISHARES TRUST BROAD USD HIGH YIELD CORPORATE BD ETF',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-04T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'GOVT',
#   'symbolId': 1651704,
#   'prevDayClosePrice': 23.12,
#   'highPrice52': 23.689,
#   'lowPrice52': 22.08,
#   'averageVol3Months': 11887759,
#   'averageVol20Days': 18963269,
#   'outstandingShares': 1158800000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.07148,
#   'yield': 3.30175,
#   'exDate': '2025-04-01T00:00:00.000000-04:00',
#   'marketCap': 26594460000,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'BATS',
#   'description': 'ISHARES TRUST US TREASURY BOND ETF USD DIS',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-04T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': None,
#   'industryGroup': None,
#   'industrySubgroup': None},
#  {'symbol': 'TSLS',
#   'symbolId': 43622031,
#   'prevDayClosePrice': 10.78,
#   'highPrice52': 31.83,
#   'lowPrice52': 6.8181,
#   'averageVol3Months': 11783982,
#   'averageVol20Days': 13217914,
#   'outstandingShares': 5775000,
#   'eps': None,
#   'pe': None,
#   'dividend': 0.07555,
#   'yield': 4.38622,
#   'exDate': '2025-03-25T00:00:00.000000-04:00',
#   'marketCap': 59078200,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NASDAQ',
#   'description': 'DIREXION SHARES ETF TRUST DAILY TSLA BEAR 1X SHS',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-01T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
# ...
#   'eps': 3.63,
#   'pe': 18.21488,
#   'dividend': 0.34,
#   'yield': 2.05687,
#   'exDate': '2025-01-31T00:00:00.000000-05:00',
#   'marketCap': 7779612700,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NYSE',
#   'description': 'SMITH A O CORP',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-02-18T00:00:00.000000-05:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': 'Industrial',
#   'industryGroup': 'Undefined',
#   'industrySubgroup': 'Undefined'},
#  {'symbol': 'CRL',
#   'symbolId': 13093,
#   'prevDayClosePrice': 140.98,
#   'highPrice52': 264.705,
#   'lowPrice52': 138.7,
#   'averageVol3Months': 1169211,
#   'averageVol20Days': 1097481,
#   'outstandingShares': 51142000,
#   'eps': 0.2,
#   'pe': 746.4,
#   'dividend': 0,
#   'yield': 0,
#   'exDate': None,
#   'marketCap': 7634419100,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NYSE',
#   'description': 'CHARLES RIVER LABORATORIES',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': None,
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': 'Healthcare',
#   'industryGroup': 'Undefined',
#   'industrySubgroup': 'Undefined'},
#  {'symbol': 'LW',
#   'symbolId': 15657148,
#   'prevDayClosePrice': 59.57,
#   'highPrice52': 89.51,
#   'lowPrice52': 47.9,
#   'averageVol3Months': 2803064,
#   'averageVol20Days': 2948672,
#   'outstandingShares': 142641000,
#   'eps': 4.51,
#   'pe': 12.00665,
#   'dividend': 0.37,
#   'yield': 2.73315,
#   'exDate': '2025-05-02T00:00:00.000000-04:00',
#   'marketCap': 7723993700,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NYSE',
#   'description': 'LAMB WESTON HLDGS INC',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-05-30T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': 'ConsumerDefensive',
#   'industryGroup': 'Undefined',
#   'industrySubgroup': 'Undefined'},
#  {'symbol': 'GNRC',
#   'symbolId': 19855,
#   'prevDayClosePrice': 115.64,
#   'highPrice52': 195.94,
#   'lowPrice52': 115.4,
#   'averageVol3Months': 848609,
#   'averageVol20Days': 817746,
#   'outstandingShares': 59614000,
#   'eps': 5.39,
#   'pe': 23.78108,
#   'dividend': 0,
#   'yield': 0,
#   'exDate': None,
#   'marketCap': 7641325700,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NYSE',
#   'description': 'GENERAC HLDGS INC',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': None,
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': 'Industrial',
#   'industryGroup': 'Undefined',
#   'industrySubgroup': 'Undefined'},
#  {'symbol': 'WYNN',
#   'symbolId': 42216,
#   'prevDayClosePrice': 72.88,
#   'highPrice52': 110.38,
#   'lowPrice52': 71.63,
#   'averageVol3Months': 2616292,
#   'averageVol20Days': 2302308,
#   'outstandingShares': 106167000,
#   'eps': 4.35,
#   'pe': 18.74483,
#   'dividend': 0.25,
#   'yield': 1.22639,
#   'exDate': '2025-02-24T00:00:00.000000-05:00',
#   'marketCap': 8656883900,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NASDAQ',
#   'description': 'WYNN RESORTS LTD',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-03-05T00:00:00.000000-05:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': 'ConsumerCyclical',
#   'industryGroup': 'Undefined',
#   'industrySubgroup': 'Undefined'},
#  {'symbol': 'FRT',
#   'symbolId': 39832692,
#   'prevDayClosePrice': 92.68,
#   'highPrice52': 118.34,
#   'lowPrice52': 92.51,
#   'averageVol3Months': 775717,
#   'averageVol20Days': 893076,
#   'outstandingShares': 85681000,
#   'eps': 3.42,
#   'pe': 28.97076,
#   'dividend': 1.1,
#   'yield': 4.44086,
#   'exDate': '2025-04-01T00:00:00.000000-04:00',
#   'marketCap': 8489235199,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NYSE',
#   'description': 'FEDERAL REALTY INVESTMENT TRUST',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-15T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': 'RealEstate',
#   'industryGroup': 'Undefined',
#   'industrySubgroup': 'Undefined'},
#  {'symbol': 'PARA',
#   'symbolId': 28120205,
#   'prevDayClosePrice': 11.48,
#   'highPrice52': 14.54,
#   'lowPrice52': 9.54,
#   'averageVol3Months': 9331417,
#   'averageVol20Days': 9751664,
#   'outstandingShares': 630008000,
#   'eps': -9.36,
#   'pe': None,
#   'dividend': 0.05,
#   'yield': 1.68067,
#   'exDate': '2025-03-17T00:00:00.000000-04:00',
#   'marketCap': 7497090800,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NASDAQ',
#   'description': 'PARAMOUNT GLOBAL',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-01T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': 'CommunicationServices',
#   'industryGroup': 'Undefined',
#   'industrySubgroup': 'Undefined'},
#  {'symbol': 'FOX',
#   'symbolId': 25053791,
#   'prevDayClosePrice': 47.9,
#   'highPrice52': 55,
#   'lowPrice52': 27.625,
#   'averageVol3Months': 1248346,
#   'averageVol20Days': 1416017,
#   'outstandingShares': 235581000,
#   'eps': 4.66,
#   'pe': 11.37339,
#   'dividend': 0.27,
#   'yield': 1.01887,
#   'exDate': '2025-03-05T00:00:00.000000-05:00',
#   'marketCap': 12485794300,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NASDAQ',
#   'description': 'FOX CORP',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-03-26T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': 'CommunicationServices',
#   'industryGroup': 'Undefined',
#   'industrySubgroup': 'Undefined'},
#  {'symbol': 'IVZ',
#   'symbolId': 44078,
#   'prevDayClosePrice': 13.83,
#   'highPrice52': 19.55,
#   'lowPrice52': 13.74,
#   'averageVol3Months': 4823062,
#   'averageVol20Days': 5916598,
#   'outstandingShares': 447602000,
#   'eps': 1.18,
#   'pe': 13.29661,
#   'dividend': 0.205,
#   'yield': 5.22626,
#   'exDate': '2025-02-14T00:00:00.000000-05:00',
#   'marketCap': 7022872200,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NYSE',
#   'description': 'INVESCO LTD',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-03-04T00:00:00.000000-05:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': 'FinancialServices',
#   'industryGroup': 'Undefined',
#   'industrySubgroup': 'Undefined'},
#  {'symbol': 'DVA',
#   'symbolId': 15649,
#   'prevDayClosePrice': 153.73,
#   'highPrice52': 179.6,
#   'lowPrice52': 125.64,
#   'averageVol3Months': 877508,
#   'averageVol20Days': 857544,
#   'outstandingShares': 80000000,
#   'eps': 10.73,
#   'pe': 14.37931,
#   'dividend': 0,
#   'yield': 0,
#   'exDate': None,
#   'marketCap': 12343200000,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NYSE',
#   'description': 'DAVITA INC',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': None,
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': 'Healthcare',
#   'industryGroup': 'Undefined',
#   'industrySubgroup': 'Undefined'},
#  {'symbol': 'MGM',
#   'symbolId': 26173,
#   'prevDayClosePrice': 27.9,
#   'highPrice52': 47.45,
#   'lowPrice52': 27.5001,
#   'averageVol3Months': 5464951,
#   'averageVol20Days': 6314671,
#   'outstandingShares': 285551000,
#   'eps': 2.4,
#   'pe': 12.8125,
#   'dividend': 0.0025,
#   'yield': 0,
#   'exDate': '2022-12-08T00:00:00.000000-05:00',
#   'marketCap': 8780681100,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NYSE',
#   'description': 'MGM RESORTS INTERNATIONAL',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2022-12-15T00:00:00.000000-05:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': 'ConsumerCyclical',
#   'industryGroup': 'Undefined',
#   'industrySubgroup': 'Undefined'},
#  {'symbol': 'BF.B',
#   'symbolId': 11173,
#   'prevDayClosePrice': 32.91,
#   'highPrice52': 52.2438,
#   'lowPrice52': 30.48,
#   'averageVol3Months': 3427552,
#   'averageVol20Days': 3474624,
#   'outstandingShares': 303540000,
#   'eps': 2.08,
#   'pe': 16.59135,
#   'dividend': 0.2265,
#   'yield': 2.62533,
#   'exDate': '2025-03-07T00:00:00.000000-05:00',
#   'marketCap': 10475164100,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NYSE',
#   'description': 'BROWN-FORMAN CORP',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-01T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': 'ConsumerDefensive',
#   'industryGroup': 'Undefined',
#   'industrySubgroup': 'Undefined'},
#  {'symbol': 'MHK',
#   'symbolId': 27780,
#   'prevDayClosePrice': 107.84,
#   'highPrice52': 164.289,
#   'lowPrice52': 104.88,
#   'averageVol3Months': 784451,
#   'averageVol20Days': 802824,
#   'outstandingShares': 62587000,
#   'eps': 8.14,
#   'pe': 14.39189,
#   'dividend': 0,
#   'yield': 0,
#   'exDate': None,
#   'marketCap': 7332093800,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NYSE',
#   'description': 'MOHAWK INDUSTRIES',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': None,
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': 'ConsumerCyclical',
#   'industryGroup': 'Undefined',
#   'industrySubgroup': 'Undefined'},
#  {'symbol': 'BEN',
#   'symbolId': 19294,
#   'prevDayClosePrice': 17.95,
#   'highPrice52': 28.08,
#   'lowPrice52': 17.93,
#   'averageVol3Months': 4247798,
#   'averageVol20Days': 4193732,
#   'outstandingShares': 525398000,
#   'eps': 0.64,
#   'pe': 30.35938,
#   'dividend': 0.32,
#   'yield': 6.58775,
#   'exDate': '2025-03-31T00:00:00.000000-04:00',
#   'marketCap': 10208482700,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NYSE',
#   'description': 'FRANKLIN RESOURCES INC',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-11T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': 'FinancialServices',
#   'industryGroup': 'Undefined',
#   'industrySubgroup': 'Undefined'},
#  {'symbol': 'CZR',
#   'symbolId': 31476150,
#   'prevDayClosePrice': 23.77,
#   'highPrice52': 45.93,
#   'lowPrice52': 23.465,
#   'averageVol3Months': 5321523,
#   'averageVol20Days': 6287924,
#   'outstandingShares': 212013000,
#   'eps': -1.29,
#   'pe': None,
#   'dividend': 0,
#   'yield': 0,
#   'exDate': None,
#   'marketCap': 5569589500,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NASDAQ',
#   'description': 'CAESARS ENTERTAINMENT INC NEW',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': None,
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': 'ConsumerCyclical',
#   'industryGroup': 'Undefined',
#   'industrySubgroup': 'Undefined'},
#  {'symbol': 'NWS',
#   'symbolId': 3954441,
#   'prevDayClosePrice': 29.43,
#   'highPrice52': 35.25,
#   'lowPrice52': 23.99,
#   'averageVol3Months': 853849,
#   'averageVol20Days': 1003542,
#   'outstandingShares': 189341000,
#   'eps': 0.75,
#   'pe': 40.73333,
#   'dividend': 0.1,
#   'yield': 0.65466,
#   'exDate': '2025-03-12T00:00:00.000000-04:00',
#   'marketCap': 5784363100,
#   'tradeUnit': 1,
#   'optionType': None,
#   'optionDurationType': None,
#   'optionRoot': '',
#   'optionContractDeliverables': {'underlyings': [], 'cashInLieu': 0},
#   'optionExerciseType': None,
#   'listingExchange': 'NASDAQ',
#   'description': 'NEWS CORP NEW',
#   'securityType': 'Stock',
#   'optionExpiryDate': None,
#   'dividendDate': '2025-04-09T00:00:00.000000-04:00',
#   'optionStrikePrice': None,
#   'isTradable': True,
#   'isQuotable': True,
#   'hasOptions': True,
#   'currency': 'USD',
#   'minTicks': [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1, 'minTick': 0.01}],
#   'industrySector': 'CommunicationServices',
#   'industryGroup': 'Undefined',
#   'industrySubgroup': 'Undefined'}]

# %%
local_symbols.import_symbols_from_csv('../lists/S&P500.csv')
# Out:
# Symbol AAPL saved to local database
# Symbol MSFT saved to local database
# Symbol NVDA saved to local database
# Symbol AMZN saved to local database
# Symbol META saved to local database
# Symbol BRK.B saved to local database
# Symbol GOOGL saved to local database
# Symbol AVGO saved to local database
# Symbol GOOG saved to local database
# Symbol TSLA saved to local database
# Symbol JPM saved to local database
# Symbol LLY saved to local database
# Symbol V saved to local database
# Symbol XOM saved to local database
# Symbol UNH saved to local database
# Symbol MA saved to local database
# Symbol COST saved to local database
# Symbol PG saved to local database
# Symbol JNJ saved to local database
# Symbol NFLX saved to local database
# Symbol WMT saved to local database
# Symbol ABBV saved to local database
# Symbol HD saved to local database
# Symbol CVX saved to local database
# Symbol KO saved to local database
# Symbol BAC saved to local database
# Symbol CRM saved to local database
# Symbol PM saved to local database
# Symbol CSCO saved to local database
# Symbol WFC saved to local database
# Symbol ABT saved to local database
# Symbol IBM saved to local database
# Symbol MRK saved to local database
# Symbol ORCL saved to local database
# Symbol MCD saved to local database
# Symbol LIN saved to local database
# Symbol GE saved to local database
# Symbol PEP saved to local database
# Symbol T saved to local database
# Symbol ACN saved to local database
# Symbol VZ saved to local database
# Symbol TMO saved to local database
# Symbol DIS saved to local database
# Symbol ISRG saved to local database
# Symbol RTX saved to local database
# Symbol PLTR saved to local database
# Symbol INTU saved to local database
# Symbol GS saved to local database
# Symbol QCOM saved to local database
# Symbol AMGN saved to local database
# Symbol ADBE saved to local database
# Symbol AMD saved to local database
# Symbol PGR saved to local database
# Symbol NOW saved to local database
# Symbol TXN saved to local database
# Symbol SPGI saved to local database
# Symbol CAT saved to local database
# Symbol BKNG saved to local database
# Symbol UBER saved to local database
# Symbol AXP saved to local database
# Symbol BSX saved to local database
# Symbol NEE saved to local database
# Symbol MS saved to local database
# Symbol PFE saved to local database
# Symbol UNP saved to local database
# Symbol GILD saved to local database
# Symbol CMCSA saved to local database
# Symbol BLK saved to local database
# Symbol HON saved to local database
# Symbol TJX saved to local database
# Symbol COP saved to local database
# Symbol SCHW saved to local database
# Symbol C saved to local database
# Symbol LOW saved to local database
# Symbol DHR saved to local database
# Symbol BA saved to local database
# Symbol TMUS saved to local database
# Symbol SYK saved to local database
# Symbol FI saved to local database
# Symbol VRTX saved to local database
# Symbol ADP saved to local database
# Symbol BMY saved to local database
# Symbol MMC saved to local database
# Symbol DE saved to local database
# Symbol AMAT saved to local database
# Symbol MDT saved to local database
# Symbol PANW saved to local database
# Symbol CB saved to local database
# Symbol SBUX saved to local database
# Symbol ETN saved to local database
# Symbol PLD saved to local database
# Symbol BX saved to local database
# Symbol AMT saved to local database
# Symbol MO saved to local database
# Symbol ELV saved to local database
# Symbol SO saved to local database
# Symbol ADI saved to local database
# Symbol ICE saved to local database
# Symbol INTC saved to local database
# Symbol MU saved to local database
# Symbol CME saved to local database
# Symbol DUK saved to local database
# Symbol LMT saved to local database
# Symbol WELL saved to local database
# Symbol LRCX saved to local database
# Symbol KLAC saved to local database
# Symbol CI saved to local database
# Symbol AJG saved to local database
# Symbol MDLZ saved to local database
# Symbol CRWD saved to local database
# Symbol AON saved to local database
# Symbol CVS saved to local database
# Symbol WM saved to local database
# Symbol MCK saved to local database
# Symbol GEV saved to local database
# Symbol ORLY saved to local database
# Symbol SHW saved to local database
# Symbol UPS saved to local database
# Symbol ANET saved to local database
# Symbol MMM saved to local database
# Symbol APH saved to local database
# Symbol EQIX saved to local database
# Symbol PH saved to local database
# Symbol KKR saved to local database
# Symbol TDG saved to local database
# Symbol CL saved to local database
# Symbol TT saved to local database
# Symbol NKE saved to local database
# Symbol ZTS saved to local database
# Symbol MSI saved to local database
# Symbol WMB saved to local database
# Symbol EOG saved to local database
# Symbol MCO saved to local database
# Symbol CTAS saved to local database
# Symbol CDNS saved to local database
# Symbol NOC saved to local database
# Symbol PNC saved to local database
# Symbol GD saved to local database
# Symbol COF saved to local database
# Symbol CMG saved to local database
# Symbol REGN saved to local database
# Symbol SNPS saved to local database
# Symbol ITW saved to local database
# Symbol USB saved to local database
# Symbol BDX saved to local database
# Symbol APD saved to local database
# Symbol PYPL saved to local database
# Symbol AZO saved to local database
# Symbol ECL saved to local database
# Symbol ROP saved to local database
# Symbol CEG saved to local database
# Symbol DASH saved to local database
# Symbol EMR saved to local database
# Symbol HCA saved to local database
# Symbol OKE saved to local database
# Symbol FTNT saved to local database
# Symbol APO saved to local database
# Symbol BK saved to local database
# Symbol TRV saved to local database
# Symbol SLB saved to local database
# Symbol AEP saved to local database
# Symbol CSX saved to local database
# Symbol ADSK saved to local database
# Symbol KMI saved to local database
# Symbol AFL saved to local database
# Symbol NEM saved to local database
# Symbol ALL saved to local database
# Symbol HLT saved to local database
# Symbol MAR saved to local database
# Symbol FCX saved to local database
# Symbol TFC saved to local database
# Symbol FDX saved to local database
# Symbol NSC saved to local database
# Symbol JCI saved to local database
# Symbol HWM saved to local database
# Symbol ABNB saved to local database
# Symbol AIG saved to local database
# Symbol CARR saved to local database
# Symbol PCAR saved to local database
# Symbol PSX saved to local database
# Symbol SPG saved to local database
# Symbol RCL saved to local database
# Symbol O saved to local database
# Symbol WDAY saved to local database
# Symbol CPRT saved to local database
# Symbol PAYX saved to local database
# Symbol RSG saved to local database
# Symbol NXPI saved to local database
# Symbol COR saved to local database
# Symbol TGT saved to local database
# Symbol PSA saved to local database
# Symbol KMB saved to local database
# Symbol D saved to local database
# Symbol GM saved to local database
# Symbol AMP saved to local database
# Symbol MET saved to local database
# Symbol EXC saved to local database
# Symbol MPC saved to local database
# Symbol KVUE saved to local database
# Symbol DLR saved to local database
# Symbol CCI saved to local database
# Symbol SRE saved to local database
# Symbol KR saved to local database
# Symbol FICO saved to local database
# Symbol FAST saved to local database
# Symbol HES saved to local database
# Symbol YUM saved to local database
# Symbol MSCI saved to local database
# Symbol GWW saved to local database
# Symbol TRGP saved to local database
# Symbol BKR saved to local database
# Symbol CTVA saved to local database
# Symbol CMI saved to local database
# Symbol DFS saved to local database
# Symbol EW saved to local database
# Symbol TEL saved to local database
# Symbol ROST saved to local database
# Symbol VRSK saved to local database
# Symbol VLO saved to local database
# Symbol PEG saved to local database
# Symbol MNST saved to local database
# Symbol KDP saved to local database
# Symbol URI saved to local database
# Symbol OTIS saved to local database
# Symbol XEL saved to local database
# Symbol VST saved to local database
# Symbol AME saved to local database
# Symbol FIS saved to local database
# Symbol PRU saved to local database
# Symbol LHX saved to local database
# Symbol F saved to local database
# Symbol CBRE saved to local database
# Symbol ED saved to local database
# Symbol AXON saved to local database
# Symbol CTSH saved to local database
# Symbol PCG saved to local database
# Symbol PWR saved to local database
# Symbol GEHC saved to local database
# Symbol SYY saved to local database
# Symbol ETR saved to local database
# Symbol ACGL saved to local database
# Symbol DHI saved to local database
# Symbol CHTR saved to local database
# Symbol HIG saved to local database
# Symbol GLW saved to local database
# Symbol WEC saved to local database
# Symbol IDXX saved to local database
# Symbol VICI saved to local database
# Symbol EA saved to local database
# Symbol TTWO saved to local database
# Symbol WTW saved to local database
# Symbol CSGP saved to local database
# Symbol GRMN saved to local database
# Symbol OXY saved to local database
# Symbol A saved to local database
# Symbol CAH saved to local database
# Symbol GIS saved to local database
# Symbol RMD saved to local database
# Symbol EBAY saved to local database
# Symbol IT saved to local database
# Symbol IR saved to local database
# Symbol HUM saved to local database
# Symbol EQT saved to local database
# Symbol LULU saved to local database
# Symbol EXR saved to local database
# Symbol NDAQ saved to local database
# Symbol DD saved to local database
# Symbol ODFL saved to local database
# Symbol WAB saved to local database
# Symbol VMC saved to local database
# Symbol AVB saved to local database
# Symbol EFX saved to local database
# Symbol CNC saved to local database
# Symbol VTR saved to local database
# Symbol FANG saved to local database
# Symbol MTB saved to local database
# Symbol BRO saved to local database
# Symbol IQV saved to local database
# Symbol TSCO saved to local database
# Symbol MLM saved to local database
# Symbol ROK saved to local database
# Symbol XYL saved to local database
# Symbol AWK saved to local database
# Symbol DTE saved to local database
# Symbol STZ saved to local database
# Symbol DELL saved to local database
# Symbol BR saved to local database
# Symbol NUE saved to local database
# Symbol IP saved to local database
# Symbol DAL saved to local database
# Symbol MPWR saved to local database
# Symbol ANSS saved to local database
# Symbol AEE saved to local database
# Symbol CHD saved to local database
# Symbol LEN saved to local database
# Symbol DXCM saved to local database
# Symbol PPL saved to local database
# Symbol KHC saved to local database
# Symbol FITB saved to local database
# Symbol MCHP saved to local database
# Symbol HPQ saved to local database
# Symbol KEYS saved to local database
# Symbol STT saved to local database
# Symbol PPG saved to local database
# Symbol RJF saved to local database
# Symbol GDDY saved to local database
# Symbol HSY saved to local database
# Symbol IRM saved to local database
# Symbol TPL saved to local database
# Symbol FTV saved to local database
# Symbol TYL saved to local database
# Symbol MTD saved to local database
# Symbol DVN saved to local database
# Symbol ATO saved to local database
# Symbol DOW saved to local database
# Symbol DRI saved to local database
# Symbol EQR saved to local database
# Symbol CPAY saved to local database
# Symbol GPN saved to local database
# Symbol DOV saved to local database
# Symbol VLTO saved to local database
# Symbol WBD saved to local database
# Symbol CBOE saved to local database
# Symbol CNP saved to local database
# Symbol SBAC saved to local database
# Symbol EXE saved to local database
# Symbol TDY saved to local database
# Symbol CINF saved to local database
# Symbol ADM saved to local database
# Symbol EIX saved to local database
# Symbol ES saved to local database
# Symbol UAL saved to local database
# Symbol ZBH saved to local database
# Symbol CMS saved to local database
# Symbol SW saved to local database
# Symbol STE saved to local database
# Symbol K saved to local database
# Symbol HAL saved to local database
# Symbol WAT saved to local database
# Symbol HBAN saved to local database
# Symbol NVR saved to local database
# Symbol WRB saved to local database
# Symbol CDW saved to local database
# Symbol CTRA saved to local database
# Symbol WY saved to local database
# Symbol PHM saved to local database
# Symbol MKC saved to local database
# Symbol FE saved to local database
# Symbol EXPE saved to local database
# Symbol VRSN saved to local database
# Symbol SYF saved to local database
# Symbol LYV saved to local database
# Symbol TROW saved to local database
# Symbol CCL saved to local database
# Symbol HPE saved to local database
# Symbol BIIB saved to local database
# Symbol LUV saved to local database
# Symbol INVH saved to local database
# Symbol IFF saved to local database
# Symbol RF saved to local database
# Symbol ESS saved to local database
# Symbol MAA saved to local database
# Symbol LH saved to local database
# Symbol WSM saved to local database
# Symbol NRG saved to local database
# Symbol NTRS saved to local database
# Symbol DG saved to local database
# Symbol DGX saved to local database
# Symbol NI saved to local database
# Symbol PTC saved to local database
# Symbol PODD saved to local database
# Symbol LYB saved to local database
# Symbol MOH saved to local database
# Symbol CLX saved to local database
# Symbol TSN saved to local database
# Symbol LII saved to local database
# Symbol STX saved to local database
# Symbol CFG saved to local database
# Symbol NTAP saved to local database
# Symbol HUBB saved to local database
# Symbol PFG saved to local database
# Symbol STLD saved to local database
# Symbol SNA saved to local database
# Symbol LDOS saved to local database
# Symbol PKG saved to local database
# Symbol BAX saved to local database
# Symbol FDS saved to local database
# Symbol SMCI saved to local database
# Symbol ON saved to local database
# Symbol ULTA saved to local database
# Symbol DECK saved to local database
# Symbol EXPD saved to local database
# Symbol COO saved to local database
# Symbol GPC saved to local database
# Symbol LNT saved to local database
# Symbol L saved to local database
# Symbol WST saved to local database
# Symbol OMC saved to local database
# Symbol TRMB saved to local database
# Symbol DPZ saved to local database
# Symbol KEY saved to local database
# Symbol EVRG saved to local database
# Symbol EG saved to local database
# Symbol BALL saved to local database
# Symbol EL saved to local database
# Symbol FFIV saved to local database
# Symbol ROL saved to local database
# Symbol DLTR saved to local database
# Symbol JBL saved to local database
# Symbol J saved to local database
# Symbol MAS saved to local database
# Symbol TPR saved to local database
# Symbol ZBRA saved to local database
# Symbol PNR saved to local database
# Symbol GEN saved to local database
# Symbol BBY saved to local database
# Symbol BLDR saved to local database
# Symbol AVY saved to local database
# Symbol KIM saved to local database
# Symbol ARE saved to local database
# Symbol DOC saved to local database
# Symbol AMCR saved to local database
# Symbol WDC saved to local database
# Symbol HOLX saved to local database
# Symbol IEX saved to local database
# Symbol APTV saved to local database
# Symbol CF saved to local database
# Symbol UDR saved to local database
# Symbol FSLR saved to local database
# Symbol TER saved to local database
# Symbol JKHY saved to local database
# Symbol LVS saved to local database
# Symbol TXT saved to local database
# Symbol CPT saved to local database
# Symbol RVTY saved to local database
# Symbol CAG saved to local database
# Symbol SJM saved to local database
# Symbol FOXA saved to local database
# Symbol POOL saved to local database
# Symbol AKAM saved to local database
# Symbol REG saved to local database
# Symbol KMX saved to local database
# Symbol CHRW saved to local database
# Symbol JNPR saved to local database
# Symbol SWK saved to local database
# Symbol JBHT saved to local database
# Symbol ALLE saved to local database
# Symbol ALGN saved to local database
# Symbol LKQ saved to local database
# Symbol GL saved to local database
# Symbol UHS saved to local database
# Symbol NDSN saved to local database
# Symbol PNW saved to local database
# Symbol AIZ saved to local database
# Symbol SOLV saved to local database
# Symbol ERIE saved to local database
# Symbol TAP saved to local database
# Symbol VTRS saved to local database
# Symbol SWKS saved to local database
# Symbol NWSA saved to local database
# Symbol PAYC saved to local database
# Symbol EMN saved to local database
# Symbol BG saved to local database
# Symbol TKO saved to local database
# Symbol IPG saved to local database
# Symbol HST saved to local database
# Symbol BXP saved to local database
# Symbol INCY saved to local database
# Symbol MRNA saved to local database
# Symbol EPAM saved to local database
# Symbol TECH saved to local database
# Symbol DAY saved to local database
# Symbol HRL saved to local database
# Symbol RL saved to local database
# Symbol AES saved to local database
# Symbol HSIC saved to local database
# Symbol MOS saved to local database
# Symbol ALB saved to local database
# Symbol NCLH saved to local database
# Symbol ENPH saved to local database
# Symbol MKTX saved to local database
# Symbol HAS saved to local database
# Symbol WBA saved to local database
# Symbol HII saved to local database
# Symbol CPB saved to local database
# Symbol MTCH saved to local database
# Symbol APA saved to local database
# Symbol AOS saved to local database
# Symbol CRL saved to local database
# Symbol LW saved to local database
# Symbol GNRC saved to local database
# Symbol WYNN saved to local database
# Symbol FRT saved to local database
# Symbol PARA saved to local database
# Symbol FOX saved to local database
# Symbol IVZ saved to local database
# Symbol DVA saved to local database
# Symbol MGM saved to local database
# Symbol BF.B saved to local database
# Symbol MHK saved to local database
# Symbol BEN saved to local database
# Symbol CZR saved to local database
# Symbol NWS saved to local database
# 503

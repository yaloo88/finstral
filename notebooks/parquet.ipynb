# %%
import sys
import datetime
from pathlib import Path
import pyarrow as pa
import pyarrow.parquet as pq
import os
import pandas as pd
import logging
sys.path.append(r'C:\Users\Administrator\finstral-1')
import qt_api.qt_api as qt
import src.local_symbols as local_symbols
import src.local_candles as local_candles

# %%
df = local_candles.prepare_parquet_autogluon(update_db=False)
# Out:
# Processing symbol: BRK.B
# Retrieved 27054 candles for BRK.B
# --------------------------------------------------
# Processing symbol: LLY
# Retrieved 25770 candles for LLY
# --------------------------------------------------
# Processing symbol: XOM
# Retrieved 28504 candles for XOM
# --------------------------------------------------
# Processing symbol: MA
# Retrieved 24467 candles for MA
# --------------------------------------------------
# Processing symbol: ABBV
# Retrieved 25373 candles for ABBV
# --------------------------------------------------
# Processing symbol: BAC
# Retrieved 31635 candles for BAC
# --------------------------------------------------
# Processing symbol: PM
# Retrieved 25196 candles for PM
# --------------------------------------------------
# Processing symbol: WFC
# Retrieved 27271 candles for WFC
# --------------------------------------------------
# Processing symbol: ABT
# Retrieved 24959 candles for ABT
# --------------------------------------------------
# Processing symbol: ORCL
# Retrieved 31494 candles for ORCL
# --------------------------------------------------
# Processing symbol: GE
# Retrieved 25922 candles for GE
# --------------------------------------------------
# Processing symbol: T
# Retrieved 31234 candles for T
# --------------------------------------------------
# Processing symbol: ACN
# Retrieved 24525 candles for ACN
# --------------------------------------------------
# Processing symbol: TMO
# Retrieved 23669 candles for TMO
# --------------------------------------------------
# Processing symbol: RTX
# Retrieved 25372 candles for RTX
# --------------------------------------------------
# Processing symbol: PGR
# Retrieved 24418 candles for PGR
# --------------------------------------------------
# Processing symbol: NOW
# Retrieved 23923 candles for NOW
# --------------------------------------------------
# Processing symbol: SPGI
# Retrieved 22110 candles for SPGI
# --------------------------------------------------
# Processing symbol: UBER
# Retrieved 35552 candles for UBER
# --------------------------------------------------
# Processing symbol: BSX
# Retrieved 25139 candles for BSX
# --------------------------------------------------
# Processing symbol: NEE
# Retrieved 25977 candles for NEE
# --------------------------------------------------
# Processing symbol: MS
# Retrieved 25923 candles for MS
# --------------------------------------------------
# Processing symbol: PFE
# Retrieved 38212 candles for PFE
# --------------------------------------------------
# Processing symbol: UNP
# Retrieved 24209 candles for UNP
# --------------------------------------------------
# Processing symbol: BLK
# Retrieved 19200 candles for BLK
# --------------------------------------------------
# Processing symbol: TJX
# Retrieved 24985 candles for TJX
# --------------------------------------------------
# Processing symbol: COP
# Retrieved 25671 candles for COP
# --------------------------------------------------
# Processing symbol: SCHW
# Retrieved 25798 candles for SCHW
# --------------------------------------------------
# Processing symbol: C
# Retrieved 28875 candles for C
# --------------------------------------------------
# Processing symbol: LOW
# Retrieved 24345 candles for LOW
# --------------------------------------------------
# Processing symbol: DHR
# Retrieved 24605 candles for DHR
# --------------------------------------------------
# Processing symbol: SYK
# Retrieved 22717 candles for SYK
# --------------------------------------------------
# Processing symbol: FI
# Retrieved 24392 candles for FI
# --------------------------------------------------
# Processing symbol: BMY
# Retrieved 26647 candles for BMY
# --------------------------------------------------
# Processing symbol: MMC
# Retrieved 23522 candles for MMC
# --------------------------------------------------
# Processing symbol: DE
# Retrieved 22850 candles for DE
# --------------------------------------------------
# Processing symbol: MDT
# Retrieved 25197 candles for MDT
# --------------------------------------------------
# Processing symbol: CB
# Retrieved 23267 candles for CB
# --------------------------------------------------
# Processing symbol: ETN
# Retrieved 24921 candles for ETN
# --------------------------------------------------
# Processing symbol: PLD
# Retrieved 24483 candles for PLD
# --------------------------------------------------
# Processing symbol: BX
# Retrieved 25112 candles for BX
# --------------------------------------------------
# Processing symbol: AMT
# Retrieved 24070 candles for AMT
# --------------------------------------------------
# Processing symbol: MO
# Retrieved 27740 candles for MO
# --------------------------------------------------
# Processing symbol: ELV
# Retrieved 22924 candles for ELV
# --------------------------------------------------
# Processing symbol: SO
# Retrieved 24726 candles for SO
# --------------------------------------------------
# Processing symbol: ICE
# Retrieved 24294 candles for ICE
# --------------------------------------------------
# Processing symbol: CME
# Retrieved 23483 candles for CME
# --------------------------------------------------
# Processing symbol: DUK
# Retrieved 24648 candles for DUK
# --------------------------------------------------
# Processing symbol: LMT
# Retrieved 23785 candles for LMT
# --------------------------------------------------
# Processing symbol: WELL
# Retrieved 24011 candles for WELL
# --------------------------------------------------
# Processing symbol: CI
# Retrieved 23016 candles for CI
# --------------------------------------------------
# Processing symbol: AJG
# Retrieved 22703 candles for AJG
# --------------------------------------------------
# Processing symbol: AON
# Retrieved 20366 candles for AON
# --------------------------------------------------
# Processing symbol: CVS
# Retrieved 27178 candles for CVS
# --------------------------------------------------
# Processing symbol: WM
# Retrieved 23424 candles for WM
# --------------------------------------------------
# Processing symbol: MCK
# Retrieved 18809 candles for MCK
# --------------------------------------------------
# Processing symbol: GEV
# Retrieved 26989 candles for GEV
# --------------------------------------------------
# Processing symbol: UPS
# Retrieved 27040 candles for UPS
# --------------------------------------------------
# Processing symbol: ANET
# Retrieved 31410 candles for ANET
# --------------------------------------------------
# Processing symbol: APH
# Retrieved 25744 candles for APH
# --------------------------------------------------
# Processing symbol: EQIX
# Retrieved 15911 candles for EQIX
# --------------------------------------------------
# Processing symbol: PH
# Retrieved 19522 candles for PH
# --------------------------------------------------
# Processing symbol: KKR
# Retrieved 25064 candles for KKR
# --------------------------------------------------
# Processing symbol: TDG
# Retrieved 10236 candles for TDG
# --------------------------------------------------
# Processing symbol: CL
# Retrieved 24808 candles for CL
# --------------------------------------------------
# Processing symbol: TT
# Retrieved 23279 candles for TT
# --------------------------------------------------
# Processing symbol: ZTS
# Retrieved 24219 candles for ZTS
# --------------------------------------------------
# Processing symbol: MSI
# Retrieved 18662 candles for MSI
# --------------------------------------------------
# Processing symbol: WMB
# Retrieved 24902 candles for WMB
# --------------------------------------------------
# Processing symbol: EOG
# Retrieved 24518 candles for EOG
# --------------------------------------------------
# Processing symbol: MCO
# Retrieved 19122 candles for MCO
# --------------------------------------------------
# Processing symbol: NOC
# Retrieved 20698 candles for NOC
# --------------------------------------------------
# Processing symbol: PNC
# Retrieved 24093 candles for PNC
# --------------------------------------------------
# Processing symbol: GD
# Retrieved 23517 candles for GD
# --------------------------------------------------
# Processing symbol: COF
# Retrieved 24889 candles for COF
# --------------------------------------------------
# Processing symbol: CMG
# Retrieved 28474 candles for CMG
# --------------------------------------------------
# Processing symbol: ITW
# Retrieved 21427 candles for ITW
# --------------------------------------------------
# Processing symbol: USB
# Retrieved 25210 candles for USB
# --------------------------------------------------
# Processing symbol: BDX
# Retrieved 23560 candles for BDX
# --------------------------------------------------
# Processing symbol: APD
# Retrieved 22179 candles for APD
# --------------------------------------------------
# Processing symbol: AZO
# Retrieved 5250 candles for AZO
# --------------------------------------------------
# Processing symbol: ECL
# Retrieved 21994 candles for ECL
# --------------------------------------------------
# Processing symbol: EMR
# Retrieved 24352 candles for EMR
# --------------------------------------------------
# Processing symbol: HCA
# Retrieved 22667 candles for HCA
# --------------------------------------------------
# Processing symbol: OKE
# Retrieved 24675 candles for OKE
# --------------------------------------------------
# Processing symbol: APO
# Retrieved 24712 candles for APO
# --------------------------------------------------
# Processing symbol: BK
# Retrieved 24624 candles for BK
# --------------------------------------------------
# Processing symbol: SLB
# Retrieved 26571 candles for SLB
# --------------------------------------------------
# Processing symbol: KMI
# Retrieved 27041 candles for KMI
# --------------------------------------------------
# Processing symbol: AFL
# Retrieved 24105 candles for AFL
# --------------------------------------------------
# Processing symbol: NEM
# Retrieved 29452 candles for NEM
# --------------------------------------------------
# Processing symbol: ALL
# Retrieved 23203 candles for ALL
# --------------------------------------------------
# Processing symbol: HLT
# Retrieved 23497 candles for HLT
# --------------------------------------------------
# Processing symbol: FCX
# Retrieved 29280 candles for FCX
# --------------------------------------------------
# Processing symbol: TFC
# Retrieved 24980 candles for TFC
# --------------------------------------------------
# Processing symbol: FDX
# Retrieved 24134 candles for FDX
# --------------------------------------------------
# Processing symbol: NSC
# Retrieved 22478 candles for NSC
# --------------------------------------------------
# Processing symbol: JCI
# Retrieved 24683 candles for JCI
# --------------------------------------------------
# Processing symbol: HWM
# Retrieved 24769 candles for HWM
# --------------------------------------------------
# Processing symbol: AIG
# Retrieved 24547 candles for AIG
# --------------------------------------------------
# Processing symbol: CARR
# Retrieved 24792 candles for CARR
# --------------------------------------------------
# Processing symbol: PSX
# Retrieved 24415 candles for PSX
# --------------------------------------------------
# Processing symbol: SPG
# Retrieved 22397 candles for SPG
# --------------------------------------------------
# Processing symbol: RCL
# Retrieved 24984 candles for RCL
# --------------------------------------------------
# Processing symbol: O
# Retrieved 29437 candles for O
# --------------------------------------------------
# Processing symbol: RSG
# Retrieved 21340 candles for RSG
# --------------------------------------------------
# Processing symbol: COR
# Retrieved 22444 candles for COR
# --------------------------------------------------
# Processing symbol: TGT
# Retrieved 27829 candles for TGT
# --------------------------------------------------
# Processing symbol: PSA
# Retrieved 17769 candles for PSA
# --------------------------------------------------
# Processing symbol: KMB
# Retrieved 23857 candles for KMB
# --------------------------------------------------
# Processing symbol: D
# Retrieved 24749 candles for D
# --------------------------------------------------
# Processing symbol: GM
# Retrieved 28917 candles for GM
# --------------------------------------------------
# Processing symbol: AMP
# Retrieved 16019 candles for AMP
# --------------------------------------------------
# Processing symbol: MET
# Retrieved 24567 candles for MET
# --------------------------------------------------
# Processing symbol: MPC
# Retrieved 24245 candles for MPC
# --------------------------------------------------
# Processing symbol: KVUE
# Retrieved 24817 candles for KVUE
# --------------------------------------------------
# Processing symbol: DLR
# Retrieved 23952 candles for DLR
# --------------------------------------------------
# Processing symbol: CCI
# Retrieved 24633 candles for CCI
# --------------------------------------------------
# Processing symbol: SRE
# Retrieved 24631 candles for SRE
# --------------------------------------------------
# Processing symbol: KR
# Retrieved 24836 candles for KR
# --------------------------------------------------
# Processing symbol: FICO
# Retrieved 8205 candles for FICO
# --------------------------------------------------
# Processing symbol: HES
# Retrieved 23641 candles for HES
# --------------------------------------------------
# Processing symbol: YUM
# Retrieved 23850 candles for YUM
# --------------------------------------------------
# Processing symbol: MSCI
# Retrieved 16579 candles for MSCI
# --------------------------------------------------
# Processing symbol: GWW
# Retrieved 9999 candles for GWW
# --------------------------------------------------
# Processing symbol: TRGP
# Retrieved 23152 candles for TRGP
# --------------------------------------------------
# Processing symbol: CTVA
# Retrieved 24291 candles for CTVA
# --------------------------------------------------
# Processing symbol: CMI
# Retrieved 19729 candles for CMI
# --------------------------------------------------
# Processing symbol: DFS
# Retrieved 23399 candles for DFS
# --------------------------------------------------
# Processing symbol: EW
# Retrieved 24546 candles for EW
# --------------------------------------------------
# Processing symbol: TEL
# Retrieved 23004 candles for TEL
# --------------------------------------------------
# Processing symbol: VLO
# Retrieved 24561 candles for VLO
# --------------------------------------------------
# Processing symbol: PEG
# Retrieved 24158 candles for PEG
# --------------------------------------------------
# Processing symbol: URI
# Retrieved 18630 candles for URI
# --------------------------------------------------
# Processing symbol: OTIS
# Retrieved 23959 candles for OTIS
# --------------------------------------------------
# Processing symbol: VST
# Retrieved 32807 candles for VST
# --------------------------------------------------
# Processing symbol: AME
# Retrieved 21797 candles for AME
# --------------------------------------------------
# Processing symbol: FIS
# Retrieved 24512 candles for FIS
# --------------------------------------------------
# Processing symbol: PRU
# Retrieved 23795 candles for PRU
# --------------------------------------------------
# Processing symbol: LHX
# Retrieved 22591 candles for LHX
# --------------------------------------------------
# Processing symbol: F
# Retrieved 39286 candles for F
# --------------------------------------------------
# Processing symbol: CBRE
# Retrieved 23703 candles for CBRE
# --------------------------------------------------
# Processing symbol: ED
# Retrieved 24105 candles for ED
# --------------------------------------------------
# Processing symbol: PCG
# Retrieved 26197 candles for PCG
# --------------------------------------------------
# Processing symbol: PWR
# Retrieved 23083 candles for PWR
# --------------------------------------------------
# Processing symbol: SYY
# Retrieved 24399 candles for SYY
# --------------------------------------------------
# Processing symbol: ETR
# Retrieved 24554 candles for ETR
# --------------------------------------------------
# Processing symbol: ACGL
# Retrieved 23344 candles for ACGL
# --------------------------------------------------
# Processing symbol: DHI
# Retrieved 24848 candles for DHI
# --------------------------------------------------
# Processing symbol: HIG
# Retrieved 22810 candles for HIG
# --------------------------------------------------
# Processing symbol: GLW
# Retrieved 25425 candles for GLW
# --------------------------------------------------
# Processing symbol: WEC
# Retrieved 23970 candles for WEC
# --------------------------------------------------
# Processing symbol: VICI
# Retrieved 25402 candles for VICI
# --------------------------------------------------
# Processing symbol: WTW
# Retrieved 15826 candles for WTW
# --------------------------------------------------
# Processing symbol: GRMN
# Retrieved 20026 candles for GRMN
# --------------------------------------------------
# Processing symbol: OXY
# Retrieved 33179 candles for OXY
# --------------------------------------------------
# Processing symbol: A
# Retrieved 23202 candles for A
# --------------------------------------------------
# Processing symbol: CAH
# Retrieved 23878 candles for CAH
# --------------------------------------------------
# Processing symbol: GIS
# Retrieved 25134 candles for GIS
# --------------------------------------------------
# Processing symbol: RMD
# Retrieved 20107 candles for RMD
# --------------------------------------------------
# Processing symbol: EBAY
# Retrieved 25228 candles for EBAY
# --------------------------------------------------
# Processing symbol: IT
# Retrieved 15935 candles for IT
# --------------------------------------------------
# Processing symbol: IR
# Retrieved 23959 candles for IR
# --------------------------------------------------
# Processing symbol: HUM
# Retrieved 22422 candles for HUM
# --------------------------------------------------
# Processing symbol: EQT
# Retrieved 26081 candles for EQT
# --------------------------------------------------
# Processing symbol: EXR
# Retrieved 20885 candles for EXR
# --------------------------------------------------
# Processing symbol: NDAQ
# Retrieved 24612 candles for NDAQ
# --------------------------------------------------
# Processing symbol: DD
# Retrieved 24217 candles for DD
# --------------------------------------------------
# Processing symbol: WAB
# Retrieved 20875 candles for WAB
# --------------------------------------------------
# Processing symbol: VMC
# Retrieved 20450 candles for VMC
# --------------------------------------------------
# Processing symbol: AVB
# Retrieved 17477 candles for AVB
# --------------------------------------------------
# Processing symbol: EFX
# Retrieved 20602 candles for EFX
# --------------------------------------------------
# Processing symbol: CNC
# Retrieved 24755 candles for CNC
# --------------------------------------------------
# Processing symbol: VTR
# Retrieved 24014 candles for VTR
# --------------------------------------------------
# Processing symbol: MTB
# Retrieved 21961 candles for MTB
# --------------------------------------------------
# Processing symbol: BRO
# Retrieved 23243 candles for BRO
# --------------------------------------------------
# Processing symbol: IQV
# Retrieved 22834 candles for IQV
# --------------------------------------------------
# Processing symbol: TSCO
# Retrieved 24816 candles for TSCO
# --------------------------------------------------
# Processing symbol: MLM
# Retrieved 16662 candles for MLM
# --------------------------------------------------
# Processing symbol: ROK
# Retrieved 20135 candles for ROK
# --------------------------------------------------
# Processing symbol: XYL
# Retrieved 22737 candles for XYL
# --------------------------------------------------
# Processing symbol: AWK
# Retrieved 22747 candles for AWK
# --------------------------------------------------
# Processing symbol: DTE
# Retrieved 21940 candles for DTE
# --------------------------------------------------
# Processing symbol: STZ
# Retrieved 25006 candles for STZ
# --------------------------------------------------
# Processing symbol: DELL
# Retrieved 31728 candles for DELL
# --------------------------------------------------
# Processing symbol: BR
# Retrieved 15648 candles for BR
# --------------------------------------------------
# Processing symbol: NUE
# Retrieved 25181 candles for NUE
# --------------------------------------------------
# Processing symbol: IP
# Retrieved 26183 candles for IP
# --------------------------------------------------
# Processing symbol: DAL
# Retrieved 28415 candles for DAL
# --------------------------------------------------
# Processing symbol: MPWR
# Retrieved 19551 candles for MPWR
# --------------------------------------------------
# Processing symbol: AEE
# Retrieved 23118 candles for AEE
# --------------------------------------------------
# Processing symbol: CHD
# Retrieved 22906 candles for CHD
# --------------------------------------------------
# Processing symbol: LEN
# Retrieved 24967 candles for LEN
# --------------------------------------------------
# Processing symbol: PPL
# Retrieved 24462 candles for PPL
# --------------------------------------------------
# Processing symbol: FITB
# Retrieved 24611 candles for FITB
# --------------------------------------------------
# Processing symbol: HPQ
# Retrieved 25295 candles for HPQ
# --------------------------------------------------
# Processing symbol: KEYS
# Retrieved 20287 candles for KEYS
# --------------------------------------------------
# Processing symbol: STT
# Retrieved 23724 candles for STT
# --------------------------------------------------
# Processing symbol: PPG
# Retrieved 23817 candles for PPG
# --------------------------------------------------
# Processing symbol: RJF
# Retrieved 22522 candles for RJF
# --------------------------------------------------
# Processing symbol: GDDY
# Retrieved 22867 candles for GDDY
# --------------------------------------------------
# Processing symbol: HSY
# Retrieved 23908 candles for HSY
# --------------------------------------------------
# Processing symbol: IRM
# Retrieved 23617 candles for IRM
# --------------------------------------------------
# Processing symbol: TPL
# Retrieved 5396 candles for TPL
# --------------------------------------------------
# Processing symbol: FTV
# Retrieved 23830 candles for FTV
# --------------------------------------------------
# Processing symbol: TYL
# Retrieved 9781 candles for TYL
# --------------------------------------------------
# Processing symbol: MTD
# Retrieved 6453 candles for MTD
# --------------------------------------------------
# Processing symbol: DVN
# Retrieved 27742 candles for DVN
# --------------------------------------------------
# Processing symbol: ATO
# Retrieved 19312 candles for ATO
# --------------------------------------------------
# Processing symbol: DOW
# Retrieved 26339 candles for DOW
# --------------------------------------------------
# Processing symbol: DRI
# Retrieved 22255 candles for DRI
# --------------------------------------------------
# Processing symbol: EQR
# Retrieved 22980 candles for EQR
# --------------------------------------------------
# Processing symbol: CPAY
# Retrieved 14827 candles for CPAY
# --------------------------------------------------
# Processing symbol: GPN
# Retrieved 23433 candles for GPN
# --------------------------------------------------
# Processing symbol: DOV
# Retrieved 20735 candles for DOV
# --------------------------------------------------
# Processing symbol: VLTO
# Retrieved 21568 candles for VLTO
# --------------------------------------------------
# Processing symbol: CBOE
# Retrieved 19167 candles for CBOE
# --------------------------------------------------
# Processing symbol: CNP
# Retrieved 24345 candles for CNP
# --------------------------------------------------
# Processing symbol: SBAC
# Retrieved 19436 candles for SBAC
# --------------------------------------------------
# Processing symbol: EXE
# Retrieved 24264 candles for EXE
# --------------------------------------------------
# Processing symbol: TDY
# Retrieved 10075 candles for TDY
# --------------------------------------------------
# Processing symbol: CINF
# Retrieved 19078 candles for CINF
# --------------------------------------------------
# Processing symbol: ADM
# Retrieved 24997 candles for ADM
# --------------------------------------------------
# Processing symbol: EIX
# Retrieved 25308 candles for EIX
# --------------------------------------------------
# Processing symbol: ES
# Retrieved 24134 candles for ES
# --------------------------------------------------
# Processing symbol: UAL
# Retrieved 28077 candles for UAL
# --------------------------------------------------
# Processing symbol: ZBH
# Retrieved 23486 candles for ZBH
# --------------------------------------------------
# Processing symbol: CMS
# Retrieved 23924 candles for CMS
# --------------------------------------------------
# Processing symbol: SW
# Retrieved 25289 candles for SW
# --------------------------------------------------
# Processing symbol: STE
# Retrieved 16007 candles for STE
# --------------------------------------------------
# Processing symbol: K
# Retrieved 22186 candles for K
# --------------------------------------------------
# Processing symbol: HAL
# Retrieved 26536 candles for HAL
# --------------------------------------------------
# Processing symbol: WAT
# Retrieved 15384 candles for WAT
# --------------------------------------------------
# Processing symbol: HBAN
# Retrieved 25138 candles for HBAN
# --------------------------------------------------
# Processing symbol: NVR
# Retrieved 10937 candles for NVR
# --------------------------------------------------
# Processing symbol: WRB
# Retrieved 23346 candles for WRB
# --------------------------------------------------
# Processing symbol: CTRA
# Retrieved 25661 candles for CTRA
# --------------------------------------------------
# Processing symbol: WY
# Retrieved 24375 candles for WY
# --------------------------------------------------
# Processing symbol: PHM
# Retrieved 24040 candles for PHM
# --------------------------------------------------
# Processing symbol: MKC
# Retrieved 23830 candles for MKC
# --------------------------------------------------
# Processing symbol: FE
# Retrieved 24450 candles for FE
# --------------------------------------------------
# Processing symbol: EXPE
# Retrieved 24167 candles for EXPE
# --------------------------------------------------
# Processing symbol: VRSN
# Retrieved 19739 candles for VRSN
# --------------------------------------------------
# Processing symbol: SYF
# Retrieved 24605 candles for SYF
# --------------------------------------------------
# Processing symbol: LYV
# Retrieved 23589 candles for LYV
# --------------------------------------------------
# Processing symbol: TROW
# Retrieved 23650 candles for TROW
# --------------------------------------------------
# Processing symbol: CCL
# Retrieved 34623 candles for CCL
# --------------------------------------------------
# Processing symbol: HPE
# Retrieved 27886 candles for HPE
# --------------------------------------------------
# Processing symbol: LUV
# Retrieved 26546 candles for LUV
# --------------------------------------------------
# Processing symbol: INVH
# Retrieved 24068 candles for INVH
# --------------------------------------------------
# Processing symbol: IFF
# Retrieved 22805 candles for IFF
# --------------------------------------------------
# Processing symbol: RF
# Retrieved 24754 candles for RF
# --------------------------------------------------
# Processing symbol: ESS
# Retrieved 13881 candles for ESS
# --------------------------------------------------
# Processing symbol: MAA
# Retrieved 19018 candles for MAA
# --------------------------------------------------
# Processing symbol: LH
# Retrieved 18008 candles for LH
# --------------------------------------------------
# Processing symbol: WSM
# Retrieved 23094 candles for WSM
# --------------------------------------------------
# Processing symbol: NRG
# Retrieved 24788 candles for NRG
# --------------------------------------------------
# Processing symbol: NTRS
# Retrieved 22534 candles for NTRS
# --------------------------------------------------
# Processing symbol: DG
# Retrieved 25784 candles for DG
# --------------------------------------------------
# Processing symbol: DGX
# Retrieved 21314 candles for DGX
# --------------------------------------------------
# Processing symbol: NI
# Retrieved 24401 candles for NI
# --------------------------------------------------
# Processing symbol: PTC
# Retrieved 20756 candles for PTC
# --------------------------------------------------
# Processing symbol: PODD
# Retrieved 17919 candles for PODD
# --------------------------------------------------
# Processing symbol: LYB
# Retrieved 24539 candles for LYB
# --------------------------------------------------
# Processing symbol: MOH
# Retrieved 17076 candles for MOH
# --------------------------------------------------
# Processing symbol: CLX
# Retrieved 22371 candles for CLX
# --------------------------------------------------
# Processing symbol: TSN
# Retrieved 24234 candles for TSN
# --------------------------------------------------
# Processing symbol: LII
# Retrieved 14294 candles for LII
# --------------------------------------------------
# Processing symbol: STX
# Retrieved 24640 candles for STX
# --------------------------------------------------
# Processing symbol: CFG
# Retrieved 24508 candles for CFG
# --------------------------------------------------
# Processing symbol: NTAP
# Retrieved 23752 candles for NTAP
# --------------------------------------------------
# Processing symbol: HUBB
# Retrieved 18445 candles for HUBB
# --------------------------------------------------
# Processing symbol: PFG
# Retrieved 22839 candles for PFG
# --------------------------------------------------
# Processing symbol: STLD
# Retrieved 23935 candles for STLD
# --------------------------------------------------
# Processing symbol: SNA
# Retrieved 13653 candles for SNA
# --------------------------------------------------
# Processing symbol: LDOS
# Retrieved 22761 candles for LDOS
# --------------------------------------------------
# Processing symbol: PKG
# Retrieved 19310 candles for PKG
# --------------------------------------------------
# Processing symbol: BAX
# Retrieved 24499 candles for BAX
# --------------------------------------------------
# Processing symbol: FDS
# Retrieved 11579 candles for FDS
# --------------------------------------------------
# Processing symbol: SMCI
# Retrieved 51073 candles for SMCI
# --------------------------------------------------
# Processing symbol: ULTA
# Retrieved 21591 candles for ULTA
# --------------------------------------------------
# Processing symbol: DECK
# Retrieved 26056 candles for DECK
# --------------------------------------------------
# Processing symbol: EXPD
# Retrieved 21928 candles for EXPD
# --------------------------------------------------
# Processing symbol: COO
# Retrieved 22770 candles for COO
# --------------------------------------------------
# Processing symbol: GPC
# Retrieved 22967 candles for GPC
# --------------------------------------------------
# Processing symbol: LNT
# Retrieved 23427 candles for LNT
# --------------------------------------------------
# Processing symbol: L
# Retrieved 18433 candles for L
# --------------------------------------------------
# Processing symbol: WST
# Retrieved 18139 candles for WST
# --------------------------------------------------
# Processing symbol: OMC
# Retrieved 24252 candles for OMC
# --------------------------------------------------
# Processing symbol: TRMB
# Retrieved 22959 candles for TRMB
# --------------------------------------------------
# Processing symbol: DPZ
# Retrieved 18840 candles for DPZ
# --------------------------------------------------
# Processing symbol: KEY
# Retrieved 25276 candles for KEY
# --------------------------------------------------
# Processing symbol: EVRG
# Retrieved 23694 candles for EVRG
# --------------------------------------------------
# Processing symbol: EG
# Retrieved 15560 candles for EG
# --------------------------------------------------
# Processing symbol: BALL
# Retrieved 24001 candles for BALL
# --------------------------------------------------
# Processing symbol: EL
# Retrieved 25887 candles for EL
# --------------------------------------------------
# Processing symbol: FFIV
# Retrieved 16700 candles for FFIV
# --------------------------------------------------
# Processing symbol: ROL
# Retrieved 23128 candles for ROL
# --------------------------------------------------
# Processing symbol: DLTR
# Retrieved 25261 candles for DLTR
# --------------------------------------------------
# Processing symbol: JBL
# Retrieved 22741 candles for JBL
# --------------------------------------------------
# Processing symbol: J
# Retrieved 19504 candles for J
# --------------------------------------------------
# Processing symbol: MAS
# Retrieved 23367 candles for MAS
# --------------------------------------------------
# Processing symbol: TPR
# Retrieved 25146 candles for TPR
# --------------------------------------------------
# Processing symbol: ZBRA
# Retrieved 16628 candles for ZBRA
# --------------------------------------------------
# Processing symbol: PNR
# Retrieved 22445 candles for PNR
# --------------------------------------------------
# Processing symbol: GEN
# Retrieved 24212 candles for GEN
# --------------------------------------------------
# Processing symbol: BBY
# Retrieved 24830 candles for BBY
# --------------------------------------------------
# Processing symbol: BLDR
# Retrieved 23390 candles for BLDR
# --------------------------------------------------
# Processing symbol: AVY
# Retrieved 18759 candles for AVY
# --------------------------------------------------
# Processing symbol: KIM
# Retrieved 24219 candles for KIM
# --------------------------------------------------
# Processing symbol: ARE
# Retrieved 22347 candles for ARE
# --------------------------------------------------
# Processing symbol: DOC
# Retrieved 24445 candles for DOC
# --------------------------------------------------
# Processing symbol: AMCR
# Retrieved 24885 candles for AMCR
# --------------------------------------------------
# Processing symbol: WDC
# Retrieved 25656 candles for WDC
# --------------------------------------------------
# Processing symbol: HOLX
# Retrieved 23757 candles for HOLX
# --------------------------------------------------
# Processing symbol: IEX
# Retrieved 15797 candles for IEX
# --------------------------------------------------
# Processing symbol: APTV
# Retrieved 24440 candles for APTV
# --------------------------------------------------
# Processing symbol: CF
# Retrieved 23913 candles for CF
# --------------------------------------------------
# Processing symbol: UDR
# Retrieved 23188 candles for UDR
# --------------------------------------------------
# Processing symbol: FSLR
# Retrieved 26250 candles for FSLR
# --------------------------------------------------
# Processing symbol: TER
# Retrieved 24697 candles for TER
# --------------------------------------------------
# Processing symbol: JKHY
# Retrieved 17910 candles for JKHY
# --------------------------------------------------
# Processing symbol: LVS
# Retrieved 25479 candles for LVS
# --------------------------------------------------
# Processing symbol: TXT
# Retrieved 23150 candles for TXT
# --------------------------------------------------
# Processing symbol: CPT
# Retrieved 20449 candles for CPT
# --------------------------------------------------
# Processing symbol: RVTY
# Retrieved 20516 candles for RVTY
# --------------------------------------------------
# Processing symbol: CAG
# Retrieved 24964 candles for CAG
# --------------------------------------------------
# Processing symbol: SJM
# Retrieved 22440 candles for SJM
# --------------------------------------------------
# Processing symbol: FOXA
# Retrieved 24699 candles for FOXA
# --------------------------------------------------
# Processing symbol: POOL
# Retrieved 14291 candles for POOL
# --------------------------------------------------
# Processing symbol: AKAM
# Retrieved 23878 candles for AKAM
# --------------------------------------------------
# Processing symbol: REG
# Retrieved 20648 candles for REG
# --------------------------------------------------
# Processing symbol: KMX
# Retrieved 23510 candles for KMX
# --------------------------------------------------
# Processing symbol: CHRW
# Retrieved 21877 candles for CHRW
# --------------------------------------------------
# Processing symbol: JNPR
# Retrieved 23344 candles for JNPR
# --------------------------------------------------
# Processing symbol: SWK
# Retrieved 23640 candles for SWK
# --------------------------------------------------
# Processing symbol: JBHT
# Retrieved 21179 candles for JBHT
# --------------------------------------------------
# Processing symbol: ALLE
# Retrieved 21168 candles for ALLE
# --------------------------------------------------
# Processing symbol: ALGN
# Retrieved 20688 candles for ALGN
# --------------------------------------------------
# Processing symbol: LKQ
# Retrieved 23852 candles for LKQ
# --------------------------------------------------
# Processing symbol: GL
# Retrieved 17716 candles for GL
# --------------------------------------------------
# Processing symbol: UHS
# Retrieved 18778 candles for UHS
# --------------------------------------------------
# Processing symbol: NDSN
# Retrieved 13735 candles for NDSN
# --------------------------------------------------
# Processing symbol: PNW
# Retrieved 20710 candles for PNW
# --------------------------------------------------
# Processing symbol: AIZ
# Retrieved 13748 candles for AIZ
# --------------------------------------------------
# Processing symbol: SOLV
# Retrieved 20331 candles for SOLV
# --------------------------------------------------
# Processing symbol: ERIE
# Retrieved 6053 candles for ERIE
# --------------------------------------------------
# Processing symbol: TAP
# Retrieved 24204 candles for TAP
# --------------------------------------------------
# Processing symbol: VTRS
# Retrieved 24977 candles for VTRS
# --------------------------------------------------
# Processing symbol: SWKS
# Retrieved 25018 candles for SWKS
# --------------------------------------------------
# Processing symbol: NWSA
# Retrieved 23943 candles for NWSA
# --------------------------------------------------
# Processing symbol: PAYC
# Retrieved 17370 candles for PAYC
# --------------------------------------------------
# Processing symbol: EMN
# Retrieved 21840 candles for EMN
# --------------------------------------------------
# Processing symbol: BG
# Retrieved 22921 candles for BG
# --------------------------------------------------
# Processing symbol: TKO
# Retrieved 22417 candles for TKO
# --------------------------------------------------
# Processing symbol: IPG
# Retrieved 24537 candles for IPG
# --------------------------------------------------
# Processing symbol: HST
# Retrieved 24480 candles for HST
# --------------------------------------------------
# Processing symbol: BXP
# Retrieved 22620 candles for BXP
# --------------------------------------------------
# Processing symbol: INCY
# Retrieved 23173 candles for INCY
# --------------------------------------------------
# Processing symbol: MRNA
# Retrieved 34303 candles for MRNA
# --------------------------------------------------
# Processing symbol: EPAM
# Retrieved 17502 candles for EPAM
# --------------------------------------------------
# Processing symbol: TECH
# Retrieved 22577 candles for TECH
# --------------------------------------------------
# Processing symbol: DAY
# Retrieved 23012 candles for DAY
# --------------------------------------------------
# Processing symbol: HRL
# Retrieved 24297 candles for HRL
# --------------------------------------------------
# Processing symbol: RL
# Retrieved 20189 candles for RL
# --------------------------------------------------
# Processing symbol: AES
# Retrieved 27161 candles for AES
# --------------------------------------------------
# Processing symbol: HSIC
# Retrieved 21922 candles for HSIC
# --------------------------------------------------
# Processing symbol: MOS
# Retrieved 25048 candles for MOS
# --------------------------------------------------
# Processing symbol: ALB
# Retrieved 24860 candles for ALB
# --------------------------------------------------
# Processing symbol: NCLH
# Retrieved 29248 candles for NCLH
# --------------------------------------------------
# Processing symbol: ENPH
# Retrieved 27122 candles for ENPH
# --------------------------------------------------
# Processing symbol: MKTX
# Retrieved 16393 candles for MKTX
# --------------------------------------------------
# Processing symbol: HAS
# Retrieved 22588 candles for HAS
# --------------------------------------------------
# Processing symbol: WBA
# Retrieved 31299 candles for WBA
# --------------------------------------------------
# Processing symbol: HII
# Retrieved 19341 candles for HII
# --------------------------------------------------
# Processing symbol: CPB
# Retrieved 24625 candles for CPB
# --------------------------------------------------
# Processing symbol: MTCH
# Retrieved 24740 candles for MTCH
# --------------------------------------------------
# Processing symbol: APA
# Retrieved 25780 candles for APA
# --------------------------------------------------
# Processing symbol: AOS
# Retrieved 22649 candles for AOS
# --------------------------------------------------
# Processing symbol: CRL
# Retrieved 21279 candles for CRL
# --------------------------------------------------
# Processing symbol: LW
# Retrieved 24030 candles for LW
# --------------------------------------------------
# Processing symbol: GNRC
# Retrieved 20645 candles for GNRC
# --------------------------------------------------
# Processing symbol: WYNN
# Retrieved 25425 candles for WYNN
# --------------------------------------------------
# Processing symbol: FRT
# Retrieved 19206 candles for FRT
# --------------------------------------------------
# Processing symbol: PARA
# Retrieved 26152 candles for PARA
# --------------------------------------------------
# Processing symbol: FOX
# Retrieved 21779 candles for FOX
# --------------------------------------------------
# Processing symbol: IVZ
# Retrieved 24280 candles for IVZ
# --------------------------------------------------
# Processing symbol: DVA
# Retrieved 19125 candles for DVA
# --------------------------------------------------
# Processing symbol: MGM
# Retrieved 25612 candles for MGM
# --------------------------------------------------
# Processing symbol: BF.B
# Retrieved 24353 candles for BF.B
# --------------------------------------------------
# Processing symbol: MHK
# Retrieved 19548 candles for MHK
# --------------------------------------------------
# Processing symbol: BEN
# Retrieved 24481 candles for BEN
# --------------------------------------------------
# Processing symbol: CZR
# Retrieved 25245 candles for CZR
# --------------------------------------------------
# Processing symbol: NWS
# Retrieved 19152 candles for NWS
# --------------------------------------------------
# Processing symbol: GS
# Retrieved 25633 candles for GS
# --------------------------------------------------
# Processing symbol: UNH
# Retrieved 25756 candles for UNH
# --------------------------------------------------
# Processing symbol: HD
# Retrieved 25499 candles for HD
# --------------------------------------------------
# Processing symbol: SHW
# Retrieved 23322 candles for SHW
# --------------------------------------------------
# Processing symbol: V
# Retrieved 25590 candles for V
# --------------------------------------------------
# Processing symbol: CAT
# Retrieved 24963 candles for CAT
# --------------------------------------------------
# Processing symbol: MCD
# Retrieved 25190 candles for MCD
# --------------------------------------------------
# Processing symbol: AXP
# Retrieved 25146 candles for AXP
# --------------------------------------------------
# Processing symbol: CRM
# Retrieved 27544 candles for CRM
# --------------------------------------------------
# Processing symbol: TRV
# Retrieved 22868 candles for TRV
# --------------------------------------------------
# Processing symbol: IBM
# Retrieved 25970 candles for IBM
# --------------------------------------------------
# Processing symbol: JPM
# Retrieved 27932 candles for JPM
# --------------------------------------------------
# Processing symbol: PG
# Retrieved 25889 candles for PG
# --------------------------------------------------
# Processing symbol: CVX
# Retrieved 26877 candles for CVX
# --------------------------------------------------
# Processing symbol: BA
# Retrieved 30928 candles for BA
# --------------------------------------------------
# Processing symbol: JNJ
# Retrieved 26313 candles for JNJ
# --------------------------------------------------
# Processing symbol: MMM
# Retrieved 25234 candles for MMM
# --------------------------------------------------
# Processing symbol: DIS
# Retrieved 28428 candles for DIS
# --------------------------------------------------
# Processing symbol: WMT
# Retrieved 33180 candles for WMT
# --------------------------------------------------
# Processing symbol: MRK
# Retrieved 27488 candles for MRK
# --------------------------------------------------
# Processing symbol: KO
# Retrieved 29693 candles for KO
# --------------------------------------------------
# Processing symbol: NKE
# Retrieved 33216 candles for NKE
# --------------------------------------------------
# Processing symbol: VZ
# Retrieved 30955 candles for VZ
# --------------------------------------------------
# Processing symbol: TSLL
# Retrieved 56765 candles for TSLL
# --------------------------------------------------
# Processing symbol: SOXL
# Retrieved 55976 candles for SOXL
# --------------------------------------------------
# Processing symbol: SPXS
# Retrieved 38461 candles for SPXS
# --------------------------------------------------
# Processing symbol: TQQQ
# Retrieved 53644 candles for TQQQ
# --------------------------------------------------
# Processing symbol: TSLZ
# Retrieved 44375 candles for TSLZ
# --------------------------------------------------
# Processing symbol: SQQQ
# Retrieved 53576 candles for SQQQ
# --------------------------------------------------
# Processing symbol: MSTU
# Retrieved 53380 candles for MSTU
# --------------------------------------------------
# Processing symbol: NVDQ
# Retrieved 40768 candles for NVDQ
# --------------------------------------------------
# Processing symbol: SPY
# Retrieved 44690 candles for SPY
# --------------------------------------------------
# Processing symbol: FXI
# Retrieved 37899 candles for FXI
# --------------------------------------------------
# Processing symbol: XLF
# Retrieved 32339 candles for XLF
# --------------------------------------------------
# Processing symbol: IBIT
# Retrieved 51184 candles for IBIT
# --------------------------------------------------
# Processing symbol: SOXS
# Retrieved 50956 candles for SOXS
# --------------------------------------------------
# Processing symbol: ETHU
# Retrieved 52255 candles for ETHU
# --------------------------------------------------
# Processing symbol: QQQ
# Retrieved 49429 candles for QQQ
# --------------------------------------------------
# Processing symbol: HYG
# Retrieved 25392 candles for HYG
# --------------------------------------------------
# Processing symbol: TLT
# Retrieved 40578 candles for TLT
# --------------------------------------------------
# Processing symbol: PSLV
# Retrieved 26069 candles for PSLV
# --------------------------------------------------
# Processing symbol: IWM
# Retrieved 41667 candles for IWM
# --------------------------------------------------
# Processing symbol: TZA
# Retrieved 35344 candles for TZA
# --------------------------------------------------
# Processing symbol: EEM
# Retrieved 26073 candles for EEM
# --------------------------------------------------
# Processing symbol: KWEB
# Retrieved 34645 candles for KWEB
# --------------------------------------------------
# Processing symbol: LQD
# Retrieved 25131 candles for LQD
# --------------------------------------------------
# Processing symbol: FAZ
# Retrieved 27949 candles for FAZ
# --------------------------------------------------
# Processing symbol: NVDL
# Retrieved 51114 candles for NVDL
# --------------------------------------------------
# Processing symbol: EWZ
# Retrieved 26632 candles for EWZ
# --------------------------------------------------
# Processing symbol: MSTZ
# Retrieved 46836 candles for MSTZ
# --------------------------------------------------
# Processing symbol: UVXY
# Retrieved 41221 candles for UVXY
# --------------------------------------------------
# Processing symbol: SLV
# Retrieved 34889 candles for SLV
# --------------------------------------------------
# Processing symbol: GDX
# Retrieved 33448 candles for GDX
# --------------------------------------------------
# Processing symbol: LABD
# Retrieved 29244 candles for LABD
# --------------------------------------------------
# Processing symbol: NVDX
# Retrieved 44179 candles for NVDX
# --------------------------------------------------
# Processing symbol: XLE
# Retrieved 27695 candles for XLE
# --------------------------------------------------
# Processing symbol: AMDL
# Retrieved 40191 candles for AMDL
# --------------------------------------------------
# Processing symbol: SCHD
# Retrieved 36744 candles for SCHD
# --------------------------------------------------
# ...
# Processing symbol: SPDN
# Retrieved 17702 candles for SPDN
# --------------------------------------------------
# Processing symbol: XLU
# Retrieved 26163 candles for XLU
# --------------------------------------------------
# Processing symbol: ASHR
# Retrieved 24352 candles for ASHR
# --------------------------------------------------
# Processing symbol: IEMG
# Retrieved 24408 candles for IEMG
# --------------------------------------------------
# Processing symbol: ETHA
# Retrieved 32954 candles for ETHA
# --------------------------------------------------
# Processing symbol: BIL
# Retrieved 32410 candles for BIL
# --------------------------------------------------
# Processing symbol: SCHF
# Retrieved 24406 candles for SCHF
# --------------------------------------------------
# Processing symbol: IJH
# Retrieved 26545 candles for IJH
# --------------------------------------------------
# Processing symbol: SGOV
# Retrieved 37909 candles for SGOV
# --------------------------------------------------
# Processing symbol: XLI
# Retrieved 25393 candles for XLI
# --------------------------------------------------
# Processing symbol: UNG
# Retrieved 30979 candles for UNG
# --------------------------------------------------
# Processing symbol: XBI
# Retrieved 26543 candles for XBI
# --------------------------------------------------
# Processing symbol: SPLG
# Retrieved 28107 candles for SPLG
# --------------------------------------------------
# Processing symbol: BITX
# Retrieved 43790 candles for BITX
# --------------------------------------------------
# Processing symbol: VWO
# Retrieved 24713 candles for VWO
# --------------------------------------------------
# Processing symbol: XLV
# Retrieved 25402 candles for XLV
# --------------------------------------------------
# Processing symbol: BITO
# Retrieved 39207 candles for BITO
# --------------------------------------------------
# Processing symbol: RSP
# Retrieved 25676 candles for RSP
# --------------------------------------------------
# Processing symbol: GLD
# Retrieved 30498 candles for GLD
# --------------------------------------------------
# Processing symbol: AGG
# Retrieved 24592 candles for AGG
# --------------------------------------------------
# Processing symbol: RWM
# Retrieved 23783 candles for RWM
# --------------------------------------------------
# Processing symbol: KOLD
# Retrieved 41062 candles for KOLD
# --------------------------------------------------
# Processing symbol: QYLD
# Retrieved 28590 candles for QYLD
# --------------------------------------------------
# Processing symbol: JAAA
# Retrieved 25150 candles for JAAA
# --------------------------------------------------
# Processing symbol: YINN
# Retrieved 39572 candles for YINN
# --------------------------------------------------
# Processing symbol: VXX
# Retrieved 30694 candles for VXX
# --------------------------------------------------
# Processing symbol: SHV
# Retrieved 30165 candles for SHV
# --------------------------------------------------
# Processing symbol: SMH
# Retrieved 28964 candles for SMH
# --------------------------------------------------
# Processing symbol: UVIX
# Retrieved 37880 candles for UVIX
# --------------------------------------------------
# Processing symbol: VCIT
# Retrieved 24261 candles for VCIT
# --------------------------------------------------
# Processing symbol: BND
# Retrieved 25589 candles for BND
# --------------------------------------------------
# Processing symbol: TMF
# Retrieved 40034 candles for TMF
# --------------------------------------------------
# Processing symbol: SBIT
# Retrieved 37174 candles for SBIT
# --------------------------------------------------
# Processing symbol: IAU
# Retrieved 27165 candles for IAU
# --------------------------------------------------
# Processing symbol: SPIB
# Retrieved 23159 candles for SPIB
# --------------------------------------------------
# Processing symbol: IEF
# Retrieved 26033 candles for IEF
# --------------------------------------------------
# Processing symbol: IVV
# Retrieved 26335 candles for IVV
# --------------------------------------------------
# Processing symbol: VOO
# Retrieved 29935 candles for VOO
# --------------------------------------------------
# Processing symbol: QID
# Retrieved 30366 candles for QID
# --------------------------------------------------
# Processing symbol: EMB
# Retrieved 24049 candles for EMB
# --------------------------------------------------
# Processing symbol: PGX
# Retrieved 22187 candles for PGX
# --------------------------------------------------
# Processing symbol: XLB
# Retrieved 24807 candles for XLB
# --------------------------------------------------
# Processing symbol: JPST
# Retrieved 25232 candles for JPST
# --------------------------------------------------
# Processing symbol: IGV
# Retrieved 26188 candles for IGV
# --------------------------------------------------
# Processing symbol: SCHH
# Retrieved 23297 candles for SCHH
# --------------------------------------------------
# Processing symbol: INDA
# Retrieved 25126 candles for INDA
# --------------------------------------------------
# Processing symbol: SH
# Retrieved 26310 candles for SH
# --------------------------------------------------
# Processing symbol: XRT
# Retrieved 24554 candles for XRT
# --------------------------------------------------
# Processing symbol: AAPL
# Retrieved 44372 candles for AAPL
# --------------------------------------------------
# Processing symbol: MSFT
# Retrieved 37148 candles for MSFT
# --------------------------------------------------
# Processing symbol: NVDA
# Retrieved 57246 candles for NVDA
# --------------------------------------------------
# Processing symbol: AMZN
# Retrieved 44766 candles for AMZN
# --------------------------------------------------
# Processing symbol: AVGO
# Retrieved 41257 candles for AVGO
# --------------------------------------------------
# Processing symbol: META
# Retrieved 37018 candles for META
# --------------------------------------------------
# Processing symbol: COST
# Retrieved 24715 candles for COST
# --------------------------------------------------
# Processing symbol: NFLX
# Retrieved 27696 candles for NFLX
# --------------------------------------------------
# Processing symbol: TSLA
# Retrieved 55519 candles for TSLA
# --------------------------------------------------
# Processing symbol: GOOGL
# Retrieved 41159 candles for GOOGL
# --------------------------------------------------
# Processing symbol: GOOG
# Retrieved 37832 candles for GOOG
# --------------------------------------------------
# Processing symbol: TMUS
# Retrieved 25263 candles for TMUS
# --------------------------------------------------
# Processing symbol: CSCO
# Retrieved 28676 candles for CSCO
# --------------------------------------------------
# Processing symbol: LIN
# Retrieved 23682 candles for LIN
# --------------------------------------------------
# Processing symbol: PEP
# Retrieved 26638 candles for PEP
# --------------------------------------------------
# Processing symbol: PLTR
# Retrieved 55141 candles for PLTR
# --------------------------------------------------
# Processing symbol: ISRG
# Retrieved 23944 candles for ISRG
# --------------------------------------------------
# Processing symbol: INTU
# Retrieved 23483 candles for INTU
# --------------------------------------------------
# Processing symbol: QCOM
# Retrieved 28471 candles for QCOM
# --------------------------------------------------
# Processing symbol: AMGN
# Retrieved 24622 candles for AMGN
# --------------------------------------------------
# Processing symbol: ADBE
# Retrieved 26185 candles for ADBE
# --------------------------------------------------
# Processing symbol: AMD
# Retrieved 46613 candles for AMD
# --------------------------------------------------
# Processing symbol: TXN
# Retrieved 25742 candles for TXN
# --------------------------------------------------
# Processing symbol: BKNG
# Retrieved 10744 candles for BKNG
# --------------------------------------------------
# Processing symbol: GILD
# Retrieved 25886 candles for GILD
# --------------------------------------------------
# Processing symbol: CMCSA
# Retrieved 27570 candles for CMCSA
# --------------------------------------------------
# Processing symbol: HON
# Retrieved 25188 candles for HON
# --------------------------------------------------
# Processing symbol: VRTX
# Retrieved 22906 candles for VRTX
# --------------------------------------------------
# Processing symbol: ADP
# Retrieved 22788 candles for ADP
# --------------------------------------------------
# Processing symbol: AMAT
# Retrieved 27607 candles for AMAT
# --------------------------------------------------
# Processing symbol: PANW
# Retrieved 27389 candles for PANW
# --------------------------------------------------
# Processing symbol: SBUX
# Retrieved 27429 candles for SBUX
# --------------------------------------------------
# Processing symbol: ADI
# Retrieved 24877 candles for ADI
# --------------------------------------------------
# Processing symbol: MELI
# Retrieved 14116 candles for MELI
# --------------------------------------------------
# Processing symbol: INTC
# Retrieved 50539 candles for INTC
# --------------------------------------------------
# Processing symbol: MU
# Retrieved 40353 candles for MU
# --------------------------------------------------
# Processing symbol: LRCX
# Retrieved 28806 candles for LRCX
# --------------------------------------------------
# Processing symbol: KLAC
# Retrieved 20596 candles for KLAC
# --------------------------------------------------
# Processing symbol: MDLZ
# Retrieved 25761 candles for MDLZ
# --------------------------------------------------
# Processing symbol: CTAS
# Retrieved 23187 candles for CTAS
# --------------------------------------------------
# Processing symbol: CRWD
# Retrieved 28079 candles for CRWD
# --------------------------------------------------
# Processing symbol: ORLY
# Retrieved 12343 candles for ORLY
# --------------------------------------------------
# Processing symbol: APP
# Retrieved 31147 candles for APP
# --------------------------------------------------
# Processing symbol: PDD
# Retrieved 33112 candles for PDD
# --------------------------------------------------
# Processing symbol: FTNT
# Retrieved 26085 candles for FTNT
# --------------------------------------------------
# Processing symbol: DASH
# Retrieved 25742 candles for DASH
# --------------------------------------------------
# Processing symbol: CDNS
# Retrieved 23813 candles for CDNS
# --------------------------------------------------
# Processing symbol: MSTR
# Retrieved 44274 candles for MSTR
# --------------------------------------------------
# Processing symbol: REGN
# Retrieved 19374 candles for REGN
# --------------------------------------------------
# Processing symbol: SNPS
# Retrieved 21874 candles for SNPS
# --------------------------------------------------
# Processing symbol: MAR
# Retrieved 23399 candles for MAR
# --------------------------------------------------
# Processing symbol: PYPL
# Retrieved 31674 candles for PYPL
# --------------------------------------------------
# Processing symbol: ROP
# Retrieved 16555 candles for ROP
# --------------------------------------------------
# Processing symbol: CEG
# Retrieved 27024 candles for CEG
# --------------------------------------------------
# Processing symbol: ASML
# Retrieved 25468 candles for ASML
# --------------------------------------------------
# Processing symbol: AEP
# Retrieved 24883 candles for AEP
# --------------------------------------------------
# Processing symbol: MNST
# Retrieved 24972 candles for MNST
# --------------------------------------------------
# Processing symbol: ADSK
# Retrieved 22831 candles for ADSK
# --------------------------------------------------
# Processing symbol: CSX
# Retrieved 26199 candles for CSX
# --------------------------------------------------
# Processing symbol: PAYX
# Retrieved 23514 candles for PAYX
# --------------------------------------------------
# Processing symbol: CPRT
# Retrieved 24640 candles for CPRT
# --------------------------------------------------
# Processing symbol: MRVL
# Retrieved 34441 candles for MRVL
# --------------------------------------------------
# Processing symbol: CHTR
# Retrieved 20532 candles for CHTR
# --------------------------------------------------
# Processing symbol: ABNB
# Retrieved 26384 candles for ABNB
# --------------------------------------------------
# Processing symbol: PCAR
# Retrieved 24191 candles for PCAR
# --------------------------------------------------
# Processing symbol: WDAY
# Retrieved 24255 candles for WDAY
# --------------------------------------------------
# Processing symbol: NXPI
# Retrieved 24561 candles for NXPI
# --------------------------------------------------
# Processing symbol: KDP
# Retrieved 25711 candles for KDP
# --------------------------------------------------
# Processing symbol: FANG
# Retrieved 24514 candles for FANG
# --------------------------------------------------
# Processing symbol: EXC
# Retrieved 25103 candles for EXC
# --------------------------------------------------
# Processing symbol: FAST
# Retrieved 24504 candles for FAST
# --------------------------------------------------
# Processing symbol: BKR
# Retrieved 25667 candles for BKR
# --------------------------------------------------
# Processing symbol: AZN
# Retrieved 28384 candles for AZN
# --------------------------------------------------
# Processing symbol: ROST
# Retrieved 24270 candles for ROST
# --------------------------------------------------
# Processing symbol: VRSK
# Retrieved 18476 candles for VRSK
# --------------------------------------------------
# Processing symbol: XEL
# Retrieved 24496 candles for XEL
# --------------------------------------------------
# Processing symbol: AXON
# Retrieved 18796 candles for AXON
# --------------------------------------------------
# Processing symbol: CCEP
# Retrieved 23914 candles for CCEP
# --------------------------------------------------
# Processing symbol: CTSH
# Retrieved 24600 candles for CTSH
# --------------------------------------------------
# Processing symbol: EA
# Retrieved 25023 candles for EA
# --------------------------------------------------
# Processing symbol: GEHC
# Retrieved 24550 candles for GEHC
# --------------------------------------------------
# Processing symbol: TTWO
# Retrieved 23378 candles for TTWO
# --------------------------------------------------
# Processing symbol: KHC
# Retrieved 27466 candles for KHC
# --------------------------------------------------
# Processing symbol: ODFL
# Retrieved 23214 candles for ODFL
# --------------------------------------------------
# Processing symbol: TEAM
# Retrieved 24436 candles for TEAM
# --------------------------------------------------
# Processing symbol: IDXX
# Retrieved 17669 candles for IDXX
# --------------------------------------------------
# Processing symbol: LULU
# Retrieved 24454 candles for LULU
# --------------------------------------------------
# Processing symbol: CSGP
# Retrieved 24227 candles for CSGP
# --------------------------------------------------
# Processing symbol: DDOG
# Retrieved 26479 candles for DDOG
# --------------------------------------------------
# Processing symbol: ZS
# Retrieved 24417 candles for ZS
# --------------------------------------------------
# Processing symbol: ANSS
# Retrieved 15377 candles for ANSS
# --------------------------------------------------
# Processing symbol: DXCM
# Retrieved 24847 candles for DXCM
# --------------------------------------------------
# Processing symbol: WBD
# Retrieved 28422 candles for WBD
# --------------------------------------------------
# Processing symbol: MCHP
# Retrieved 26007 candles for MCHP
# --------------------------------------------------
# Processing symbol: TTD
# Retrieved 31908 candles for TTD
# --------------------------------------------------
# Processing symbol: CDW
# Retrieved 22242 candles for CDW
# --------------------------------------------------
# Processing symbol: GFS
# Retrieved 23972 candles for GFS
# --------------------------------------------------
# Processing symbol: BIIB
# Retrieved 23113 candles for BIIB
# --------------------------------------------------
# Processing symbol: ON
# Retrieved 26983 candles for ON
# --------------------------------------------------
# Processing symbol: ARM
# Retrieved 31732 candles for ARM
# --------------------------------------------------
# Processing symbol: MDB
# Retrieved 24989 candles for MDB
# --------------------------------------------------

# %%
df
# Out:
#                               interval                  end    open    high  \
# item_id timestamp
# BRK.B   2025-01-06 06:15:00  OneMinute  2025-01-06 06:16:00  456.10  456.20
#         2025-01-06 06:21:00  OneMinute  2025-01-06 06:22:00  456.35  456.35
#         2025-01-06 07:00:00  OneMinute  2025-01-06 07:01:00  456.54  456.54
#         2025-01-06 07:59:00  OneMinute  2025-01-06 08:00:00  456.30  456.30
#         2025-01-06 08:00:00  OneMinute  2025-01-06 08:01:00  456.71  456.71
# ...                                ...                  ...     ...     ...
# MDB     2025-04-04 18:54:00  OneMinute  2025-04-04 18:55:00  153.95  153.95
#         2025-04-04 19:00:00  OneMinute  2025-04-04 19:01:00  153.51  153.51
#         2025-04-04 19:36:00  OneMinute  2025-04-04 19:37:00  153.51  153.51
#         2025-04-04 19:50:00  OneMinute  2025-04-04 19:51:00  153.50  153.50
#         2025-04-04 19:59:00  OneMinute  2025-04-04 20:00:00  153.50  153.50
#
#                                 low   close  volume        VWAP  \
# item_id timestamp
# BRK.B   2025-01-06 06:15:00  456.10  456.20     258  455.882852
#         2025-01-06 06:21:00  456.35  456.35     100  455.961142
#         2025-01-06 07:00:00  456.07  456.07     300  456.179291
#         2025-01-06 07:59:00  456.30  456.30     346  456.208096
#         2025-01-06 08:00:00  456.31  456.31    1484  456.240498
# ...                             ...     ...     ...         ...
# MDB     2025-04-04 18:54:00  153.95  153.95     496  156.060306
#         2025-04-04 19:00:00  153.51  153.51     110  156.060191
#         2025-04-04 19:36:00  153.51  153.51     398  156.060250
#         2025-04-04 19:50:00  153.50  153.50     110  156.060318
#         2025-04-04 19:59:00  153.50  153.50     693  156.059773
#
#                                 industrySector
# item_id timestamp
# BRK.B   2025-01-06 06:15:00  FinancialServices
#         2025-01-06 06:21:00  FinancialServices
#         2025-01-06 07:00:00  FinancialServices
#         2025-01-06 07:59:00  FinancialServices
#         2025-01-06 08:00:00  FinancialServices
# ...                                        ...
# MDB     2025-04-04 18:54:00         Technology
#         2025-04-04 19:00:00         Technology
#         2025-04-04 19:36:00         Technology
#         2025-04-04 19:50:00         Technology
#         2025-04-04 19:59:00         Technology
#
# [15765758 rows x 9 columns]
